# %% [markdown]
# <a href="https://colab.research.google.com/github/GraceHerchenroder/Thesis/blob/main/Thesis_Statistics_Walking_Newest.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# Importing libraries
import pandas as pd
import numpy as np
import statsmodels.api as sm
from statsmodels.formula.api import ols
from scipy import stats
from statsmodels.stats.multitest import multipletests
import matplotlib.pyplot as plt

# %%
# Performing two-way ANOVA
def statAnova_ut(kinematic_data):
  dataframe = pd.DataFrame({'Gender': np.repeat(['women', 'men'], 5),
                          'Size': ['small', 'small', 'small', 'large', 'large', 'small', 'small', 'small', 'large', 'large'],
                          'Kinematic': kinematic_data[0][:]})
  group_1_mean = np.mean(kinematic_data[0][:3])
  group_1_sd = np.std(kinematic_data[0][:3])
  group_2_mean = np.mean(kinematic_data[0][3:5])
  group_2_sd = np.std(kinematic_data[0][3:5])
  group_3_mean = np.mean(kinematic_data[0][5:8])
  group_3_sd = np.std(kinematic_data[0][5:8])
  group_4_mean = np.mean(kinematic_data[0][8:])
  group_4_sd = np.std(kinematic_data[0][8:])
  print(kinematic_data[0][:3])
  print(group_1_mean, group_1_sd)
  print(kinematic_data[0][3:5])
  print(group_2_mean, group_2_sd)
  print(kinematic_data[0][5:8])
  print(group_3_mean, group_3_sd)
  print(kinematic_data[0][8:])
  print(group_4_mean, group_4_sd)
  print(dataframe)
  model = ols('Kinematic ~ C(Gender) + C(Size) + C(Gender):C(Size)', data=dataframe).fit()
  result = sm.stats.anova_lm(model, typ=2)
  return result

def statAnova_lt(kinematic_data):
  dataframe = pd.DataFrame({'Gender': np.repeat(['women', 'men'], 5),
                          'Size': ['small', 'small', 'small', 'large', 'large', 'small', 'small', 'small', 'large', 'large'],
                          'Kinematic': kinematic_data[1][:]})
  group_1_mean = np.mean(kinematic_data[1][:3])
  group_1_sd = np.std(kinematic_data[1][:3])
  group_2_mean = np.mean(kinematic_data[1][3:5])
  group_2_sd = np.std(kinematic_data[1][3:5])
  group_3_mean = np.mean(kinematic_data[1][5:8])
  group_3_sd = np.std(kinematic_data[1][5:8])
  group_4_mean = np.mean(kinematic_data[1][8:])
  group_4_sd = np.std(kinematic_data[1][8:])
  print(kinematic_data[1][:3])
  print(group_1_mean, group_1_sd)
  print(kinematic_data[1][3:5])
  print(group_2_mean, group_2_sd)
  print(kinematic_data[1][5:8])
  print(group_3_mean, group_3_sd)
  print(kinematic_data[1][8:])
  print(group_4_mean, group_4_sd)
  print(dataframe)
  model = ols('Kinematic ~ C(Gender) + C(Size) + C(Gender):C(Size)', data=dataframe).fit()
  result = sm.stats.anova_lm(model, typ=2)
  return result

def statAnova_lum(kinematic_data):
  dataframe = pd.DataFrame({'Gender': np.repeat(['women', 'men'], 5),
                          'Size': ['small', 'small', 'small', 'large', 'large', 'small', 'small', 'small', 'large', 'large'],
                          'Kinematic': kinematic_data[2][:]})
  group_1_mean = np.mean(kinematic_data[2][:3])
  group_1_sd = np.std(kinematic_data[2][:3])
  group_2_mean = np.mean(kinematic_data[2][3:5])
  group_2_sd = np.std(kinematic_data[2][3:5])
  group_3_mean = np.mean(kinematic_data[2][5:8])
  group_3_sd = np.std(kinematic_data[2][5:8])
  group_4_mean = np.mean(kinematic_data[2][8:])
  group_4_sd = np.std(kinematic_data[2][8:])
  print(kinematic_data[2][:3])
  print(group_1_mean, group_1_sd)
  print(kinematic_data[2][3:5])
  print(group_2_mean, group_2_sd)
  print(kinematic_data[2][5:8])
  print(group_3_mean, group_3_sd)
  print(kinematic_data[2][8:])
  print(group_4_mean, group_4_sd)
  print(dataframe)
  model = ols('Kinematic ~ C(Gender) + C(Size) + C(Gender):C(Size)', data=dataframe).fit()
  result = sm.stats.anova_lm(model, typ=2)
  return result

def box_whisker(kinematic_data):
   small_men_data_ut = kinematic_data[0][8:]
   large_men_data_ut = kinematic_data[0][5:8]
   small_women_data_ut = kinematic_data[0][:3]
   large_women_data_ut = kinematic_data[0][3:5]
   small_men_data_lt = kinematic_data[1][8:]
   large_men_data_lt = kinematic_data[1][5:8]
   small_women_data_lt = kinematic_data[1][:3]
   large_women_data_lt = kinematic_data[1][3:5]
   small_men_data_lum = kinematic_data[2][8:]
   large_men_data_lum = kinematic_data[2][5:8]
   small_women_data_lum = kinematic_data[2][:3]
   large_women_data_lum = kinematic_data[2][3:5]
   fig, ax = plt.subplots(3, 2, figsize=(6, 10))
   ax[0][0].boxplot([small_men_data_ut, large_men_data_ut], labels = ['small', 'large'])
   ax[0][0].set_title('Men')
   ax[0][0].set_ylabel('Upper Thoracic')
   ax[0][1].boxplot([small_women_data_ut, large_women_data_ut], labels = ['small', 'large'])
   ax[0][1].set_title('Women')
   ax[1][0].boxplot([small_men_data_lt, large_men_data_lt], labels = ['small', 'large'])
   ax[1][0].set_title('Men')
   ax[1][0].set_ylabel('Lower Thoracic')
   ax[1][1].boxplot([small_women_data_lt, large_women_data_lt], labels = ['small', 'large'])
   ax[1][1].set_title('Women')
   ax[2][0].boxplot([small_men_data_lum, large_men_data_lum], labels = ['small', 'large'])
   ax[2][0].set_title('Men')
   ax[2][0].set_ylabel('Lumbar')
   ax[2][1].boxplot([small_women_data_lum, large_women_data_lum], labels = ['small', 'large'])
   ax[2][1].set_title('Women')
   plt.show()

# %%
# Follow Up analysis: Significant
def significant_ut(kinematic_data):
  small_men_data = kinematic_data[0][8:]
  large_men_data = kinematic_data[0][5:8]
  small_women_data = kinematic_data[0][:3]
  large_women_data = kinematic_data[0][3:5]

  [stat_small, p_small] = stats.ttest_ind(small_men_data, small_women_data);
  [stat_large, p_large] = stats.ttest_ind(large_men_data, large_women_data);
  [stat_women, p_women] = stats.ttest_ind(small_women_data, large_women_data);
  [stat_men, p_men] = stats.ttest_ind(small_men_data, large_men_data);

  result = multipletests([p_small, p_large, p_women, p_men], alpha = 0.05, method = 'bonferroni')

  return result[1]

def significant_lt(kinematic_data):
  small_men_data = kinematic_data[1][8:]
  large_men_data = kinematic_data[1][5:8]
  small_women_data = kinematic_data[1][:3]
  large_women_data = kinematic_data[1][3:5]

  [stat_small, p_small] = stats.ttest_ind(small_men_data, small_women_data);
  [stat_large, p_large] = stats.ttest_ind(large_men_data, large_women_data);
  [stat_women, p_women] = stats.ttest_ind(small_women_data, large_women_data);
  [stat_men, p_men] = stats.ttest_ind(small_men_data, large_men_data);

  result = multipletests([p_small, p_large, p_women, p_men], alpha = 0.05, method = 'bonferroni')

  return result[1]

def significant_lum(kinematic_data):
  small_men_data = kinematic_data[2][8:]
  large_men_data = kinematic_data[2][5:8]
  small_women_data = kinematic_data[2][:3]
  large_women_data = kinematic_data[2][3:5]

  [stat_small, p_small] = stats.ttest_ind(small_men_data, small_women_data);
  [stat_large, p_large] = stats.ttest_ind(large_men_data, large_women_data);
  [stat_women, p_women] = stats.ttest_ind(small_women_data, large_women_data);
  [stat_men, p_men] = stats.ttest_ind(small_men_data, large_men_data);

  result = multipletests([p_small, p_large, p_women, p_men], alpha = 0.05, method = 'bonferroni')

  return result[1]

# %%
# Flexion
print('\033[1mFlexion\033[0m')
print('')

# Minimums
url_min_walk_flex = 'https://raw.githubusercontent.com/GraceHerchenroder/Thesis/main/min_walk_flex.csv'
min_walk_flex = pd.read_csv(url_min_walk_flex, header = None)

print('Minimum: Upper Thoracic')
result_min_walk_flex_ut = statAnova_ut(min_walk_flex)
print(result_min_walk_flex_ut)
if result_min_walk_flex_ut['PR(>F)'][0] < 0.05:
  print('Gender: Significant')
if result_min_walk_flex_ut['PR(>F)'][1] < 0.05:
  print('Size: Significant')
if result_min_walk_flex_ut['PR(>F)'][2] < 0.05:
  result = significant_ut(min_walk_flex, result_min_walk_flex_ut['PR(>F)'])
  print('Small: ', result[1], ', Large: ', result[2], ', Women: ', result[3], ', Men: ', result[4])
  if result[1] < result[0]:
    print('Small: Significant')
  if result[2] < result[0]:
    print('Large: Significant')
  if result[3] < result[0]:
    print('Women: Significant')
  if result[4] < result[0]:
    print('Men: Significant')
print('')

print('Minimum: Lower Thoracic')
result_min_walk_flex_lt = statAnova_lt(min_walk_flex)
print(result_min_walk_flex_lt)
if result_min_walk_flex_lt['PR(>F)'][0] < 0.05:
  print('Gender: Significant')
if result_min_walk_flex_lt['PR(>F)'][1] < 0.05:
  print('Size: Significant')
if result_min_walk_flex_lt['PR(>F)'][2] < 0.05:
  result = significant_lt(min_walk_flex, result_min_walk_flex_lt['PR(>F)'])
  print('Small: ', result[1], ', Large: ', result[2], ', Women: ', result[3], ', Men: ', result[4])
  if result[1] < result[0]:
    print('Small: Significant')
  if result[2] < result[0]:
    print('Large: Significant')
  if result[3] < result[0]:
    print('Women: Significant')
  if result[4] < result[0]:
    print('Men: Significant')
print('')

print('Minimum: Lumbar')
result_min_walk_flex_lum = statAnova_lum(min_walk_flex)
print(result_min_walk_flex_lum)
if result_min_walk_flex_lum['PR(>F)'][0] < 0.05:
  print('Gender: Significant')
if result_min_walk_flex_lum['PR(>F)'][1] < 0.05:
  print('Size: Significant')
if result_min_walk_flex_lum['PR(>F)'][2] < 0.05:
  result = significant_lum(min_walk_flex, result_min_walk_flex_lum['PR(>F)'])
  print('Small: ', result[1], ', Large: ', result[2], ', Women: ', result[3], ', Men: ', result[4])
  if result[1] < result[0]:
    print('Small: Significant')
  if result[2] < result[0]:
    print('Large: Significant')
  if result[3] < result[0]:
    print('Women: Significant')
  if result[4] < result[0]:
    print('Men: Significant')
print('')

# Maximums
url_max_walk_flex = 'https://raw.githubusercontent.com/GraceHerchenroder/Thesis/main/max_walk_flex.csv'
max_walk_flex = pd.read_csv(url_max_walk_flex, header = None)

print('Maximum: Upper Thoracic')
result_max_walk_flex_ut = statAnova_ut(max_walk_flex)
print(result_max_walk_flex_ut)
if result_max_walk_flex_ut['PR(>F)'][0] < 0.05:
  print('Gender: Significant')
if result_max_walk_flex_ut['PR(>F)'][1] < 0.05:
  print('Size: Significant')
if result_max_walk_flex_ut['PR(>F)'][2] < 0.05:
  result = significant_ut(max_walk_flex, result_max_walk_flex_ut['PR(>F)'])
  print('Small: ', result[1], ', Large: ', result[2], ', Women: ', result[3], ', Men: ', result[4])
  if result[1] < result[0]:
    print('Small: Significant')
  if result[2] < result[0]:
    print('Large: Significant')
  if result[3] < result[0]:
    print('Women: Significant')
  if result[4] < result[0]:
    print('Men: Significant')
print('')

print('Maximum: Lower Thoracic')
result_max_walk_flex_lt = statAnova_lt(max_walk_flex)
print(result_max_walk_flex_lt)
if result_max_walk_flex_lt['PR(>F)'][0] < 0.05:
  print('Gender: Significant')
if result_max_walk_flex_lt['PR(>F)'][1] < 0.05:
  print('Size: Significant')
if result_max_walk_flex_lt['PR(>F)'][2] < 0.05:
  result = significant_lt(max_walk_flex, result_max_walk_flex_lt['PR(>F)'])
  print('Small: ', result[1], ', Large: ', result[2], ', Women: ', result[3], ', Men: ', result[4])
  if result[1] < result[0]:
    print('Small: Significant')
  if result[2] < result[0]:
    print('Large: Significant')
  if result[3] < result[0]:
    print('Women: Significant')
  if result[4] < result[0]:
    print('Men: Significant')
print('')

print('Maximum: Lumbar')
result_max_walk_flex_lum = statAnova_lum(max_walk_flex)
print(result_max_walk_flex_lum)
if result_max_walk_flex_lum['PR(>F)'][0] < 0.05:
  print('Gender: Significant')
if result_max_walk_flex_lum['PR(>F)'][1] < 0.05:
  print('Size: Significant')
if result_max_walk_flex_lum['PR(>F)'][2] < 0.05:
  result = significant_lum(max_walk_flex, result_max_walk_flex_lum['PR(>F)'])
  print('Small: ', result[1], ', Large: ', result[2], ', Women: ', result[3], ', Men: ', result[4])
  if result[1] < result[0]:
    print('Small: Significant')
  if result[2] < result[0]:
    print('Large: Significant')
  if result[3] < result[0]:
    print('Women: Significant')
  if result[4] < result[0]:
    print('Men: Significant')
print('')

# Means
url_mean_walk_flex = 'https://raw.githubusercontent.com/GraceHerchenroder/Thesis/main/mean_walk_flex.csv'
mean_walk_flex = pd.read_csv(url_mean_walk_flex, header = None)

print('Mean: Upper Thoracic')
result_mean_walk_flex_ut = statAnova_ut(mean_walk_flex)
print(result_mean_walk_flex_ut)
if result_mean_walk_flex_ut['PR(>F)'][0] < 0.05:
  print('Gender: Significant')
if result_mean_walk_flex_ut['PR(>F)'][1] < 0.05:
  print('Size: Significant')
if result_mean_walk_flex_ut['PR(>F)'][2] < 0.05:
  result = significant_ut(mean_walk_flex, result_mean_walk_flex_ut['PR(>F)'])
  print('Small: ', result[1], ', Large: ', result[2], ', Women: ', result[3], ', Men: ', result[4])
  if result[1] < result[0]:
    print('Small: Significant')
  if result[2] < result[0]:
    print('Large: Significant')
  if result[3] < result[0]:
    print('Women: Significant')
  if result[4] < result[0]:
    print('Men: Significant')
print('')

print('Mean: Lower Thoracic')
result_mean_walk_flex_lt = statAnova_lt(mean_walk_flex)
print(result_mean_walk_flex_lt)
if result_mean_walk_flex_lt['PR(>F)'][0] < 0.05:
  print('Gender: Significant')
if result_mean_walk_flex_lt['PR(>F)'][1] < 0.05:
  print('Size: Significant')
if result_mean_walk_flex_lt['PR(>F)'][2] < 0.05:
  result = significant_lt(mean_walk_flex, result_mean_walk_flex_lt['PR(>F)'])
  print('Small: ', result[1], ', Large: ', result[2], ', Women: ', result[3], ', Men: ', result[4])
  if result[1] < result[0]:
    print('Small: Significant')
  if result[2] < result[0]:
    print('Large: Significant')
  if result[3] < result[0]:
    print('Women: Significant')
  if result[4] < result[0]:
    print('Men: Significant')
print('')

print('Mean: Lumbar')
result_mean_walk_flex_lum = statAnova_lum(mean_walk_flex)
print(result_mean_walk_flex_lum)
if result_mean_walk_flex_lum['PR(>F)'][0] < 0.05:
  print('Gender: Significant')
if result_mean_walk_flex_lum['PR(>F)'][1] < 0.05:
  print('Size: Significant')
if result_mean_walk_flex_lum['PR(>F)'][2] < 0.05:
  result = significant_lum(mean_walk_flex, result_mean_walk_flex_lum['PR(>F)'])
  print('Small: ', result[1], ', Large: ', result[2], ', Women: ', result[3], ', Men: ', result[4])
  if result[1] < result[0]:
    print('Small: Significant')
  if result[2] < result[0]:
    print('Large: Significant')
  if result[3] < result[0]:
    print('Women: Significant')
  if result[4] < result[0]:
    print('Men: Significant')
print('')
# Out:
# Flexion
#
# Minimum: Upper Thoracic
# 0    24.370861
# 1    16.754343
# 2    21.655466
# Name: 0, dtype: float64
# 20.926890082444164 3.1518200161968575
# 3    29.944376
# 4     1.994364
# Name: 0, dtype: float64
# 15.96937017856355 13.975006317331749
# 5    14.186915
# 6    11.212140
# 7    21.655466
# Name: 0, dtype: float64
# 15.684840314895368 4.393070338360834
# 8     9.561691
# 9    15.201689
# Name: 0, dtype: float64
# 12.381690413958715 2.819999072384685
#   Gender   Size  Kinematic
# 0  women  small  24.370861
# 1  women  small  16.754343
# 2  women  small  21.655466
# 3  women  large  29.944376
# 4  women  large   1.994364
# 5    men  small  14.186915
# 6    men  small  11.212140
# 7    men  small  21.655466
# 8    men  large   9.561691
# 9    men  large  15.201689
#                        sum_sq   df         F    PR(>F)
# C(Gender)           52.447911  1.0  0.636754  0.455302
# C(Size)             40.943199  1.0  0.497079  0.507219
# C(Gender):C(Size)    1.642164  1.0  0.019937  0.892335
# Residual           494.205502  6.0       NaN       NaN
#
# Minimum: Lower Thoracic
# 0    21.617536
# 1    12.508242
# 2    28.732715
# Name: 1, dtype: float64
# 20.952830934663265 6.640268563363768
# 3    11.078065
# 4    14.574749
# Name: 1, dtype: float64
# 12.826406678704899 1.7483419444523003
# 5    16.111756
# 6     8.590743
# 7    28.732715
# Name: 1, dtype: float64
# 17.811737679982873 8.310323351194448
# 8    31.611173
# 9    19.110871
# Name: 1, dtype: float64
# 25.361022018884753 6.25015129376545
#   Gender   Size  Kinematic
# 0  women  small  21.617536
# 1  women  small  12.508242
# 2  women  small  28.732715
# 3  women  large  11.078065
# 4  women  large  14.574749
# 5    men  small  16.111756
# 6    men  small   8.590743
# 7    men  small  28.732715
# 8    men  large  31.611173
# 9    men  large  19.110871
#                        sum_sq   df         F    PR(>F)
# C(Gender)           24.479578  1.0  0.346649  0.577493
# C(Size)              0.199854  1.0  0.002830  0.959301
# C(Gender):C(Size)  147.436704  1.0  2.087816  0.198603
# Residual           423.706104  6.0       NaN       NaN
#
# Minimum: Lumbar
# 0   -34.951462
# 1    -2.089904
# 2   -25.261343
# Name: 2, dtype: float64
# -20.76756956201343 13.7868534494012
# 3   -26.882199
# 4   -12.659390
# Name: 2, dtype: float64
# -19.7707942277243 7.1114043783198
# 5   -25.995174
# 6   -25.522920
# 7   -25.261343
# Name: 2, dtype: float64
# -25.593145722030233 0.30367267649706453
# 8   -37.249287
# 9   -24.836445
# Name: 2, dtype: float64
# -31.04286558202825 6.20642096416605
#   Gender   Size  Kinematic
# 0  women  small -34.951462
# 1  women  small  -2.089904
# 2  women  small -25.261343
# 3  women  large -26.882199
# 4  women  large -12.659390
# 5    men  small -25.995174
# 6    men  small -25.522920
# 7    men  small -25.261343
# 8    men  large -37.249287
# 9    men  large -24.836445
#                        sum_sq   df         F    PR(>F)
# C(Gender)          137.054490  1.0  1.098351  0.334998
# C(Size)             11.897229  1.0  0.095344  0.767931
# C(Gender):C(Size)   24.934380  1.0  0.199824  0.670547
# Residual           748.692102  6.0       NaN       NaN
#
# Maximum: Upper Thoracic
# 0    25.452085
# 1    17.432824
# 2    22.640781
# Name: 0, dtype: float64
# 21.841896432706033 3.3222281999158554
# 3    30.802793
# 4     3.173644
# Name: 0, dtype: float64
# 16.98821841273033 13.81457431936947
# 5    15.304037
# 6    11.796781
# 7    22.640781
# Name: 0, dtype: float64
# 16.580532806360367 4.518123846117208
# 8     9.800314
# 9    16.982425
# Name: 0, dtype: float64
# 13.391369420650285 3.591055204705615
#   Gender   Size  Kinematic
# 0  women  small  25.452085
# 1  women  small  17.432824
# 2  women  small  22.640781
# 3  women  large  30.802793
# 4  women  large   3.173644
# 5    men  small  15.304037
# 6    men  small  11.796781
# 7    men  small  22.640781
# 8    men  large   9.800314
# 9    men  large  16.982425
#                        sum_sq   df         F    PR(>F)
# C(Gender)           52.797878  1.0  0.631266  0.457158
# C(Size)             38.812379  1.0  0.464052  0.521146
# C(Gender):C(Size)    1.662365  1.0  0.019876  0.892499
# Residual           501.828212  6.0       NaN       NaN
#
# Maximum: Lower Thoracic
# 0    23.318346
# 1    13.260614
# 2    29.365934
# Name: 1, dtype: float64
# 21.981631553109604 6.64256170294826
# 3    11.980655
# 4    16.059320
# Name: 1, dtype: float64
# 14.019987319345699 2.0393325464250003
# 5    17.094541
# 6     9.212941
# 7    29.365934
# Name: 1, dtype: float64
# 18.55780550495787 8.292230917821177
# 8    32.160972
# 9    20.634112
# Name: 1, dtype: float64
# 26.397542148996948 5.763429839193348
#   Gender   Size  Kinematic
# 0  women  small  23.318346
# 1  women  small  13.260614
# 2  women  small  29.365934
# 3  women  large  11.980655
# 4  women  large  16.059320
# 5    men  small  17.094541
# 6    men  small   9.212941
# 7    men  small  29.365934
# 8    men  large  32.160972
# 9    men  large  20.634112
#                        sum_sq   df         F    PR(>F)
# C(Gender)           20.977558  1.0  0.304459  0.601031
# C(Size)              0.008917  1.0  0.000129  0.991292
# C(Gender):C(Size)  149.810183  1.0  2.174281  0.190777
# Residual           413.406160  6.0       NaN       NaN
#
# Maximum: Lumbar
# 0   -28.144778
# 1     0.429795
# 2   -22.742638
# Name: 2, dtype: float64
# -16.819207100054257 12.39467160388944
# 3   -23.490218
# 4    -8.885168
# Name: 2, dtype: float64
# -16.18769329275091 7.302524949005691
# 5   -22.759107
# 6   -22.114935
# 7   -22.742638
# Name: 2, dtype: float64
# -22.538893074372435 0.2998593087718353
# 8   -36.142039
# 9   -22.129881
# Name: 2, dtype: float64
# -29.135959908886853 7.00607928972145
#   Gender   Size  Kinematic
# 0  women  small -28.144778
# 1  women  small   0.429795
# 2  women  small -22.742638
# 3  women  large -23.490218
# 4  women  large  -8.885168
# 5    men  small -22.759107
# 6    men  small -22.114935
# 7    men  small -22.742638
# 8    men  large -36.142039
# 9    men  large -22.129881
#                        sum_sq   df         F    PR(>F)
# C(Gender)          185.378393  1.0  1.670132  0.243778
# C(Size)             21.352694  1.0  0.192373  0.676301
# C(Gender):C(Size)   31.351427  1.0  0.282455  0.614188
# Residual           665.977435  6.0       NaN       NaN
#
# Mean: Upper Thoracic
# 0    24.942052
# 1    17.153884
# 2    22.050574
# Name: 0, dtype: float64
# 21.382169846843833 3.214442656182922
# 3    30.43703
# 4     2.49831
# Name: 0, dtype: float64
# 16.46766966803644 13.96936006982896
# 5    14.834688
# 6    11.465964
# 7    22.050574
# Name: 0, dtype: float64
# 16.117075405558236 4.415267501074423
# 8     9.701845
# 9    16.279929
# Name: 0, dtype: float64
# 12.990886894669995 3.289041825229905
#   Gender   Size  Kinematic
# 0  women  small  24.942052
# 1  women  small  17.153884
# 2  women  small  22.050574
# 3  women  large  30.437030
# 4  women  large   2.498310
# 5    men  small  14.834688
# 6    men  small  11.465964
# 7    men  small  22.050574
# 8    men  large   9.701845
# 9    men  large  16.279929
#                        sum_sq   df         F    PR(>F)
# C(Gender)           51.751012  1.0  0.619274  0.461261
# C(Size)             38.791605  1.0  0.464196  0.521084
# C(Gender):C(Size)    1.918835  1.0  0.022962  0.884524
# Residual           501.403320  6.0       NaN       NaN
#
# Mean: Lower Thoracic
# 0    22.450254
# 1    12.931312
# 2    29.162151
# Name: 1, dtype: float64
# 21.514572320982435 6.6591619117063585
# 3    11.504897
# 4    15.541343
# Name: 1, dtype: float64
# 13.5231198652763 2.0182233503463998
# 5    16.560017
# 6     8.903324
# 7    29.162151
# Name: 1, dtype: float64
# 18.208496953294688 8.352370185722942
# 8    31.888580
# 9    19.825099
# Name: 1, dtype: float64
# 25.856839069001552 6.0317405508589506
#   Gender   Size  Kinematic
# 0  women  small  22.450254
# 1  women  small  12.931312
# 2  women  small  29.162151
# 3  women  large  11.504897
# 4  women  large  15.541343
# 5    men  small  16.560017
# 6    men  small   8.903324
# 7    men  small  29.162151
# 8    men  large  31.888580
# 9    men  large  19.825099
#                        sum_sq   df         F    PR(>F)
# C(Gender)           21.753926  1.0  0.308399  0.598743
# C(Size)              0.070635  1.0  0.001001  0.975782
# C(Gender):C(Size)  146.761905  1.0  2.080599  0.199277
# Residual           423.229814  6.0       NaN       NaN
#
# Mean: Lumbar
# 0   -31.540925
# 1    -0.838223
# 2   -24.027813
# Name: 2, dtype: float64
# -18.80232050760635 13.067601505958011
# 3   -25.137641
# 4   -10.523285
# Name: 2, dtype: float64
# -17.83046286514675 7.30717787215035
# 5   -24.575584
# 6   -23.850262
# 7   -24.027813
# Name: 2, dtype: float64
# -24.1512198134596 0.3087017851811161
# 8   -36.735319
# 9   -23.429426
# Name: 2, dtype: float64
# -30.0823726459969 6.652946394301001
#   Gender   Size  Kinematic
# 0  women  small -31.540925
# 1  women  small  -0.838223
# 2  women  small -24.027813
# 3  women  large -25.137641
# 4  women  large -10.523285
# 5    men  small -24.575584
# 6    men  small -23.850262
# 7    men  small -24.027813
# 8    men  large -36.735319
# 9    men  large -23.429426
#                        sum_sq   df         F    PR(>F)
# C(Gender)          164.434447  1.0  1.393737  0.282451
# C(Size)             14.756765  1.0  0.125078  0.735687
# C(Gender):C(Size)   28.590932  1.0  0.242335  0.640017
# Residual           707.885606  6.0       NaN       NaN

# %%
diff_walk_flex = pd.read_csv(url_max_walk_flex, header = None) - pd.read_csv(url_min_walk_flex, header = None)

print('Difference: Upper Thoracic')
result_diff_walk_flex_ut = statAnova_ut(diff_walk_flex)
print(result_diff_walk_flex_ut)
if result_diff_walk_flex_ut['PR(>F)'][0] < 0.05:
  print('Gender: Significant')
if result_diff_walk_flex_ut['PR(>F)'][1] < 0.05:
  print('Size: Significant')
if result_diff_walk_flex_ut['PR(>F)'][2] < 0.05:
  result = significant_ut(diff_walk_flex, result_diff_walk_flex_ut['PR(>F)'])
  print('Small: ', result[1], ', Large: ', result[2], ', Women: ', result[3], ', Men: ', result[4])
  if result[0] < 0.05:
    print('Small: Significant')
  if result[1] < 0.05:
    print('Large: Significant')
  if result[2] < 0.05:
    print('Women: Significant')
  if result[3] < 0.05:
    print('Men: Significant')
print('')

print('Difference: Lower Thoracic')
result_diff_walk_flex_lt = statAnova_lt(diff_walk_flex)
print(result_diff_walk_flex_lt)
if result_diff_walk_flex_lt['PR(>F)'][0] < 0.05:
  print('Gender: Significant')
if result_diff_walk_flex_lt['PR(>F)'][1] < 0.05:
  print('Size: Significant')
if result_diff_walk_flex_lt['PR(>F)'][2] < 0.05:
  result = significant_lt(diff_walk_flex, result_diff_walk_flex_lt['PR(>F)'])
  print('Small: ', result[1], ', Large: ', result[2], ', Women: ', result[3], ', Men: ', result[4])
  if result[0] < 0.05:
    print('Small: Significant')
  if result[1] < 0.05:
    print('Large: Significant')
  if result[2] < 0.05:
    print('Women: Significant')
  if result[3] < 0.05:
    print('Men: Significant')
print('')

print('Difference: Lumbar')
result_diff_walk_flex_lum = statAnova_lum(diff_walk_flex)
print(result_diff_walk_flex_lum)
if result_diff_walk_flex_lum['PR(>F)'][0] < 0.05:
  print('Gender: Significant')
if result_diff_walk_flex_lum['PR(>F)'][1] < 0.05:
  print('Size: Significant')
if result_diff_walk_flex_lum['PR(>F)'][2] < 0.05:
  result = significant_lum(diff_walk_flex, result_diff_walk_flex_lum['PR(>F)'])
  print('Small: ', result[0], ', Large: ', result[1], ', Women: ', result[2], ', Men: ', result[3])
  if result[0] < 0.05:
    print('Small: Significant')
  if result[1] < 0.05:
    print('Large: Significant')
  if result[2] < 0.05:
    print('Women: Significant')
  if result[3] < 0.05:
    print('Men: Significant')
print('')
# Out:
# Difference: Upper Thoracic
# 0    1.081224
# 1    0.678481
# 2    0.985315
# Name: 0, dtype: float64
# 0.915006350261868 0.17177113776261355
# 3    0.858416
# 4    1.179280
# Name: 0, dtype: float64
# 1.0188482341667806 0.16043199796227925
# 5    1.117122
# 6    0.584641
# 7    0.985315
# Name: 0, dtype: float64
# 0.8956924914650001 0.2264332548479423
# 8    0.238623
# 9    1.780735
# Name: 0, dtype: float64
# 1.009679006691571 0.77105613232093
#   Gender   Size  Kinematic
# 0  women  small   1.081224
# 1  women  small   0.678481
# 2  women  small   0.985315
# 3  women  large   0.858416
# 4  women  large   1.179280
# 5    men  small   1.117122
# 6    men  small   0.584641
# 7    men  small   0.985315
# 8    men  large   0.238623
# 9    men  large   1.780735
#                      sum_sq   df         F    PR(>F)
# C(Gender)          0.000582  1.0  0.002354  0.962875
# C(Size)            0.028470  1.0  0.115194  0.745871
# C(Gender):C(Size)  0.000062  1.0  0.000250  0.987901
# Residual           1.482864  6.0       NaN       NaN
#
# Difference: Lower Thoracic
# 0    1.700810
# 1    0.752372
# 2    0.633220
# Name: 1, dtype: float64
# 1.0288006184463327 0.4776660054744673
# 3    0.902590
# 4    1.484571
# Name: 1, dtype: float64
# 1.1935806406407998 0.2909906019727
# 5    0.982786
# 6    0.622198
# 7    0.633220
# Name: 1, dtype: float64
# 0.7460678249749998 0.16744522891185706
# 8    0.549799
# 9    1.523242
# Name: 1, dtype: float64
# 1.0365201301121978 0.4867214545721019
#   Gender   Size  Kinematic
# 0  women  small   1.700810
# 1  women  small   0.752372
# 2  women  small   0.633220
# 3  women  large   0.902590
# 4  women  large   1.484571
# 5    men  small   0.982786
# 6    men  small   0.622198
# 7    men  small   0.633220
# 8    men  large   0.549799
# 9    men  large   1.523242
#                      sum_sq   df         F    PR(>F)
# C(Gender)          0.135099  1.0  0.574173  0.477300
# C(Size)            0.124342  1.0  0.528457  0.494630
# C(Gender):C(Size)  0.009476  1.0  0.040274  0.847576
# Residual           1.411755  6.0       NaN       NaN
#
# Difference: Lumbar
# 0    6.806683
# 1    2.519699
# 2    2.518705
# Name: 2, dtype: float64
# 3.948362461959173 2.021138073802185
# 3    3.391980
# 4    3.774222
# Name: 2, dtype: float64
# 3.5831009349733893 0.19112057068589117
# 5    3.236067
# 6    3.407985
# 7    2.518705
# Name: 2, dtype: float64
# 3.0542526476578 0.38513811505362094
# 8    1.107247
# 9    2.706564
# Name: 2, dtype: float64
# 1.906905673141397 0.7996583255554004
#   Gender   Size  Kinematic
# 0  women  small   6.806683
# 1  women  small   2.519699
# 2  women  small   2.518705
# 3  women  large   3.391980
# 4  women  large   3.774222
# 5    men  small   3.236067
# 6    men  small   3.407985
# 7    men  small   2.518705
# 8    men  large   1.107247
# 9    men  large   2.706564
#                       sum_sq   df         F    PR(>F)
# C(Gender)           3.641785  1.0  1.554994  0.258869
# C(Size)             1.372791  1.0  0.586164  0.472939
# C(Gender):C(Size)   0.366995  1.0  0.156702  0.705904
# Residual           14.051952  6.0       NaN       NaN

# %%
print('Mean')
box_whisker(mean_walk_flex)
print('Min')
box_whisker(min_walk_flex)
print('Max')
box_whisker(max_walk_flex)
# Out:
# Mean
# Min
# Max

# %%
# Lateral Flexion
print('\033[1mLateral Flexion\033[0m')
print('')

# Minimums
url_min_walk_lat = 'https://raw.githubusercontent.com/GraceHerchenroder/Thesis/main/min_walk_lat.csv'
min_walk_lat = pd.read_csv(url_min_walk_lat, header = None)

print('Minimum: Upper Thoracic')
result_min_walk_lat_ut = statAnova_ut(min_walk_lat)
print(result_min_walk_lat_ut)
if result_min_walk_lat_ut['PR(>F)'][2] < 0.05:
  result = significant_ut(min_walk_lat, result_min_walk_lat_ut['PR(>F)'])
  print('Small: ', result[1], ', Large: ', result[2], ', Women: ', result[3], ', Men: ', result[4])
  if result[1] < result[0]:
    print('Small: Significant')
  if result[2] < result[0]:
    print('Large: Significant')
  if result[3] < result[0]:
    print('Women: Significant')
  if result[4] < result[0]:
    print('Men: Significant')
print('')

print('Minimum: Lower Thoracic')
result_min_walk_lat_lt = statAnova_lt(min_walk_lat)
print(result_min_walk_lat_lt)
if result_min_walk_lat_lt['PR(>F)'][2] < 0.05:
  result = significant_lt(min_walk_lat, result_min_walk_lat_lt['PR(>F)'])
  print('Small: ', result[1], ', Large: ', result[2], ', Women: ', result[3], ', Men: ', result[4])
  if result[1] < result[0]:
    print('Small: Significant')
  if result[2] < result[0]:
    print('Large: Significant')
  if result[3] < result[0]:
    print('Women: Significant')
  if result[4] < result[0]:
    print('Men: Significant')
print('')

print('Minimum: Lumbar')
result_min_walk_lat_lum = statAnova_lum(min_walk_lat)
print(result_min_walk_lat_lum)
if result_min_walk_lat_lum['PR(>F)'][2] < 0.05:
  result = significant_lum(min_walk_lat, result_min_walk_lat_lum['PR(>F)'])
  print('Small: ', result[1], ', Large: ', result[2], ', Women: ', result[3], ', Men: ', result[4])
  if result[1] < result[0]:
    print('Small: Significant')
  if result[2] < result[0]:
    print('Large: Significant')
  if result[3] < result[0]:
    print('Women: Significant')
  if result[4] < result[0]:
    print('Men: Significant')
print('')

# Maximums
url_max_walk_lat = 'https://raw.githubusercontent.com/GraceHerchenroder/Thesis/main/max_walk_lat.csv'
max_walk_lat = pd.read_csv(url_max_walk_lat, header = None)

print('Maximum: Upper Thoracic')
result_max_walk_lat_ut = statAnova_ut(max_walk_lat)
print(result_max_walk_lat_ut)
if result_max_walk_lat_ut['PR(>F)'][2] < 0.05:
  result = significant_ut(max_walk_lat, result_max_walk_lat_ut['PR(>F)'])
  print('Small: ', result[1], ', Large: ', result[2], ', Women: ', result[3], ', Men: ', result[4])
  if result[1] < result[0]:
    print('Small: Significant')
  if result[2] < result[0]:
    print('Large: Significant')
  if result[3] < result[0]:
    print('Women: Significant')
  if result[4] < result[0]:
    print('Men: Significant')
print('')

print('Maximum: Lower Thoracic')
result_max_walk_lat_lt = statAnova_lt(max_walk_lat)
print(result_max_walk_lat_lt)
if result_max_walk_lat_lt['PR(>F)'][2] < 0.05:
  result = significant_lt(max_walk_lat, result_max_walk_lat_lt['PR(>F)'])
  print('Small: ', result[1], ', Large: ', result[2], ', Women: ', result[3], ', Men: ', result[4])
  if result[1] < result[0]:
    print('Small: Significant')
  if result[2] < result[0]:
    print('Large: Significant')
  if result[3] < result[0]:
    print('Women: Significant')
  if result[4] < result[0]:
    print('Men: Significant')
print('')

print('Maximum: Lumbar')
result_max_walk_lat_lum = statAnova_lum(max_walk_lat)
print(result_max_walk_lat_lum)
if result_max_walk_lat_lum['PR(>F)'][2] < 0.05:
  result = significant_lum(max_walk_lat, result_max_walk_lat_lum['PR(>F)'])
  print('Small: ', result[1], ', Large: ', result[2], ', Women: ', result[3], ', Men: ', result[4])
  if result[1] < result[0]:
    print('Small: Significant')
  if result[2] < result[0]:
    print('Large: Significant')
  if result[3] < result[0]:
    print('Women: Significant')
  if result[4] < result[0]:
    print('Men: Significant')
print('')

# Means
url_mean_walk_lat = 'https://raw.githubusercontent.com/GraceHerchenroder/Thesis/main/mean_walk_lat.csv'
mean_walk_lat = pd.read_csv(url_mean_walk_lat, header = None)

print('Mean: Upper Thoracic')
result_mean_walk_lat_ut = statAnova_ut(mean_walk_lat)
print(result_mean_walk_lat_ut)
if result_mean_walk_flex_ut['PR(>F)'][2] < 0.05:
  result = significant_ut(mean_walk_lat, result_mean_walk_lat_ut['PR(>F)'])
  print('Small: ', result[1], ', Large: ', result[2], ', Women: ', result[3], ', Men: ', result[4])
  if result[1] < result[0]:
    print('Small: Significant')
  if result[2] < result[0]:
    print('Large: Significant')
  if result[3] < result[0]:
    print('Women: Significant')
  if result[4] < result[0]:
    print('Men: Significant')
print('')

print('Mean: Lower Thoracic')
result_mean_walk_lat_lt = statAnova_lt(mean_walk_lat)
print(result_mean_walk_lat_lt)
if result_mean_walk_lat_lt['PR(>F)'][2] < 0.05:
  result = significant_lt(mean_walk_lat, result_mean_walk_lat_lt['PR(>F)'])
  print('Small: ', result[1], ', Large: ', result[2], ', Women: ', result[3], ', Men: ', result[4])
  if result[1] < result[0]:
    print('Small: Significant')
  if result[2] < result[0]:
    print('Large: Significant')
  if result[3] < result[0]:
    print('Women: Significant')
  if result[4] < result[0]:
    print('Men: Significant')
print('')

print('Mean: Lumbar')
result_mean_walk_lat_lum = statAnova_lum(mean_walk_lat)
print(result_mean_walk_lat_lum)
if result_mean_walk_lat_lum['PR(>F)'][2] < 0.05:
  result = significant_lum(mean_walk_lat, result_mean_walk_lat_lum['PR(>F)'])
  print('Small: ', result[1], ', Large: ', result[2], ', Women: ', result[3], ', Men: ', result[4])
  if result[1] < result[0]:
    print('Small: Significant')
  if result[2] < result[0]:
    print('Large: Significant')
  if result[3] < result[0]:
    print('Women: Significant')
  if result[4] < result[0]:
    print('Men: Significant')
print('')
# Out:
# Lateral Flexion
#
# Minimum: Upper Thoracic
# 0    2.921275
# 1    0.589405
# 2    4.247871
# Name: 0, dtype: float64
# 2.5861840225241424 1.512240677678248
# 3    5.119119
# 4    0.914037
# Name: 0, dtype: float64
# 3.0165780910383018 2.102541232494868
# 5    0.580979
# 6    0.809295
# 7    4.247871
# Name: 0, dtype: float64
# 1.8793818161588256 1.67736676906006
# 8    0.520826
# 9    3.275026
# Name: 0, dtype: float64
# 1.897925983930336 1.377100277073334
#   Gender   Size  Kinematic
# 0  women  small   2.921275
# 1  women  small   0.589405
# 2  women  small   4.247871
# 3  women  large   5.119119
# 4  women  large   0.914037
# 5    men  small   0.580979
# 6    men  small   0.809295
# 7    men  small   4.247871
# 8    men  large   0.520826
# 9    men  large   3.275026
#                       sum_sq   df         F    PR(>F)
# C(Gender)           1.898964  1.0  0.407861  0.546646
# C(Size)             0.120927  1.0  0.025973  0.877256
# C(Gender):C(Size)   0.101772  1.0  0.021859  0.887307
# Residual           27.935463  6.0       NaN       NaN
#
# Minimum: Lower Thoracic
# 0    1.862279
# 1    2.921554
# 2    0.824315
# Name: 1, dtype: float64
# 1.8693827273408143 0.8562088820975868
# 3    0.384508
# 4    2.585517
# Name: 1, dtype: float64
# 1.485012393773382 1.100504563627678
# 5    2.525598
# 6    3.963757
# 7    0.824315
# Name: 1, dtype: float64
# 2.4378898694850277 1.2831714332872612
# 8    4.468800
# 9    1.013493
# Name: 1, dtype: float64
# 2.74114661711418 1.7276536965742197
#   Gender   Size  Kinematic
# 0  women  small   1.862279
# 1  women  small   2.921554
# 2  women  small   0.824315
# 3  women  large   0.384508
# 4  women  large   2.585517
# 5    men  small   2.525598
# 6    men  small   3.963757
# 7    men  small   0.824315
# 8    men  large   4.468800
# 9    men  large   1.013493
#                       sum_sq   df         F    PR(>F)
# C(Gender)           1.778975  1.0  0.687276  0.438821
# C(Size)             0.003948  1.0  0.001525  0.970115
# C(Gender):C(Size)   0.283699  1.0  0.109602  0.751854
# Residual           15.530663  6.0       NaN       NaN
#
# Minimum: Lumbar
# 0    2.598203
# 1    0.338122
# 2    2.692824
# Name: 2, dtype: float64
# 1.8763828540007108 1.0884005176549254
# 3    0.286887
# 4    1.202851
# Name: 2, dtype: float64
# 0.7448690594399435 0.45798167189144656
# 5    2.053601
# 6    4.465525
# 7    2.692824
# Name: 2, dtype: float64
# 3.0706498999955696 1.0202641134722112
# 8    6.881475
# 9    1.481376
# Name: 2, dtype: float64
# 4.181425359635875 2.7000495366043253
#   Gender   Size  Kinematic
# 0  women  small   2.598203
# 1  women  small   0.338122
# 2  women  small   2.692824
# 3  women  large   0.286887
# 4  women  large   1.202851
# 5    men  small   2.053601
# 6    men  small   4.465525
# 7    men  small   2.692824
# 8    men  large   6.881475
# 9    men  large   1.481376
#                       sum_sq   df         F    PR(>F)
# C(Gender)          10.932613  1.0  3.026093  0.132590
# C(Size)             0.000258  1.0  0.000071  0.993531
# C(Gender):C(Size)   3.016717  1.0  0.835012  0.396062
# Residual           21.676693  6.0       NaN       NaN
#
# Maximum: Upper Thoracic
# 0    4.254434
# 1    2.118872
# 2    6.571207
# Name: 0, dtype: float64
# 4.314837714816483 1.8181602371193073
# 3    7.015478
# 4    5.259685
# Name: 0, dtype: float64
# 6.13758181569985 0.87789654135192
# 5    2.971943
# 6    1.830466
# 7    6.571207
# Name: 0, dtype: float64
# 3.79120540350289 2.0202394219713944
# 8    1.402797
# 9    7.851863
# Name: 0, dtype: float64
# 4.62732992905057 3.22453277303712
#   Gender   Size  Kinematic
# 0  women  small   4.254434
# 1  women  small   2.118872
# 2  women  small   6.571207
# 3  women  large   7.015478
# 4  women  large   5.259685
# 5    men  small   2.971943
# 6    men  small   1.830466
# 7    men  small   6.571207
# 8    men  large   1.402797
# 9    men  large   7.851863
#                       sum_sq   df         F    PR(>F)
# C(Gender)           2.108096  1.0  0.284251  0.613089
# C(Size)             4.241749  1.0  0.571949  0.478118
# C(Gender):C(Size)   0.584051  1.0  0.078752  0.788421
# Residual           44.497850  6.0       NaN       NaN
#
# Maximum: Lower Thoracic
# 0    9.304656
# 1    9.100211
# 2    3.519692
# Name: 1, dtype: float64
# 7.308186533511118 2.6801698986155107
# 3     5.974888
# 4    10.369370
# Name: 1, dtype: float64
# 8.172128794923275 2.197240830064925
# 5    6.968492
# 6    8.110239
# 7    3.519692
# Name: 1, dtype: float64
# 6.199474390927507 1.9513791361114832
# 8    6.178586
# 9    6.529166
# Name: 1, dtype: float64
# 6.35387588202423 0.1752896701164497
#   Gender   Size  Kinematic
# 0  women  small   9.304656
# 1  women  small   9.100211
# 2  women  small   3.519692
# 3  women  large   5.974888
# 4  women  large  10.369370
# 5    men  small   6.968492
# 6    men  small   8.110239
# 7    men  small   3.519692
# 8    men  large   6.178586
# 9    men  large   6.529166
#                       sum_sq   df         F    PR(>F)
# C(Gender)           4.847839  1.0  0.681343  0.440702
# C(Size)             0.622214  1.0  0.087450  0.777412
# C(Gender):C(Size)   0.302069  1.0  0.042454  0.843569
# Residual           42.690761  6.0       NaN       NaN
#
# Maximum: Lumbar
# 0    10.661570
# 1     4.563583
# 2     9.006103
# Name: 2, dtype: float64
# 8.07708545202135 2.5747062664367686
# 3    11.843777
# 4     6.266887
# Name: 2, dtype: float64
# 9.0553323137235 2.7884448339504004
# 5    10.137839
# 6    13.499516
# 7     9.006103
# Name: 2, dtype: float64
# 10.881152628619612 1.9082409209229971
# 8     9.888150
# 9    12.072154
# Name: 2, dtype: float64
# 10.980152019294689 1.0920020173315104
#   Gender   Size  Kinematic
# 0  women  small  10.661570
# 1  women  small   4.563583
# 2  women  small   9.006103
# 3  women  large  11.843777
# 4  women  large   6.266887
# 5    men  small  10.137839
# 6    men  small  13.499516
# 7    men  small   9.006103
# 8    men  large   9.888150
# 9    men  large  12.072154
#                       sum_sq   df         F    PR(>F)
# C(Gender)          15.035274  1.0  1.850599  0.222600
# C(Size)             0.696276  1.0  0.085700  0.779576
# C(Gender):C(Size)   0.463846  1.0  0.057092  0.819105
# Residual           48.747273  6.0       NaN       NaN
#
# Mean: Upper Thoracic
# 0    3.473242
# 1    1.306807
# 2    5.337405
# Name: 0, dtype: float64
# 3.372484508148157 1.6470267153995402
# 3    6.100415
# 4    3.493083
# Name: 0, dtype: float64
# 4.796748656960845 1.3036659535435549
# 5    1.350428
# 6    1.107395
# 7    5.337405
# Name: 0, dtype: float64
# 2.5984092807755967 1.9393023375528058
# 8    0.880624
# 9    5.529811
# Name: 0, dtype: float64
# 3.205217733733055 2.324593259740835
#   Gender   Size  Kinematic
# 0  women  small   3.473242
# 1  women  small   1.306807
# 2  women  small   5.337405
# 3  women  large   6.100415
# 4  women  large   3.493083
# 5    men  small   1.350428
# 6    men  small   1.107395
# 7    men  small   5.337405
# 8    men  large   0.880624
# 9    men  large   5.529811
#                       sum_sq   df         F    PR(>F)
# C(Gender)           3.030819  1.0  0.540778  0.489846
# C(Size)             2.475154  1.0  0.441632  0.531032
# C(Gender):C(Size)   0.400940  1.0  0.071538  0.798066
# Residual           33.627329  6.0       NaN       NaN
#
# Mean: Lower Thoracic
# 0    5.487680
# 1    5.598982
# 2    2.052462
# Name: 1, dtype: float64
# 4.379708157195116 1.6462389285939796
# 3    2.845868
# 4    6.186504
# Name: 1, dtype: float64
# 4.516185745975751 1.6703179309395702
# 5    4.656139
# 6    6.160746
# 7    2.052462
# Name: 1, dtype: float64
# 4.289782071731383 1.6970881272985767
# 8    5.296999
# 9    3.662187
# Name: 1, dtype: float64
# 4.47959281337063 0.8174060179216198
#   Gender   Size  Kinematic
# 0  women  small   5.487680
# 1  women  small   5.598982
# 2  women  small   2.052462
# 3  women  large   2.845868
# 4  women  large   6.186504
# 5    men  small   4.656139
# 6    men  small   6.160746
# 7    men  small   2.052462
# 8    men  large   5.296999
# 9    men  large   3.662187
#                       sum_sq   df         F    PR(>F)
# C(Gender)           0.011762  1.0  0.002979  0.958242
# C(Size)             0.063878  1.0  0.016181  0.902935
# C(Gender):C(Size)   0.001707  1.0  0.000432  0.984086
# Residual           23.686861  6.0       NaN       NaN
#
# Mean: Lumbar
# 0    6.048426
# 1    2.267094
# 2    6.755086
# Name: 2, dtype: float64
# 5.02353550030962 1.9703329593667236
# 3    5.993455
# 4    3.759088
# Name: 2, dtype: float64
# 4.876271448024751 1.1171834960514402
# 5    4.795684
# 6    8.366643
# 7    6.755086
# Name: 2, dtype: float64
# 6.639137530499291 1.4601416327447168
# 8    8.432904
# 9    6.312330
# Name: 2, dtype: float64
# 7.37261656093772 1.0602870296208504
#   Gender   Size  Kinematic
# 0  women  small   6.048426
# 1  women  small   2.267094
# 2  women  small   6.755086
# 3  women  large   5.993455
# 4  women  large   3.759088
# 5    men  small   4.795684
# 6    men  small   8.366643
# 7    men  small   6.755086
# 8    men  large   8.432904
# 9    men  large   6.312330
#                       sum_sq   df         F    PR(>F)
# C(Gender)           9.681569  1.0  2.549202  0.161463
# C(Size)             0.206189  1.0  0.054290  0.823504
# C(Gender):C(Size)   0.465425  1.0  0.122549  0.738248
# Residual           22.787292  6.0       NaN       NaN

# %%
print('Mean')
box_whisker(mean_walk_lat)
print('Min')
box_whisker(min_walk_lat)
print('Max')
box_whisker(max_walk_lat)
# Out:
# Mean

# %%
# Axial Flexion
# Flexion
print('\033[1mAxial Flexion\033[0m')
print('')

# Minimums
url_min_walk_axi = 'https://raw.githubusercontent.com/GraceHerchenroder/Thesis/main/min_walk_axi.csv'
min_walk_axi = pd.read_csv(url_min_walk_axi, header = None)

print('Minimum: Upper Thoracic')
result_min_walk_axi_ut = statAnova_ut(min_walk_axi)
print(result_min_walk_axi_ut)
if result_min_walk_axi_ut['PR(>F)'][2] < 0.05:
  result = significant_ut(min_walk_axi, result_min_walk_axi_ut['PR(>F)'])
  print('Small: ', result[1], ', Large: ', result[2], ', Women: ', result[3], ', Men: ', result[4])
  if result[1] < result[0]:
    print('Small: Significant')
  if result[2] < result[0]:
    print('Large: Significant')
  if result[3] < result[0]:
    print('Women: Significant')
  if result[4] < result[0]:
    print('Men: Significant')
print('')

print('Minimum: Lower Thoracic')
result_min_walk_axi_lt = statAnova_lt(min_walk_axi)
print(result_min_walk_axi_lt)
if result_min_walk_axi_lt['PR(>F)'][2] < 0.05:
  result = significant_lt(min_walk_axi, result_min_walk_axi_lt['PR(>F)'])
  print('Small: ', result[1], ', Large: ', result[2], ', Women: ', result[3], ', Men: ', result[4])
  if result[1] < result[0]:
    print('Small: Significant')
  if result[2] < result[0]:
    print('Large: Significant')
  if result[3] < result[0]:
    print('Women: Significant')
  if result[4] < result[0]:
    print('Men: Significant')
print('')

print('Minimum: Lumbar')
result_min_walk_axi_lum = statAnova_lum(min_walk_axi)
print(result_min_walk_axi_lum)
if result_min_walk_axi_lum['PR(>F)'][2] < 0.05:
  result = significant_lum(min_walk_axi, result_min_walk_axi_lum['PR(>F)'])
  print('Small: ', result[1], ', Large: ', result[2], ', Women: ', result[3], ', Men: ', result[4])
  if result[1] < result[0]:
    print('Small: Significant')
  if result[2] < result[0]:
    print('Large: Significant')
  if result[3] < result[0]:
    print('Women: Significant')
  if result[4] < result[0]:
    print('Men: Significant')
print('')

# Maximums
url_max_walk_axi = 'https://raw.githubusercontent.com/GraceHerchenroder/Thesis/main/max_walk_axi.csv'
max_walk_axi = pd.read_csv(url_max_walk_axi, header = None)

print('Maximum: Upper Thoracic')
result_max_walk_axi_ut = statAnova_ut(max_walk_axi)
print(result_max_walk_axi_ut)
if result_max_walk_axi_ut['PR(>F)'][2] < 0.05:
  result = significant_ut(max_walk_axi, result_max_walk_axi_ut['PR(>F)'])
  print('Small: ', result[1], ', Large: ', result[2], ', Women: ', result[3], ', Men: ', result[4])
  if result[1] < result[0]:
    print('Small: Significant')
  if result[2] < result[0]:
    print('Large: Significant')
  if result[3] < result[0]:
    print('Women: Significant')
  if result[4] < result[0]:
    print('Men: Significant')
print('')

print('Maximum: Lower Thoracic')
result_max_walk_axi_lt = statAnova_lt(max_walk_axi)
print(result_max_walk_axi_lt)
if result_max_walk_axi_lt['PR(>F)'][2] < 0.05:
  result = significant_lt(max_walk_axi, result_max_walk_axi_lt['PR(>F)'])
  print('Small: ', result[1], ', Large: ', result[2], ', Women: ', result[3], ', Men: ', result[4])
  if result[1] < result[0]:
    print('Small: Significant')
  if result[2] < result[0]:
    print('Large: Significant')
  if result[3] < result[0]:
    print('Women: Significant')
  if result[4] < result[0]:
    print('Men: Significant')
print('')

print('Maximum: Lumbar')
result_max_walk_axi_lum = statAnova_lum(max_walk_axi)
print(result_max_walk_axi_lum)
if result_max_walk_axi_lum['PR(>F)'][2] < 0.05:
  result = significant_lum(max_walk_axi, result_max_walk_axi_lum['PR(>F)'])
  print('Small: ', result[1], ', Large: ', result[2], ', Women: ', result[3], ', Men: ', result[4])
  if result[1] < result[0]:
    print('Small: Significant')
  if result[2] < result[0]:
    print('Large: Significant')
  if result[3] < result[0]:
    print('Women: Significant')
  if result[4] < result[0]:
    print('Men: Significant')
print('')

# Means
url_mean_walk_axi = 'https://raw.githubusercontent.com/GraceHerchenroder/Thesis/main/mean_walk_axi.csv'
mean_walk_axi = pd.read_csv(url_mean_walk_axi, header = None)

print('Mean: Upper Thoracic')
result_mean_walk_axi_ut = statAnova_ut(mean_walk_axi)
print(result_mean_walk_axi_ut)
if result_mean_walk_axi_ut['PR(>F)'][2] < 0.05:
  result = significant_ut(mean_walk_axi, result_mean_walk_axi_ut['PR(>F)'])
  print('Small: ', result[1], ', Large: ', result[2], ', Women: ', result[3], ', Men: ', result[4])
  if result[1] < result[0]:
    print('Small: Significant')
  if result[2] < result[0]:
    print('Large: Significant')
  if result[3] < result[0]:
    print('Women: Significant')
  if result[4] < result[0]:
    print('Men: Significant')
print('')

print('Mean: Lower Thoracic')
result_mean_walk_axi_lt = statAnova_lt(mean_walk_axi)
print(result_mean_walk_axi_lt)
if result_mean_walk_axi_lt['PR(>F)'][2] < 0.05:
  result = significant_lt(mean_walk_axi, result_mean_walk_axi_lt['PR(>F)'])
  print('Small: ', result[1], ', Large: ', result[2], ', Women: ', result[3], ', Men: ', result[4])
  if result[1] < result[0]:
    print('Small: Significant')
  if result[2] < result[0]:
    print('Large: Significant')
  if result[3] < result[0]:
    print('Women: Significant')
  if result[4] < result[0]:
    print('Men: Significant')
print('')

print('Mean: Lumbar')
result_mean_walk_axi_lum = statAnova_lum(mean_walk_axi)
print(result_mean_walk_axi_lum)
if result_mean_walk_axi_lum['PR(>F)'][2] < 0.05:
  result = significant_lum(mean_walk_axi, result_mean_walk_axi_lum['PR(>F)'])
  print('Small: ', result[1], ', Large: ', result[2], ', Women: ', result[3], ', Men: ', result[4])
  if result[1] < result[0]:
    print('Small: Significant')
  if result[2] < result[0]:
    print('Large: Significant')
  if result[3] < result[0]:
    print('Women: Significant')
  if result[4] < result[0]:
    print('Men: Significant')
print('')

# %%
print('Mean')
box_whisker(mean_walk_axi)
print('Min')
box_whisker(min_walk_axi)
print('Max')
box_whisker(max_walk_axi)
