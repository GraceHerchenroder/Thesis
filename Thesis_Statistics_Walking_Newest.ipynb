# %% [markdown]
# <a href="https://colab.research.google.com/github/GraceHerchenroder/Thesis/blob/main/Thesis_Statistics_Walking_Newest.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# Importing libraries
import pandas as pd
import numpy as np
import statsmodels.api as sm
from statsmodels.formula.api import ols
from scipy import stats
from statsmodels.stats.multitest import multipletests
import matplotlib.pyplot as plt

# %%
# Performing two-way ANOVA
def statAnova_ut(kinematic_data):
  dataframe = pd.DataFrame({'Gender': np.repeat(['women', 'men'], 5),
                          'Size': ['small', 'small', 'small', 'large', 'large', 'small', 'small', 'small', 'large', 'large'],
                          'Kinematic': kinematic_data[0][:]})
  group_1_mean = np.mean(kinematic_data[0][:3])
  group_1_sd = np.std(kinematic_data[0][:3])
  group_2_mean = np.mean(kinematic_data[0][3:5])
  group_2_sd = np.std(kinematic_data[0][3:5])
  group_3_mean = np.mean(kinematic_data[0][5:8])
  group_3_sd = np.std(kinematic_data[0][5:8])
  group_4_mean = np.mean(kinematic_data[0][8:])
  group_4_sd = np.std(kinematic_data[0][8:])
  print(kinematic_data[0][:3])
  print(group_1_mean, group_1_sd)
  print(kinematic_data[0][3:5])
  print(group_2_mean, group_2_sd)
  print(kinematic_data[0][5:8])
  print(group_3_mean, group_3_sd)
  print(kinematic_data[0][8:])
  print(group_4_mean, group_4_sd)
  print(dataframe)
  model = ols('Kinematic ~ C(Gender) + C(Size) + C(Gender):C(Size)', data=dataframe).fit()
  result = sm.stats.anova_lm(model, typ=2)
  return result

def statAnova_lt(kinematic_data):
  dataframe = pd.DataFrame({'Gender': np.repeat(['women', 'men'], 5),
                          'Size': ['small', 'small', 'small', 'large', 'large', 'small', 'small', 'small', 'large', 'large'],
                          'Kinematic': kinematic_data[1][:]})
  group_1_mean = np.mean(kinematic_data[1][:3])
  group_1_sd = np.std(kinematic_data[1][:3])
  group_2_mean = np.mean(kinematic_data[1][3:5])
  group_2_sd = np.std(kinematic_data[1][3:5])
  group_3_mean = np.mean(kinematic_data[1][5:8])
  group_3_sd = np.std(kinematic_data[1][5:8])
  group_4_mean = np.mean(kinematic_data[1][8:])
  group_4_sd = np.std(kinematic_data[1][8:])
  print(kinematic_data[1][:3])
  print(group_1_mean, group_1_sd)
  print(kinematic_data[1][3:5])
  print(group_2_mean, group_2_sd)
  print(kinematic_data[1][5:8])
  print(group_3_mean, group_3_sd)
  print(kinematic_data[1][8:])
  print(group_4_mean, group_4_sd)
  print(dataframe)
  model = ols('Kinematic ~ C(Gender) + C(Size) + C(Gender):C(Size)', data=dataframe).fit()
  result = sm.stats.anova_lm(model, typ=2)
  return result

def statAnova_lum(kinematic_data):
  dataframe = pd.DataFrame({'Gender': np.repeat(['women', 'men'], 5),
                          'Size': ['small', 'small', 'small', 'large', 'large', 'small', 'small', 'small', 'large', 'large'],
                          'Kinematic': kinematic_data[2][:]})
  group_1_mean = np.mean(kinematic_data[2][:3])
  group_1_sd = np.std(kinematic_data[2][:3])
  group_2_mean = np.mean(kinematic_data[2][3:5])
  group_2_sd = np.std(kinematic_data[2][3:5])
  group_3_mean = np.mean(kinematic_data[2][5:8])
  group_3_sd = np.std(kinematic_data[2][5:8])
  group_4_mean = np.mean(kinematic_data[2][8:])
  group_4_sd = np.std(kinematic_data[2][8:])
  print(kinematic_data[2][:3])
  print(group_1_mean, group_1_sd)
  print(kinematic_data[2][3:5])
  print(group_2_mean, group_2_sd)
  print(kinematic_data[2][5:8])
  print(group_3_mean, group_3_sd)
  print(kinematic_data[2][8:])
  print(group_4_mean, group_4_sd)
  print(dataframe)
  model = ols('Kinematic ~ C(Gender) + C(Size) + C(Gender):C(Size)', data=dataframe).fit()
  result = sm.stats.anova_lm(model, typ=2)
  return result

def box_whisker(kinematic_data):
   small_men_data_ut = kinematic_data[0][8:]
   large_men_data_ut = kinematic_data[0][5:8]
   small_women_data_ut = kinematic_data[0][:3]
   large_women_data_ut = kinematic_data[0][3:5]
   small_men_data_lt = kinematic_data[1][8:]
   large_men_data_lt = kinematic_data[1][5:8]
   small_women_data_lt = kinematic_data[1][:3]
   large_women_data_lt = kinematic_data[1][3:5]
   small_men_data_lum = kinematic_data[2][8:]
   large_men_data_lum = kinematic_data[2][5:8]
   small_women_data_lum = kinematic_data[2][:3]
   large_women_data_lum = kinematic_data[2][3:5]
   fig, ax = plt.subplots(3, 2, figsize=(6, 10))
   ax[0][0].boxplot([small_men_data_ut, large_men_data_ut], labels = ['small', 'large'])
   ax[0][0].set_title('Men')
   ax[0][0].set_ylabel('Upper Thoracic')
   ax[0][1].boxplot([small_women_data_ut, large_women_data_ut], labels = ['small', 'large'])
   ax[0][1].set_title('Women')
   ax[1][0].boxplot([small_men_data_lt, large_men_data_lt], labels = ['small', 'large'])
   ax[1][0].set_title('Men')
   ax[1][0].set_ylabel('Lower Thoracic')
   ax[1][1].boxplot([small_women_data_lt, large_women_data_lt], labels = ['small', 'large'])
   ax[1][1].set_title('Women')
   ax[2][0].boxplot([small_men_data_lum, large_men_data_lum], labels = ['small', 'large'])
   ax[2][0].set_title('Men')
   ax[2][0].set_ylabel('Lumbar')
   ax[2][1].boxplot([small_women_data_lum, large_women_data_lum], labels = ['small', 'large'])
   ax[2][1].set_title('Women')
   plt.show()

# %%
# Follow Up analysis: Significant
def significant_ut(kinematic_data, p_values):
  [reject, p_corrected] = multipletests(p_values, method = 'bonferroni')
  small_men_data = kinematic_data[0][8:]
  large_men_data = kinematic_data[0][5:8]
  small_women_data = kinematic_data[0][:3]
  large_women_data = kinematic_data[0][3:5]

  [stat_small, p_small] = stats.ttest_ind(small_men_data, small_women_data);
  [stat_large, p_large] = stats.ttest_ind(large_men_data, large_women_data);
  [stat_women, p_women] = stats.ttest_ind(small_women_data, large_women_data);
  [stat_men, p_men] = stats.ttest_ind(small_men_data, large_men_data);

  return [p_corrected, p_small, p_large, p_women, p_men]

def significant_lt(kinematic_data, p_values):
  [reject, p_corrected] = multipletests(p_values, method = 'bonferroni')
  small_men_data = kinematic_data[1][8:]
  large_men_data = kinematic_data[1][5:8]
  small_women_data = kinematic_data[1][:3]
  large_women_data = kinematic_data[1][3:5]

  [stat_small, p_small] = stats.ttest_ind(small_men_data, small_women_data);
  [stat_large, p_large] = stats.ttest_ind(large_men_data, large_women_data);
  [stat_women, p_women] = stats.ttest_ind(small_women_data, large_women_data);
  [stat_men, p_men] = stats.ttest_ind(small_men_data, large_men_data);

  return [p_corrected, p_small, p_large, p_women, p_men]

def significant_lum(kinematic_data, p_values):
  [reject, p_corrected] = multipletests(p_values, method = 'bonferroni')
  small_men_data = kinematic_data[2][8:]
  large_men_data = kinematic_data[2][5:8]
  small_women_data = kinematic_data[2][:3]
  large_women_data = kinematic_data[2][3:5]

  [stat_small, p_small] = stats.ttest_ind(small_men_data, small_women_data);
  [stat_large, p_large] = stats.ttest_ind(large_men_data, large_women_data);
  [stat_women, p_women] = stats.ttest_ind(small_women_data, large_women_data);
  [stat_men, p_men] = stats.ttest_ind(small_men_data, large_men_data);

  return [p_corrected, p_small, p_large, p_women, p_men]

# %%
# Flexion
print('\033[1mFlexion\033[0m')
print('')

# Minimums
url_min_walk_flex = 'https://raw.githubusercontent.com/GraceHerchenroder/Thesis/main/min_walk_flex.csv'
min_walk_flex = pd.read_csv(url_min_walk_flex, header = None)

print('Minimum: Upper Thoracic')
result_min_walk_flex_ut = statAnova_ut(min_walk_flex)
print(result_min_walk_flex_ut)
if result_min_walk_flex_ut['PR(>F)'][0] < 0.05:
  print('Gender: Significant')
if result_min_walk_flex_ut['PR(>F)'][1] < 0.05:
  print('Size: Significant')
if result_min_walk_flex_ut['PR(>F)'][2] < 0.05:
  result = significant_ut(min_walk_flex, result_min_walk_flex_ut['PR(>F)'])
  print('Small: ', result[1], ', Large: ', result[2], ', Women: ', result[3], ', Men: ', result[4])
  if result[1] < result[0]:
    print('Small: Significant')
  if result[2] < result[0]:
    print('Large: Significant')
  if result[3] < result[0]:
    print('Women: Significant')
  if result[4] < result[0]:
    print('Men: Significant')
print('')

print('Minimum: Lower Thoracic')
result_min_walk_flex_lt = statAnova_lt(min_walk_flex)
print(result_min_walk_flex_lt)
if result_min_walk_flex_lt['PR(>F)'][0] < 0.05:
  print('Gender: Significant')
if result_min_walk_flex_lt['PR(>F)'][1] < 0.05:
  print('Size: Significant')
if result_min_walk_flex_lt['PR(>F)'][2] < 0.05:
  result = significant_lt(min_walk_flex, result_min_walk_flex_lt['PR(>F)'])
  print('Small: ', result[1], ', Large: ', result[2], ', Women: ', result[3], ', Men: ', result[4])
  if result[1] < result[0]:
    print('Small: Significant')
  if result[2] < result[0]:
    print('Large: Significant')
  if result[3] < result[0]:
    print('Women: Significant')
  if result[4] < result[0]:
    print('Men: Significant')
print('')

print('Minimum: Lumbar')
result_min_walk_flex_lum = statAnova_lum(min_walk_flex)
print(result_min_walk_flex_lum)
if result_min_walk_flex_lum['PR(>F)'][0] < 0.05:
  print('Gender: Significant')
if result_min_walk_flex_lum['PR(>F)'][1] < 0.05:
  print('Size: Significant')
if result_min_walk_flex_lum['PR(>F)'][2] < 0.05:
  result = significant_lum(min_walk_flex, result_min_walk_flex_lum['PR(>F)'])
  print('Small: ', result[1], ', Large: ', result[2], ', Women: ', result[3], ', Men: ', result[4])
  if result[1] < result[0]:
    print('Small: Significant')
  if result[2] < result[0]:
    print('Large: Significant')
  if result[3] < result[0]:
    print('Women: Significant')
  if result[4] < result[0]:
    print('Men: Significant')
print('')

# Maximums
url_max_walk_flex = 'https://raw.githubusercontent.com/GraceHerchenroder/Thesis/main/max_walk_flex.csv'
max_walk_flex = pd.read_csv(url_max_walk_flex, header = None)

print('Maximum: Upper Thoracic')
result_max_walk_flex_ut = statAnova_ut(max_walk_flex)
print(result_max_walk_flex_ut)
if result_max_walk_flex_ut['PR(>F)'][0] < 0.05:
  print('Gender: Significant')
if result_max_walk_flex_ut['PR(>F)'][1] < 0.05:
  print('Size: Significant')
if result_max_walk_flex_ut['PR(>F)'][2] < 0.05:
  result = significant_ut(max_walk_flex, result_max_walk_flex_ut['PR(>F)'])
  print('Small: ', result[1], ', Large: ', result[2], ', Women: ', result[3], ', Men: ', result[4])
  if result[1] < result[0]:
    print('Small: Significant')
  if result[2] < result[0]:
    print('Large: Significant')
  if result[3] < result[0]:
    print('Women: Significant')
  if result[4] < result[0]:
    print('Men: Significant')
print('')

print('Maximum: Lower Thoracic')
result_max_walk_flex_lt = statAnova_lt(max_walk_flex)
print(result_max_walk_flex_lt)
if result_max_walk_flex_lt['PR(>F)'][0] < 0.05:
  print('Gender: Significant')
if result_max_walk_flex_lt['PR(>F)'][1] < 0.05:
  print('Size: Significant')
if result_max_walk_flex_lt['PR(>F)'][2] < 0.05:
  result = significant_lt(max_walk_flex, result_max_walk_flex_lt['PR(>F)'])
  print('Small: ', result[1], ', Large: ', result[2], ', Women: ', result[3], ', Men: ', result[4])
  if result[1] < result[0]:
    print('Small: Significant')
  if result[2] < result[0]:
    print('Large: Significant')
  if result[3] < result[0]:
    print('Women: Significant')
  if result[4] < result[0]:
    print('Men: Significant')
print('')

print('Maximum: Lumbar')
result_max_walk_flex_lum = statAnova_lum(max_walk_flex)
print(result_max_walk_flex_lum)
if result_max_walk_flex_lum['PR(>F)'][0] < 0.05:
  print('Gender: Significant')
if result_max_walk_flex_lum['PR(>F)'][1] < 0.05:
  print('Size: Significant')
if result_max_walk_flex_lum['PR(>F)'][2] < 0.05:
  result = significant_lum(max_walk_flex, result_max_walk_flex_lum['PR(>F)'])
  print('Small: ', result[1], ', Large: ', result[2], ', Women: ', result[3], ', Men: ', result[4])
  if result[1] < result[0]:
    print('Small: Significant')
  if result[2] < result[0]:
    print('Large: Significant')
  if result[3] < result[0]:
    print('Women: Significant')
  if result[4] < result[0]:
    print('Men: Significant')
print('')

# Means
url_mean_walk_flex = 'https://raw.githubusercontent.com/GraceHerchenroder/Thesis/main/mean_walk_flex.csv'
mean_walk_flex = pd.read_csv(url_mean_walk_flex, header = None)

print('Mean: Upper Thoracic')
result_mean_walk_flex_ut = statAnova_ut(mean_walk_flex)
print(result_mean_walk_flex_ut)
if result_mean_walk_flex_ut['PR(>F)'][0] < 0.05:
  print('Gender: Significant')
if result_mean_walk_flex_ut['PR(>F)'][1] < 0.05:
  print('Size: Significant')
if result_mean_walk_flex_ut['PR(>F)'][2] < 0.05:
  result = significant_ut(mean_walk_flex, result_mean_walk_flex_ut['PR(>F)'])
  print('Small: ', result[1], ', Large: ', result[2], ', Women: ', result[3], ', Men: ', result[4])
  if result[1] < result[0]:
    print('Small: Significant')
  if result[2] < result[0]:
    print('Large: Significant')
  if result[3] < result[0]:
    print('Women: Significant')
  if result[4] < result[0]:
    print('Men: Significant')
print('')

print('Mean: Lower Thoracic')
result_mean_walk_flex_lt = statAnova_lt(mean_walk_flex)
print(result_mean_walk_flex_lt)
if result_mean_walk_flex_lt['PR(>F)'][0] < 0.05:
  print('Gender: Significant')
if result_mean_walk_flex_lt['PR(>F)'][1] < 0.05:
  print('Size: Significant')
if result_mean_walk_flex_lt['PR(>F)'][2] < 0.05:
  result = significant_lt(mean_walk_flex, result_mean_walk_flex_lt['PR(>F)'])
  print('Small: ', result[1], ', Large: ', result[2], ', Women: ', result[3], ', Men: ', result[4])
  if result[1] < result[0]:
    print('Small: Significant')
  if result[2] < result[0]:
    print('Large: Significant')
  if result[3] < result[0]:
    print('Women: Significant')
  if result[4] < result[0]:
    print('Men: Significant')
print('')

print('Mean: Lumbar')
result_mean_walk_flex_lum = statAnova_lum(mean_walk_flex)
print(result_mean_walk_flex_lum)
if result_mean_walk_flex_lum['PR(>F)'][0] < 0.05:
  print('Gender: Significant')
if result_mean_walk_flex_lum['PR(>F)'][1] < 0.05:
  print('Size: Significant')
if result_mean_walk_flex_lum['PR(>F)'][2] < 0.05:
  result = significant_lum(mean_walk_flex, result_mean_walk_flex_lum['PR(>F)'])
  print('Small: ', result[1], ', Large: ', result[2], ', Women: ', result[3], ', Men: ', result[4])
  if result[1] < result[0]:
    print('Small: Significant')
  if result[2] < result[0]:
    print('Large: Significant')
  if result[3] < result[0]:
    print('Women: Significant')
  if result[4] < result[0]:
    print('Men: Significant')
print('')
# Out:
# Flexion
#
# Minimum: Upper Thoracic
# 0    24.370861
# 1    16.754343
# 2    21.655466
# Name: 0, dtype: float64
# 20.926890082444164 3.1518200161968575
# 3    29.944376
# 4     2.030569
# Name: 0, dtype: float64
# 15.987472786835228 13.95690370906007
# 5    14.186915
# 6    11.212140
# 7    21.655466
# Name: 0, dtype: float64
# 15.684840314895368 4.393070338360834
# 8     9.561691
# 9    15.201689
# Name: 0, dtype: float64
# 12.381690413958715 2.819999072384685
#   Gender   Size  Kinematic
# 0  women  small  24.370861
# 1  women  small  16.754343
# 2  women  small  21.655466
# 3  women  large  29.944376
# 4  women  large   2.030569
# 5    men  small  14.186915
# 6    men  small  11.212140
# 7    men  small  21.655466
# 8    men  large   9.561691
# 9    men  large  15.201689
#                        sum_sq   df         F    PR(>F)
# C(Gender)           52.613873  1.0  0.640079  0.454184
# C(Size)             40.763948  1.0  0.495918  0.507696
# C(Gender):C(Size)    1.606423  1.0  0.019543  0.893395
# Residual           493.194221  6.0       NaN       NaN
#
# Minimum: Lower Thoracic
# 0    21.344107
# 1    12.508242
# 2    28.732715
# Name: 1, dtype: float64
# 20.8616880482663 6.632391302131923
# 3    11.063427
# 4    14.574749
# Name: 1, dtype: float64
# 12.8190879501949 1.7556606729622999
# 5    16.111756
# 6    -6.073522
# 7    28.732715
# Name: 1, dtype: float64
# 12.92364937035923 14.387298689824224
# 8    31.611173
# 9    19.110871
# Name: 1, dtype: float64
# 25.361022018884753 6.25015129376545
#   Gender   Size  Kinematic
# 0  women  small  21.344107
# 1  women  small  12.508242
# 2  women  small  28.732715
# 3  women  large  11.063427
# 4  women  large  14.574749
# 5    men  small  16.111756
# 6    men  small  -6.073522
# 7    men  small  28.732715
# 8    men  large  31.611173
# 9    men  large  19.110871
#                        sum_sq   df         F    PR(>F)
# C(Gender)            0.161227  1.0  0.001155  0.973987
# C(Size)             11.588415  1.0  0.083047  0.782906
# C(Gender):C(Size)  251.657570  1.0  1.803475  0.227863
# Residual           837.242405  6.0       NaN       NaN
#
# Minimum: Lumbar
# 0   -34.855213
# 1    -2.023029
# 2   -25.197197
# Name: 2, dtype: float64
# -20.691813371165725 13.777080996651973
# 3   -26.717615
# 4    -7.262824
# Name: 2, dtype: float64
# -16.990219633430954 9.727395257969144
# 5   -25.902887
# 6   -25.533565
# 7   -25.197197
# Name: 2, dtype: float64
# -25.544549664012266 0.2882010897851759
# 8   -37.249287
# 9   -25.591958
# Name: 2, dtype: float64
# -31.42062217530215 5.828664370892149
#   Gender   Size  Kinematic
# 0  women  small -34.855213
# 1  women  small  -2.023029
# 2  women  small -25.197197
# 3  women  large -26.717615
# 4  women  large  -7.262824
# 5    men  small -25.902887
# 6    men  small -25.533565
# 7    men  small -25.197197
# 8    men  large -37.249287
# 9    men  large -25.591958
#                        sum_sq   df         F    PR(>F)
# C(Gender)          188.521077  1.0  1.367971  0.286516
# C(Size)              2.837015  1.0  0.020586  0.890609
# C(Gender):C(Size)   55.039014  1.0  0.399381  0.550714
# Residual           826.864156  6.0       NaN       NaN
#
# Maximum: Upper Thoracic
# 0    25.452085
# 1    17.432824
# 2    22.640781
# Name: 0, dtype: float64
# 21.841896432706033 3.3222281999158554
# 3    30.802793
# 4     3.174619
# Name: 0, dtype: float64
# 16.988705750594395 13.814086981505405
# 5    15.304037
# 6    11.796781
# 7    22.640781
# Name: 0, dtype: float64
# 16.580532806360367 4.518123846117208
# 8     9.800314
# 9    16.982425
# Name: 0, dtype: float64
# 13.391369420650285 3.591055204705615
#   Gender   Size  Kinematic
# 0  women  small  25.452085
# 1  women  small  17.432824
# 2  women  small  22.640781
# 3  women  large  30.802793
# 4  women  large   3.174619
# 5    men  small  15.304037
# 6    men  small  11.796781
# 7    men  small  22.640781
# 8    men  large   9.800314
# 9    men  large  16.982425
#                        sum_sq   df         F    PR(>F)
# C(Gender)           52.802357  1.0  0.631354  0.457128
# C(Size)             38.807675  1.0  0.464020  0.521160
# C(Gender):C(Size)    1.661392  1.0  0.019865  0.892527
# Residual           501.801283  6.0       NaN       NaN
#
# Maximum: Lower Thoracic
# 0    23.398271
# 1    13.260614
# 2    29.365934
# Name: 1, dtype: float64
# 22.008273058433833 6.64802750493892
# 3    11.94268
# 4    16.05932
# Name: 1, dtype: float64
# 14.00099968974455 2.0583201760261502
# 5    17.094541
# 6     5.840436
# 7    29.365934
# Name: 1, dtype: float64
# 17.433637111040618 9.60723713532345
# 8    32.160972
# 9    20.634112
# Name: 1, dtype: float64
# 26.397542148996948 5.763429839193348
#   Gender   Size  Kinematic
# 0  women  small  23.398271
# 1  women  small  13.260614
# 2  women  small  29.365934
# 3  women  large  11.942680
# 4  women  large  16.059320
# 5    men  small  17.094541
# 6    men  small   5.840436
# 7    men  small  29.365934
# 8    men  large  32.160972
# 9    men  large  20.634112
#                        sum_sq   df         F    PR(>F)
# C(Gender)           12.252668  1.0  0.151769  0.710303
# C(Size)              0.549086  1.0  0.006801  0.936955
# C(Gender):C(Size)  172.812538  1.0  2.140564  0.193776
# Residual           484.393436  6.0       NaN       NaN
#
# Maximum: Lumbar
# 0   -28.030934
# 1    -0.078454
# 2   -22.673345
# Name: 2, dtype: float64
# -16.92757780572291 12.113234142013395
# 3   -23.344416
# 4    10.872165
# Name: 2, dtype: float64
# -6.2361254947038 17.1082903791475
# 5   -22.548395
# 6   -22.090478
# 7   -22.673345
# Name: 2, dtype: float64
# -22.4374064460773 0.2505626095784803
# 8   -36.142039
# 9   -17.254505
# Name: 2, dtype: float64
# -26.69827205094555 9.44376714766275
#   Gender   Size  Kinematic
# 0  women  small -28.030934
# 1  women  small  -0.078454
# 2  women  small -22.673345
# 3  women  large -23.344416
# 4  women  large  10.872165
# 5    men  small -22.548395
# 6    men  small -22.090478
# 7    men  small -22.673345
# 8    men  large -36.142039
# 9    men  large -17.254505
#                         sum_sq   df         F    PR(>F)
# C(Gender)           330.093673  1.0  1.644799  0.246985
# C(Size)              24.811467  1.0  0.123631  0.737148
# C(Gender):C(Size)   134.143087  1.0  0.668411  0.444851
# Residual           1204.136344  6.0       NaN       NaN
#
# Mean: Upper Thoracic
# 0    24.942052
# 1    17.153884
# 2    22.050574
# Name: 0, dtype: float64
# 21.382169846843833 3.214442656182922
# 3    30.437030
# 4     2.508688
# Name: 0, dtype: float64
# 16.47285868138061 13.96417105648479
# 5    14.834688
# 6    11.465964
# 7    22.050574
# Name: 0, dtype: float64
# 16.117075405558236 4.415267501074423
# 8     9.701845
# 9    16.279929
# Name: 0, dtype: float64
# 12.990886894669995 3.289041825229905
#   Gender   Size  Kinematic
# 0  women  small  24.942052
# 1  women  small  17.153884
# 2  women  small  22.050574
# 3  women  large  30.437030
# 4  women  large   2.508688
# 5    men  small  14.834688
# 6    men  small  11.465964
# 7    men  small  22.050574
# 8    men  large   9.701845
# 9    men  large  16.279929
#                        sum_sq   df         F    PR(>F)
# C(Gender)           51.798241  1.0  0.620198  0.460942
# C(Size)             38.741553  1.0  0.463866  0.521227
# C(Gender):C(Size)    1.907716  1.0  0.022842  0.884823
# Residual           501.113425  6.0       NaN       NaN
#
# Mean: Lower Thoracic
# 0    22.383431
# 1    12.931312
# 2    29.162151
# Name: 1, dtype: float64
# 21.492297679455103 6.656105897259531
# 3    11.457391
# 4    15.541343
# Name: 1, dtype: float64
# 13.499367129342751 2.0419760862799494
# 5    16.560017
# 6    -0.088917
# 7    29.162151
# Name: 1, dtype: float64
# 15.21108324190837 11.979731777467844
# 8    31.888580
# 9    19.825099
# Name: 1, dtype: float64
# 25.856839069001552 6.0317405508589506
#   Gender   Size  Kinematic
# 0  women  small  22.383431
# 1  women  small  12.931312
# 2  women  small  29.162151
# 3  women  large  11.457391
# 4  women  large  15.541343
# 5    men  small  16.560017
# 6    men  small  -0.088917
# 7    men  small  29.162151
# 8    men  large  31.888580
# 9    men  large  19.825099
#                        sum_sq   df         F    PR(>F)
# C(Gender)            3.447217  1.0  0.032089  0.863728
# C(Size)              4.222489  1.0  0.039306  0.849390
# C(Gender):C(Size)  208.440378  1.0  1.940315  0.213056
# Residual           644.556278  6.0       NaN       NaN
#
# Mean: Lumbar
# 0   -31.431745
# 1    -1.092308
# 2   -23.971223
# Name: 2, dtype: float64
# -18.83175831251263 12.90816099150091
# 3   -24.961453
# 4     3.952553
# Name: 2, dtype: float64
# -10.504449777971036 14.457002917922065
# 5   -24.455383
# 6   -23.818911
# 7   -23.971223
# Name: 2, dtype: float64
# -24.081839085565264 0.2713559948110126
# 8   -36.735319
# 9   -22.459763
# Name: 2, dtype: float64
# -29.597541064803153 7.1377779754947515
#   Gender   Size  Kinematic
# 0  women  small -31.431745
# 1  women  small  -1.092308
# 2  women  small -23.971223
# 3  women  large -24.961453
# 4  women  large   3.952553
# 5    men  small -24.455383
# 6    men  small -23.818911
# 7    men  small -23.971223
# 8    men  large -36.735319
# 9    men  large -22.459763
#                         sum_sq   df         F    PR(>F)
# C(Gender)           290.913793  1.0  1.711277  0.238698
# C(Size)               4.743079  1.0  0.027901  0.872830
# C(Gender):C(Size)   114.977364  1.0  0.676345  0.442297
# Residual           1019.988378  6.0       NaN       NaN

# %%
print('Mean')
box_whisker(mean_walk_flex)
print('Min')
box_whisker(min_walk_flex)
print('Max')
box_whisker(max_walk_flex)
# Out:
# Mean
# Min
# Max

# %%
# Lateral Flexion
print('\033[1mLateral Flexion\033[0m')
print('')

# Minimums
url_min_walk_lat = 'https://raw.githubusercontent.com/GraceHerchenroder/Thesis/main/min_walk_lat.csv'
min_walk_lat = pd.read_csv(url_min_walk_lat, header = None)

print('Minimum: Upper Thoracic')
result_min_walk_lat_ut = statAnova_ut(min_walk_lat)
print(result_min_walk_lat_ut)
if result_min_walk_lat_ut['PR(>F)'][2] < 0.05:
  result = significant_ut(min_walk_lat, result_min_walk_lat_ut['PR(>F)'])
  print('Small: ', result[1], ', Large: ', result[2], ', Women: ', result[3], ', Men: ', result[4])
  if result[1] < result[0]:
    print('Small: Significant')
  if result[2] < result[0]:
    print('Large: Significant')
  if result[3] < result[0]:
    print('Women: Significant')
  if result[4] < result[0]:
    print('Men: Significant')
print('')

print('Minimum: Lower Thoracic')
result_min_walk_lat_lt = statAnova_lt(min_walk_lat)
print(result_min_walk_lat_lt)
if result_min_walk_lat_lt['PR(>F)'][2] < 0.05:
  result = significant_lt(min_walk_lat, result_min_walk_lat_lt['PR(>F)'])
  print('Small: ', result[1], ', Large: ', result[2], ', Women: ', result[3], ', Men: ', result[4])
  if result[1] < result[0]:
    print('Small: Significant')
  if result[2] < result[0]:
    print('Large: Significant')
  if result[3] < result[0]:
    print('Women: Significant')
  if result[4] < result[0]:
    print('Men: Significant')
print('')

print('Minimum: Lumbar')
result_min_walk_lat_lum = statAnova_lum(min_walk_lat)
print(result_min_walk_lat_lum)
if result_min_walk_lat_lum['PR(>F)'][2] < 0.05:
  result = significant_lum(min_walk_lat, result_min_walk_lat_lum['PR(>F)'])
  print('Small: ', result[1], ', Large: ', result[2], ', Women: ', result[3], ', Men: ', result[4])
  if result[1] < result[0]:
    print('Small: Significant')
  if result[2] < result[0]:
    print('Large: Significant')
  if result[3] < result[0]:
    print('Women: Significant')
  if result[4] < result[0]:
    print('Men: Significant')
print('')

# Maximums
url_max_walk_lat = 'https://raw.githubusercontent.com/GraceHerchenroder/Thesis/main/max_walk_lat.csv'
max_walk_lat = pd.read_csv(url_max_walk_lat, header = None)

print('Maximum: Upper Thoracic')
result_max_walk_lat_ut = statAnova_ut(max_walk_lat)
print(result_max_walk_lat_ut)
if result_max_walk_lat_ut['PR(>F)'][2] < 0.05:
  result = significant_ut(max_walk_lat, result_max_walk_lat_ut['PR(>F)'])
  print('Small: ', result[1], ', Large: ', result[2], ', Women: ', result[3], ', Men: ', result[4])
  if result[1] < result[0]:
    print('Small: Significant')
  if result[2] < result[0]:
    print('Large: Significant')
  if result[3] < result[0]:
    print('Women: Significant')
  if result[4] < result[0]:
    print('Men: Significant')
print('')

print('Maximum: Lower Thoracic')
result_max_walk_lat_lt = statAnova_lt(max_walk_lat)
print(result_max_walk_lat_lt)
if result_max_walk_lat_lt['PR(>F)'][2] < 0.05:
  result = significant_lt(max_walk_lat, result_max_walk_lat_lt['PR(>F)'])
  print('Small: ', result[1], ', Large: ', result[2], ', Women: ', result[3], ', Men: ', result[4])
  if result[1] < result[0]:
    print('Small: Significant')
  if result[2] < result[0]:
    print('Large: Significant')
  if result[3] < result[0]:
    print('Women: Significant')
  if result[4] < result[0]:
    print('Men: Significant')
print('')

print('Maximum: Lumbar')
result_max_walk_lat_lum = statAnova_lum(max_walk_lat)
print(result_max_walk_lat_lum)
if result_max_walk_lat_lum['PR(>F)'][2] < 0.05:
  result = significant_lum(max_walk_lat, result_max_walk_lat_lum['PR(>F)'])
  print('Small: ', result[1], ', Large: ', result[2], ', Women: ', result[3], ', Men: ', result[4])
  if result[1] < result[0]:
    print('Small: Significant')
  if result[2] < result[0]:
    print('Large: Significant')
  if result[3] < result[0]:
    print('Women: Significant')
  if result[4] < result[0]:
    print('Men: Significant')
print('')

# Means
url_mean_walk_lat = 'https://raw.githubusercontent.com/GraceHerchenroder/Thesis/main/mean_walk_lat.csv'
mean_walk_lat = pd.read_csv(url_mean_walk_lat, header = None)

print('Mean: Upper Thoracic')
result_mean_walk_lat_ut = statAnova_ut(mean_walk_lat)
print(result_mean_walk_lat_ut)
if result_mean_walk_flex_ut['PR(>F)'][2] < 0.05:
  result = significant_ut(mean_walk_lat, result_mean_walk_lat_ut['PR(>F)'])
  print('Small: ', result[1], ', Large: ', result[2], ', Women: ', result[3], ', Men: ', result[4])
  if result[1] < result[0]:
    print('Small: Significant')
  if result[2] < result[0]:
    print('Large: Significant')
  if result[3] < result[0]:
    print('Women: Significant')
  if result[4] < result[0]:
    print('Men: Significant')
print('')

print('Mean: Lower Thoracic')
result_mean_walk_lat_lt = statAnova_lt(mean_walk_lat)
print(result_mean_walk_lat_lt)
if result_mean_walk_lat_lt['PR(>F)'][2] < 0.05:
  result = significant_lt(mean_walk_lat, result_mean_walk_lat_lt['PR(>F)'])
  print('Small: ', result[1], ', Large: ', result[2], ', Women: ', result[3], ', Men: ', result[4])
  if result[1] < result[0]:
    print('Small: Significant')
  if result[2] < result[0]:
    print('Large: Significant')
  if result[3] < result[0]:
    print('Women: Significant')
  if result[4] < result[0]:
    print('Men: Significant')
print('')

print('Mean: Lumbar')
result_mean_walk_lat_lum = statAnova_lum(mean_walk_lat)
print(result_mean_walk_lat_lum)
if result_mean_walk_lat_lum['PR(>F)'][2] < 0.05:
  result = significant_lum(mean_walk_lat, result_mean_walk_lat_lum['PR(>F)'])
  print('Small: ', result[1], ', Large: ', result[2], ', Women: ', result[3], ', Men: ', result[4])
  if result[1] < result[0]:
    print('Small: Significant')
  if result[2] < result[0]:
    print('Large: Significant')
  if result[3] < result[0]:
    print('Women: Significant')
  if result[4] < result[0]:
    print('Men: Significant')
print('')
# Out:
# Lateral Flexion
#
# Minimum: Upper Thoracic
# 0   -4.312982
# 1   -1.065873
# 2   -6.593536
# Name: 0, dtype: float64
# -3.9907973370442704 2.2681295234706407
# 3    4.361329
# 4   -2.084772
# Name: 0, dtype: float64
# 1.138278334132305 3.223050376101145
# 5   -0.699490
# 6   -1.860293
# 7   -6.593536
# Name: 0, dtype: float64
# -3.0511063539297445 2.5493102754546357
# 8   -1.394681
# 9   -7.214376
# Name: 0, dtype: float64
# -4.304528496706856 2.909847462966365
#   Gender   Size  Kinematic
# 0  women  small  -4.312982
# 1  women  small  -1.065873
# 2  women  small  -6.593536
# 3  women  large   4.361329
# 4  women  large  -2.084772
# 5    men  small  -0.699490
# 6    men  small  -1.860293
# 7    men  small  -6.593536
# 8    men  large  -1.394681
# 9    men  large  -7.214376
#                       sum_sq   df         F    PR(>F)
# C(Gender)           6.506908  1.0  0.537460  0.491126
# C(Size)             9.012414  1.0  0.744410  0.421394
# C(Gender):C(Size)  24.441767  1.0  2.018849  0.205180
# Residual           72.640715  6.0       NaN       NaN
#
# Minimum: Lower Thoracic
# 0    1.855094
# 1   -9.919851
# 2   -3.215191
# Name: 1, dtype: float64
# -3.759982534189904 4.82251187917005
# 3    0.385390
# 4   -9.448473
# Name: 1, dtype: float64
# -4.5315414572840895 4.916931311485641
# 5   -6.920040
# 6    3.864308
# 7   -3.215191
# Name: 1, dtype: float64
# -2.0903075421796866 4.4739665245515585
# 8   -6.173221
# 9    0.950243
# Name: 1, dtype: float64
# -2.6114888539259624 3.5617320106873884
#   Gender   Size  Kinematic
# 0  women  small   1.855094
# 1  women  small  -9.919851
# 2  women  small  -3.215191
# 3  women  large   0.385390
# 4  women  large  -9.448473
# 5    men  small  -6.920040
# 6    men  small   3.864308
# 7    men  small  -3.215191
# 8    men  large  -6.173221
# 9    men  large   0.950243
#                        sum_sq   df         F    PR(>F)
# C(Gender)            7.830710  1.0  0.230832  0.647923
# C(Size)              1.002706  1.0  0.029558  0.869150
# C(Gender):C(Size)    0.037613  1.0  0.001109  0.974517
# Residual           203.543289  6.0       NaN       NaN
#
# Minimum: Lumbar
# 0   -10.589452
# 1     0.201012
# 2    -8.694928
# Name: 2, dtype: float64
# -6.3611224482907645 4.704148095900434
# 3   -11.142439
# 4     0.484177
# Name: 2, dtype: float64
# -5.329130912644694 5.8133076290043055
# 5     2.243232
# 6   -12.411340
# 7    -8.694928
# Name: 2, dtype: float64
# -6.287678517183797 6.220142314259539
# 8     6.135371
# 9   -10.741199
# Name: 2, dtype: float64
# -2.3029138029013754 8.438285277122125
#   Gender   Size  Kinematic
# 0  women  small -10.589452
# 1  women  small   0.201012
# 2  women  small  -8.694928
# 3  women  large -11.142439
# 4  women  large   0.484177
# 5    men  small   2.243232
# 6    men  small -12.411340
# 7    men  small  -8.694928
# 8    men  large   6.135371
# 9    men  large -10.741199
#                        sum_sq   df         F    PR(>F)
# C(Gender)            3.934759  1.0  0.060156  0.814423
# C(Size)             15.100706  1.0  0.230865  0.647900
# C(Gender):C(Size)    5.231322  1.0  0.079978  0.786830
# Residual           392.455947  6.0       NaN       NaN
#
# Maximum: Upper Thoracic
# 0    3.680973
# 1    2.235419
# 2   -3.902997
# Name: 0, dtype: float64
# 0.6711316904433201 3.287795242727868
# 3    6.973097
# 4    5.056681
# Name: 0, dtype: float64
# 6.0148889871819105 0.95820754469479
# 5    2.915691
# 6   -0.292603
# 7   -3.902997
# Name: 0, dtype: float64
# -0.4266364165687914 2.785330522962081
# 8   -0.332244
# 9    5.250184
# Name: 0, dtype: float64
# 2.4589700654922573 2.7912137996797535
#   Gender   Size  Kinematic
# 0  women  small   3.680973
# 1  women  small   2.235419
# 2  women  small  -3.902997
# 3  women  large   6.973097
# 4  women  large   5.056681
# 5    men  small   2.915691
# 6    men  small  -0.292603
# 7    men  small  -3.902997
# 8    men  large  -0.332244
# 9    men  large   5.250184
#                       sum_sq   df         F    PR(>F)
# C(Gender)          10.826698  1.0  0.888392  0.382299
# C(Size)            40.633457  1.0  3.334207  0.117641
# C(Gender):C(Size)   3.625503  1.0  0.297493  0.605126
# Residual           73.121063  6.0       NaN       NaN
#
# Maximum: Lower Thoracic
# 0    9.286139
# 1    3.707765
# 2    3.500410
# Name: 1, dtype: float64
# 5.498104669151424 2.6798818260940727
# 3    5.802108
# 4   -1.417533
# Name: 1, dtype: float64
# 2.1922875334288947 3.609820871455265
# 5    3.885317
# 6    7.806566
# 7    3.500410
# Name: 1, dtype: float64
# 5.064097597468863 1.9455741812244516
# 8   -4.169552
# 9    6.527334
# Name: 1, dtype: float64
# 1.1788909155891498 5.348443119466371
#   Gender   Size  Kinematic
# 0  women  small   9.286139
# 1  women  small   3.707765
# 2  women  small   3.500410
# 3  women  large   5.802108
# 4  women  large  -1.417533
# 5    men  small   3.885317
# 6    men  small   7.806566
# 7    men  small   3.500410
# 8    men  large  -4.169552
# 9    men  large   6.527334
#                        sum_sq   df         F    PR(>F)
# C(Gender)            1.108101  1.0  0.057230  0.818892
# C(Size)             31.026494  1.0  1.602410  0.252492
# C(Gender):C(Size)    0.201415  1.0  0.010402  0.922086
# Residual           116.174378  6.0       NaN       NaN
#
# Maximum: Lumbar
# 0    7.897874
# 1    4.586394
# 2    9.483517
# Name: 2, dtype: float64
# 7.322594927595027 2.0402063751878776
# 3    5.007607
# 4    6.235562
# Name: 2, dtype: float64
# 5.621584658411905 0.6139774850074651
# 5    10.131986
# 6     2.663429
# 7     9.483517
# Name: 2, dtype: float64
# 7.426310600711879 3.3782548638633556
# 8    9.781823
# 9    9.770506
# Name: 2, dtype: float64
# 9.776164491890114 0.005658276016865749
#   Gender   Size  Kinematic
# 0  women  small   7.897874
# 1  women  small   4.586394
# 2  women  small   9.483517
# 3  women  large   5.007607
# 4  women  large   6.235562
# 5    men  small  10.131986
# 6    men  small   2.663429
# 7    men  small   9.483517
# 8    men  large   9.781823
# 9    men  large   9.770506
#                       sum_sq   df         F    PR(>F)
# C(Gender)           7.430969  1.0  0.939061  0.369944
# C(Size)             0.252599  1.0  0.031921  0.864081
# C(Gender):C(Size)   9.845700  1.0  1.244214  0.307333
# Residual           47.479145  6.0       NaN       NaN
#
# Mean: Upper Thoracic
# 0   -0.149673
# 1    0.613459
# 2   -5.237863
# Name: 0, dtype: float64
# -1.5913592595881083 2.597221107189841
# 3    5.886975
# 4    1.747533
# Name: 0, dtype: float64
# 3.8172543916131 2.06972104942612
# 5    0.808635
# 6   -0.876140
# 7   -5.237863
# Name: 0, dtype: float64
# -1.7684559501085573 2.5478366623982294
# 8   -0.797869
# 9    0.679351
# Name: 0, dtype: float64
# -0.05925876141075903 0.738610243711852
#   Gender   Size  Kinematic
# 0  women  small  -0.149673
# 1  women  small   0.613459
# 2  women  small  -5.237863
# 3  women  large   5.886975
# 4  women  large   1.747533
# 5    men  small   0.808635
# 6    men  small  -0.876140
# 7    men  small  -5.237863
# 8    men  large  -0.797869
# 9    men  large   0.679351
#                       sum_sq   df         F    PR(>F)
# C(Gender)           6.862990  1.0  0.834074  0.396311
# C(Size)            30.397939  1.0  3.694326  0.102971
# C(Gender):C(Size)   8.211409  1.0  0.997950  0.356376
# Residual           49.369668  6.0       NaN       NaN
#
# Mean: Lower Thoracic
# 0    5.442150
# 1   -1.765733
# 2    0.275896
# Name: 1, dtype: float64
# 1.3174374446380892 3.033370188216534
# 3    2.774333
# 4   -4.606995
# Name: 1, dtype: float64
# -0.9163310995048648 3.6906641364200348
# 5   -1.667016
# 6    5.841522
# 7    0.275896
# Name: 1, dtype: float64
# 1.4834670730699997 3.1820546021809095
# 8   -5.145477
# 9    3.632183
# Name: 1, dtype: float64
# -0.7566469893597201 4.38882987858568
#   Gender   Size  Kinematic
# 0  women  small   5.442150
# 1  women  small  -1.765733
# 2  women  small   0.275896
# 3  women  large   2.774333
# 4  women  large  -4.606995
# 5    men  small  -1.667016
# 6    men  small   5.841522
# 7    men  small   0.275896
# 8    men  large  -5.145477
# 9    men  large   3.632183
#                        sum_sq   df         F    PR(>F)
# C(Gender)            0.066824  1.0  0.003240  0.956456
# C(Size)             12.009375  1.0  0.582291  0.474339
# C(Gender):C(Size)    0.000024  1.0  0.000001  0.999172
# Residual           123.746078  6.0       NaN       NaN
#
# Mean: Lumbar
# 0   -1.406981
# 1    2.237245
# 2    0.705994
# Name: 2, dtype: float64
# 0.5120859550971383 1.4940540887756144
# 3   -1.931901
# 4    3.278265
# Name: 2, dtype: float64
# 0.673181948388805 2.605083428836505
# 5    3.986774
# 6   -5.131347
# 7    0.705994
# Name: 2, dtype: float64
# -0.14619297305516513 3.770915140131318
# 8    8.004085
# 9    0.548279
# Name: 2, dtype: float64
# 4.27618196030547 3.7279032952287903
#   Gender   Size  Kinematic
# 0  women  small  -1.406981
# 1  women  small   2.237245
# 2  women  small   0.705994
# 3  women  large  -1.931901
# 4  women  large   3.278265
# 5    men  small   3.986774
# 6    men  small  -5.131347
# 7    men  small   0.705994
# 8    men  large   8.004085
# 9    men  large   0.548279
#                       sum_sq   df         F    PR(>F)
# C(Gender)           2.736507  1.0  0.180979  0.685369
# C(Size)            12.604923  1.0  0.833627  0.396430
# C(Gender):C(Size)  10.895099  1.0  0.720548  0.428525
# Residual           90.723441  6.0       NaN       NaN

# %%
print('Mean')
box_whisker(mean_walk_lat)
print('Min')
box_whisker(min_walk_lat)
print('Max')
box_whisker(max_walk_lat)
# Out:
# Mean
# Min
# Max

# %%
# Axial Flexion
# Flexion
print('\033[1mAxial Flexion\033[0m')
print('')

# Minimums
url_min_walk_axi = 'https://raw.githubusercontent.com/GraceHerchenroder/Thesis/main/min_walk_axi.csv'
min_walk_axi = pd.read_csv(url_min_walk_axi, header = None)

print('Minimum: Upper Thoracic')
result_min_walk_axi_ut = statAnova_ut(min_walk_axi)
print(result_min_walk_axi_ut)
if result_min_walk_axi_ut['PR(>F)'][2] < 0.05:
  result = significant_ut(min_walk_axi, result_min_walk_axi_ut['PR(>F)'])
  print('Small: ', result[1], ', Large: ', result[2], ', Women: ', result[3], ', Men: ', result[4])
  if result[1] < result[0]:
    print('Small: Significant')
  if result[2] < result[0]:
    print('Large: Significant')
  if result[3] < result[0]:
    print('Women: Significant')
  if result[4] < result[0]:
    print('Men: Significant')
print('')

print('Minimum: Lower Thoracic')
result_min_walk_axi_lt = statAnova_lt(min_walk_axi)
print(result_min_walk_axi_lt)
if result_min_walk_axi_lt['PR(>F)'][2] < 0.05:
  result = significant_lt(min_walk_axi, result_min_walk_axi_lt['PR(>F)'])
  print('Small: ', result[1], ', Large: ', result[2], ', Women: ', result[3], ', Men: ', result[4])
  if result[1] < result[0]:
    print('Small: Significant')
  if result[2] < result[0]:
    print('Large: Significant')
  if result[3] < result[0]:
    print('Women: Significant')
  if result[4] < result[0]:
    print('Men: Significant')
print('')

print('Minimum: Lumbar')
result_min_walk_axi_lum = statAnova_lum(min_walk_axi)
print(result_min_walk_axi_lum)
if result_min_walk_axi_lum['PR(>F)'][2] < 0.05:
  result = significant_lum(min_walk_axi, result_min_walk_axi_lum['PR(>F)'])
  print('Small: ', result[1], ', Large: ', result[2], ', Women: ', result[3], ', Men: ', result[4])
  if result[1] < result[0]:
    print('Small: Significant')
  if result[2] < result[0]:
    print('Large: Significant')
  if result[3] < result[0]:
    print('Women: Significant')
  if result[4] < result[0]:
    print('Men: Significant')
print('')

# Maximums
url_max_walk_axi = 'https://raw.githubusercontent.com/GraceHerchenroder/Thesis/main/max_walk_axi.csv'
max_walk_axi = pd.read_csv(url_max_walk_axi, header = None)

print('Maximum: Upper Thoracic')
result_max_walk_axi_ut = statAnova_ut(max_walk_axi)
print(result_max_walk_axi_ut)
if result_max_walk_axi_ut['PR(>F)'][2] < 0.05:
  result = significant_ut(max_walk_axi, result_max_walk_axi_ut['PR(>F)'])
  print('Small: ', result[1], ', Large: ', result[2], ', Women: ', result[3], ', Men: ', result[4])
  if result[1] < result[0]:
    print('Small: Significant')
  if result[2] < result[0]:
    print('Large: Significant')
  if result[3] < result[0]:
    print('Women: Significant')
  if result[4] < result[0]:
    print('Men: Significant')
print('')

print('Maximum: Lower Thoracic')
result_max_walk_axi_lt = statAnova_lt(max_walk_axi)
print(result_max_walk_axi_lt)
if result_max_walk_axi_lt['PR(>F)'][2] < 0.05:
  result = significant_lt(max_walk_axi, result_max_walk_axi_lt['PR(>F)'])
  print('Small: ', result[1], ', Large: ', result[2], ', Women: ', result[3], ', Men: ', result[4])
  if result[1] < result[0]:
    print('Small: Significant')
  if result[2] < result[0]:
    print('Large: Significant')
  if result[3] < result[0]:
    print('Women: Significant')
  if result[4] < result[0]:
    print('Men: Significant')
print('')

print('Maximum: Lumbar')
result_max_walk_axi_lum = statAnova_lum(max_walk_axi)
print(result_max_walk_axi_lum)
if result_max_walk_axi_lum['PR(>F)'][2] < 0.05:
  result = significant_lum(max_walk_axi, result_max_walk_axi_lum['PR(>F)'])
  print('Small: ', result[1], ', Large: ', result[2], ', Women: ', result[3], ', Men: ', result[4])
  if result[1] < result[0]:
    print('Small: Significant')
  if result[2] < result[0]:
    print('Large: Significant')
  if result[3] < result[0]:
    print('Women: Significant')
  if result[4] < result[0]:
    print('Men: Significant')
print('')

# Means
url_mean_walk_axi = 'https://raw.githubusercontent.com/GraceHerchenroder/Thesis/main/mean_walk_axi.csv'
mean_walk_axi = pd.read_csv(url_mean_walk_axi, header = None)

print('Mean: Upper Thoracic')
result_mean_walk_axi_ut = statAnova_ut(mean_walk_axi)
print(result_mean_walk_axi_ut)
if result_mean_walk_axi_ut['PR(>F)'][2] < 0.05:
  result = significant_ut(mean_walk_axi, result_mean_walk_axi_ut['PR(>F)'])
  print('Small: ', result[1], ', Large: ', result[2], ', Women: ', result[3], ', Men: ', result[4])
  if result[1] < result[0]:
    print('Small: Significant')
  if result[2] < result[0]:
    print('Large: Significant')
  if result[3] < result[0]:
    print('Women: Significant')
  if result[4] < result[0]:
    print('Men: Significant')
print('')

print('Mean: Lower Thoracic')
result_mean_walk_axi_lt = statAnova_lt(mean_walk_axi)
print(result_mean_walk_axi_lt)
if result_mean_walk_axi_lt['PR(>F)'][2] < 0.05:
  result = significant_lt(mean_walk_axi, result_mean_walk_axi_lt['PR(>F)'])
  print('Small: ', result[1], ', Large: ', result[2], ', Women: ', result[3], ', Men: ', result[4])
  if result[1] < result[0]:
    print('Small: Significant')
  if result[2] < result[0]:
    print('Large: Significant')
  if result[3] < result[0]:
    print('Women: Significant')
  if result[4] < result[0]:
    print('Men: Significant')
print('')

print('Mean: Lumbar')
result_mean_walk_axi_lum = statAnova_lum(mean_walk_axi)
print(result_mean_walk_axi_lum)
if result_mean_walk_axi_lum['PR(>F)'][2] < 0.05:
  result = significant_lum(mean_walk_axi, result_mean_walk_axi_lum['PR(>F)'])
  print('Small: ', result[1], ', Large: ', result[2], ', Women: ', result[3], ', Men: ', result[4])
  if result[1] < result[0]:
    print('Small: Significant')
  if result[2] < result[0]:
    print('Large: Significant')
  if result[3] < result[0]:
    print('Women: Significant')
  if result[4] < result[0]:
    print('Men: Significant')
print('')
# Out:
# Axial Flexion
#
# Minimum: Upper Thoracic
# 0   -3.949188
# 1    1.414292
# 2   -7.926120
# Name: 0, dtype: float64
# -3.4870057915038366 3.827186405057633
# 3    -3.889262
# 4   -10.493957
# Name: 0, dtype: float64
# -7.191609190886995 3.3023474832744046
# 5     3.187104
# 6   -10.195586
# 7    -7.926120
# Name: 0, dtype: float64
# -4.978200839552127 5.847607830586286
# 8   -4.48218
# 9    3.94117
# Name: 0, dtype: float64
# -0.2705047372001752 4.211674791785825
#   Gender   Size  Kinematic
# 0  women  small  -3.949188
# 1  women  small   1.414292
# 2  women  small  -7.926120
# 3  women  large  -3.889262
# 4  women  large -10.493957
# 5    men  small   3.187104
# 6    men  small -10.195586
# 7    men  small  -7.926120
# 8    men  large  -4.482180
# 9    men  large   3.941170
#                        sum_sq   df         F    PR(>F)
# C(Gender)            8.777111  1.0  0.258387  0.629374
# C(Size)              0.603717  1.0  0.017773  0.898304
# C(Gender):C(Size)   42.460070  1.0  1.249971  0.306314
# Residual           203.813026  6.0       NaN       NaN
#
# Minimum: Lower Thoracic
# 0    -1.672188
# 1    -0.950492
# 2    10.570189
# Name: 1, dtype: float64
# 2.649169467032459 5.608750390010076
# 3     0.348139
# 4   -13.607154
# Name: 1, dtype: float64
# -6.629507708437383 6.977646351359817
# 5   -11.354048
# 6    -7.554602
# 7    10.570189
# Name: 1, dtype: float64
# -2.779487027068867 9.56623678535611
# 8   -10.792405
# 9    -2.318891
# Name: 1, dtype: float64
# -6.555648170180875 4.236757022551425
#   Gender   Size  Kinematic
# 0  women  small  -1.672188
# 1  women  small  -0.950492
# 2  women  small  10.570189
# 3  women  large   0.348139
# 4  women  large -13.607154
# 5    men  small -11.354048
# 6    men  small  -7.554602
# 7    men  small  10.570189
# 8    men  large -10.792405
# 9    men  large  -2.318891
#                        sum_sq   df         F    PR(>F)
# C(Gender)           26.044313  1.0  0.311170  0.597145
# C(Size)            102.257282  1.0  1.221741  0.311360
# C(Gender):C(Size)   18.166610  1.0  0.217049  0.657730
# Residual           502.188219  6.0       NaN       NaN
#
# Minimum: Lumbar
# 0   -1.101256
# 1   -4.557675
# 2    1.803531
# Name: 2, dtype: float64
# -1.2851333931740199 2.6002043596452378
# 3   -0.679084
# 4   -7.175073
# Name: 2, dtype: float64
# -3.927078280944599 3.247994645539441
# 5   -1.693249
# 6    3.882191
# 7    1.803531
# Name: 2, dtype: float64
# 1.3308241165109267 2.3005754101340665
# 8    -5.259731
# 9   -12.613135
# Name: 2, dtype: float64
# -8.936432948690845 3.6767022873619553
#   Gender   Size  Kinematic
# 0  women  small  -1.101256
# 1  women  small  -4.557675
# 2  women  small   1.803531
# 3  women  large  -0.679084
# 4  women  large  -7.175073
# 5    men  small  -1.693249
# 6    men  small   3.882191
# 7    men  small   1.803531
# 8    men  large  -5.259731
# 9    men  large -12.613135
#                       sum_sq   df         F    PR(>F)
# C(Gender)           0.471253  1.0  0.033543  0.860715
# C(Size)            99.988497  1.0  7.116927  0.037138
# C(Gender):C(Size)  34.887231  1.0  2.483185  0.166139
# Residual           84.296348  6.0       NaN       NaN
#
# Maximum: Upper Thoracic
# 0    5.389987
# 1    9.487755
# 2    3.906906
# Name: 0, dtype: float64
# 6.261549237359763 2.3602521989564833
# 3   -0.013726
# 4    6.773142
# Name: 0, dtype: float64
# 3.37970842503603 3.3934340306583204
# 5    13.101876
# 6    -5.086574
# 7     3.906906
# Name: 0, dtype: float64
# 3.974069313735466 7.425555349159563
# 8    -1.011567
# 9    22.716701
# Name: 0, dtype: float64
# 10.852566880828954 11.864134136495045
#   Gender   Size  Kinematic
# 0  women  small   5.389987
# 1  women  small   9.487755
# 2  women  small   3.906906
# 3  women  large  -0.013726
# 4  women  large   6.773142
# 5    men  small  13.101876
# 6    men  small  -5.086574
# 7    men  small   3.906906
# 8    men  large  -1.011567
# 9    men  large  22.716701
#                        sum_sq   df         F    PR(>F)
# C(Gender)            6.533937  1.0  0.080554  0.786088
# C(Size)              9.583959  1.0  0.118156  0.742768
# C(Gender):C(Size)   57.158523  1.0  0.704682  0.433382
# Residual           486.675135  6.0       NaN       NaN
#
# Maximum: Lower Thoracic
# 0     7.807985
# 1     5.741588
# 2    24.835270
# Name: 1, dtype: float64
# 12.794947532146834 8.555486142117806
# 3    7.327713
# 4    5.728046
# Name: 1, dtype: float64
# 6.52787948732416 0.7998338829294198
# 5     4.486879
# 6     0.056156
# 7    24.835270
# Name: 1, dtype: float64
# 9.792768339977309 10.789360738196761
# 8    -4.477507
# 9    12.639948
# Name: 1, dtype: float64
# 4.081220717638059 8.55872766260334
#   Gender   Size  Kinematic
# 0  women  small   7.807985
# 1  women  small   5.741588
# 2  women  small  24.835270
# 3  women  large   7.327713
# 4  women  large   5.728046
# 5    men  small   4.486879
# 6    men  small   0.056156
# 7    men  small  24.835270
# 8    men  large  -4.477507
# 9    men  large  12.639948
#                        sum_sq   df         F    PR(>F)
# C(Gender)           19.320597  1.0  0.161768  0.701470
# C(Size)             86.092340  1.0  0.720837  0.428438
# C(Gender):C(Size)    0.185162  1.0  0.001550  0.969869
# Residual           716.603052  6.0       NaN       NaN
#
# Maximum: Lumbar
# 0    4.055025
# 1    2.054845
# 2    5.812621
# Name: 2, dtype: float64
# 3.9741638460674302 1.5351708115075609
# 3    6.438218
# 4    1.128610
# Name: 2, dtype: float64
# 3.7834138965450146 2.654804137740295
# 5     4.944337
# 6    10.491234
# 7     5.812621
# Name: 2, dtype: float64
# 7.082730614201459 2.436103251494998
# 8    5.698657
# 9    4.771910
# Name: 2, dtype: float64
# 5.23528314369115 0.46337342827552996
#   Gender   Size  Kinematic
# 0  women  small   4.055025
# 1  women  small   2.054845
# 2  women  small   5.812621
# 3  women  large   6.438218
# 4  women  large   1.128610
# 5    men  small   4.944337
# 6    men  small  10.491234
# 7    men  small   5.812621
# 8    men  large   5.698657
# 9    men  large   4.771910
#                       sum_sq   df         F    PR(>F)
# C(Gender)          14.955917  1.0  2.277583  0.181992
# C(Size)             2.492549  1.0  0.379581  0.560459
# C(Gender):C(Size)   1.646788  1.0  0.250783  0.634361
# Residual           39.399445  6.0       NaN       NaN
#
# Mean: Upper Thoracic
# 0    1.052777
# 1    5.108474
# 2   -2.446588
# Name: 0, dtype: float64
# 1.2382211404991603 3.0871273572416777
# 3   -2.094176
# 4   -1.515717
# Name: 0, dtype: float64
# -1.8049462563876 0.28922973064971
# 5    6.809853
# 6   -7.390651
# 7   -2.446588
# Name: 0, dtype: float64
# -1.0091285718589902 5.88576235588345
# 8    -2.773576
# 9    11.994116
# Name: 0, dtype: float64
# 4.610270206275185 7.383845711826115
#   Gender   Size  Kinematic
# 0  women  small   1.052777
# 1  women  small   5.108474
# 2  women  small  -2.446588
# 3  women  large  -2.094176
# 4  women  large  -1.515717
# 5    men  small   6.809853
# 6    men  small  -7.390651
# 7    men  small  -2.446588
# 8    men  large  -2.773576
# 9    men  large  11.994116
#                        sum_sq   df         F    PR(>F)
# C(Gender)            3.706842  1.0  0.092009  0.771881
# C(Size)              3.982181  1.0  0.098843  0.763867
# C(Gender):C(Size)   45.024032  1.0  1.117558  0.331139
# Residual           241.727324  6.0       NaN       NaN
#
# Mean: Lower Thoracic
# 0     4.443702
# 1     1.754465
# 2    15.991596
# Name: 1, dtype: float64
# 7.396587566215399 6.175955132140066
# 3    3.976406
# 4   -2.983276
# Name: 1, dtype: float64
# 0.49656470860145485 3.4798409036323648
# 5    -3.534318
# 6    -3.289199
# 7    15.991596
# Name: 1, dtype: float64
# 3.05602649442906 9.14737662624929
# 8   -7.658666
# 9    4.104135
# Name: 1, dtype: float64
# -1.7772655870198597 5.881400776056839
#   Gender   Size  Kinematic
# 0  women  small   4.443702
# 1  women  small   1.754465
# 2  women  small  15.991596
# 3  women  large   3.976406
# 4  women  large  -2.983276
# 5    men  small  -3.534318
# 6    men  small  -3.289199
# 7    men  small  15.991596
# 8    men  large  -7.658666
# 9    men  large   4.104135
#                        sum_sq   df         F    PR(>F)
# C(Gender)           30.868184  1.0  0.403637  0.548665
# C(Size)             82.602408  1.0  1.080120  0.338727
# C(Gender):C(Size)    2.562826  1.0  0.033512  0.860778
# Residual           458.851098  6.0       NaN       NaN
#
# Mean: Lumbar
# 0    1.326661
# 1   -1.503165
# 2    4.020324
# Name: 2, dtype: float64
# 1.2812735216593498 2.2551833147812896
# 3    2.435732
# 4   -2.409748
# Name: 2, dtype: float64
# 0.012991781307299943 2.4227401140778904
# 5    1.491480
# 6    7.369295
# 7    4.020324
# Name: 2, dtype: float64
# 4.293699842228617 2.407381294455349
# 8    0.199038
# 9   -4.427216
# Name: 2, dtype: float64
# -2.1140890786252093 2.3131267254775905
#   Gender   Size  Kinematic
# 0  women  small   1.326661
# 1  women  small  -1.503165
# 2  women  small   4.020324
# 3  women  large   2.435732
# 4  women  large  -2.409748
# 5    men  small   1.491480
# 6    men  small   7.369295
# 7    men  small   4.020324
# 8    men  large   0.199038
# 9    men  large  -4.427216
#                       sum_sq   df         F    PR(>F)
# C(Gender)           2.287821  1.0  0.249198  0.635413
# C(Size)            35.353236  1.0  3.850803  0.097378
# C(Gender):C(Size)  15.848720  1.0  1.726300  0.236882
# Residual           55.084459  6.0       NaN       NaN

# %%
print('Mean')
box_whisker(mean_walk_axi)
print('Min')
box_whisker(min_walk_axi)
print('Max')
box_whisker(max_walk_axi)
# Out:
# Mean
# Min
# Max
