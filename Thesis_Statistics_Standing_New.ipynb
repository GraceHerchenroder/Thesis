# %% [markdown]
# <a href="https://colab.research.google.com/github/GraceHerchenroder/Thesis/blob/main/Thesis_Statistics_Standing_New.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# Importing libraries
import pandas as pd
import numpy as np
import statsmodels.api as sm
from statsmodels.formula.api import ols
from scipy import stats
from statsmodels.stats.multitest import multipletests
import matplotlib.pyplot as plt

# %%
# Performing two-way ANOVA
def statAnova_ut(kinematic_data):
  dataframe = pd.DataFrame({'Gender': np.repeat(['women', 'men'], 5),
                          'Size': ['small', 'small', 'small', 'large', 'large', 'small', 'small', 'small', 'large', 'large'],
                          'Kinematic': kinematic_data[0][:]})
  group_1_mean = np.mean(kinematic_data[0][:3])
  group_1_sd = np.std(kinematic_data[0][:3])
  group_2_mean = np.mean(kinematic_data[0][3:5])
  group_2_sd = np.std(kinematic_data[0][3:5])
  group_3_mean = np.mean(kinematic_data[0][5:8])
  group_3_sd = np.std(kinematic_data[0][5:8])
  group_4_mean = np.mean(kinematic_data[0][8:])
  group_4_sd = np.std(kinematic_data[0][8:])
  print(kinematic_data[0][:3])
  print(group_1_mean, group_1_sd)
  print(kinematic_data[0][3:5])
  print(group_2_mean, group_2_sd)
  print(kinematic_data[0][5:8])
  print(group_3_mean, group_3_sd)
  print(kinematic_data[0][8:])
  print(group_4_mean, group_4_sd)
  print(dataframe)
  model = ols('Kinematic ~ C(Gender) + C(Size) + C(Gender):C(Size)', data=dataframe).fit()
  result = sm.stats.anova_lm(model, typ=2)
  return result

def statAnova_lt(kinematic_data):
  dataframe = pd.DataFrame({'Gender': np.repeat(['women', 'men'], 5),
                          'Size': ['small', 'small', 'small', 'large', 'large', 'small', 'small', 'small', 'large', 'large'],
                          'Kinematic': kinematic_data[1][:]})
  group_1_mean = np.mean(kinematic_data[1][:3])
  group_1_sd = np.std(kinematic_data[1][:3])
  group_2_mean = np.mean(kinematic_data[1][3:5])
  group_2_sd = np.std(kinematic_data[1][3:5])
  group_3_mean = np.mean(kinematic_data[1][5:8])
  group_3_sd = np.std(kinematic_data[1][5:8])
  group_4_mean = np.mean(kinematic_data[1][8:])
  group_4_sd = np.std(kinematic_data[1][8:])
  print(kinematic_data[1][:3])
  print(group_1_mean, group_1_sd)
  print(kinematic_data[1][3:5])
  print(group_2_mean, group_2_sd)
  print(kinematic_data[1][5:8])
  print(group_3_mean, group_3_sd)
  print(kinematic_data[1][8:])
  print(group_4_mean, group_4_sd)
  print(dataframe)
  model = ols('Kinematic ~ C(Gender) + C(Size) + C(Gender):C(Size)', data=dataframe).fit()
  result = sm.stats.anova_lm(model, typ=2)
  return result

def statAnova_lum(kinematic_data):
  dataframe = pd.DataFrame({'Gender': np.repeat(['women', 'men'], 5),
                          'Size': ['small', 'small', 'small', 'large', 'large', 'small', 'small', 'small', 'large', 'large'],
                          'Kinematic': kinematic_data[2][:]})
  group_1_mean = np.mean(kinematic_data[2][:3])
  group_1_sd = np.std(kinematic_data[2][:3])
  group_2_mean = np.mean(kinematic_data[2][3:5])
  group_2_sd = np.std(kinematic_data[2][3:5])
  group_3_mean = np.mean(kinematic_data[2][5:8])
  group_3_sd = np.std(kinematic_data[2][5:8])
  group_4_mean = np.mean(kinematic_data[2][8:])
  group_4_sd = np.std(kinematic_data[2][8:])
  print(kinematic_data[2][:3])
  print(group_1_mean, group_1_sd)
  print(kinematic_data[2][3:5])
  print(group_2_mean, group_2_sd)
  print(kinematic_data[2][5:8])
  print(group_3_mean, group_3_sd)
  print(kinematic_data[2][8:])
  print(group_4_mean, group_4_sd)
  print(dataframe)
  model = ols('Kinematic ~ C(Gender) + C(Size) + C(Gender):C(Size)', data=dataframe).fit()
  result = sm.stats.anova_lm(model, typ=2)
  return result

def box_whisker(kinematic_data):
   small_men_data_ut = kinematic_data[0][8:]
   large_men_data_ut = kinematic_data[0][5:8]
   small_women_data_ut = kinematic_data[0][:3]
   large_women_data_ut = kinematic_data[0][3:5]
   small_men_data_lt = kinematic_data[1][8:]
   large_men_data_lt = kinematic_data[1][5:8]
   small_women_data_lt = kinematic_data[1][:3]
   large_women_data_lt = kinematic_data[1][3:5]
   small_men_data_lum = kinematic_data[2][8:]
   large_men_data_lum = kinematic_data[2][5:8]
   small_women_data_lum = kinematic_data[2][:3]
   large_women_data_lum = kinematic_data[2][3:5]
   fig, ax = plt.subplots(3, 2, figsize=(6, 10))
   ax[0][0].boxplot([small_men_data_ut, large_men_data_ut], labels = ['small', 'large'])
   ax[0][0].set_title('Men')
   ax[0][0].set_ylabel('Upper Thoracic')
   ax[0][1].boxplot([small_women_data_ut, large_women_data_ut], labels = ['small', 'large'])
   ax[0][1].set_title('Women')
   ax[1][0].boxplot([small_men_data_lt, large_men_data_lt], labels = ['small', 'large'])
   ax[1][0].set_title('Men')
   ax[1][0].set_ylabel('Lower Thoracic')
   ax[1][1].boxplot([small_women_data_lt, large_women_data_lt], labels = ['small', 'large'])
   ax[1][1].set_title('Women')
   ax[2][0].boxplot([small_men_data_lum, large_men_data_lum], labels = ['small', 'large'])
   ax[2][0].set_title('Men')
   ax[2][0].set_ylabel('Lumbar')
   ax[2][1].boxplot([small_women_data_lum, large_women_data_lum], labels = ['small', 'large'])
   ax[2][1].set_title('Women')
   plt.show()

# %%
# Follow Up analysis: Significant
def significant_ut(kinematic_data, p_values):
  [reject, p_corrected] = multipletests(p_values, method = 'bonferroni')
  small_men_data = kinematic_data[0][8:]
  large_men_data = kinematic_data[0][5:8]
  small_women_data = kinematic_data[0][:3]
  large_women_data = kinematic_data[0][3:5]

  [stat_small, p_small] = stats.ttest_ind(small_men_data, small_women_data);
  [stat_large, p_large] = stats.ttest_ind(large_men_data, large_women_data);
  [stat_women, p_women] = stats.ttest_ind(small_women_data, large_women_data);
  [stat_men, p_men] = stats.ttest_ind(small_men_data, large_men_data);

  return [p_corrected, p_small, p_large, p_women, p_men]

def significant_lt(kinematic_data, p_values):
  [reject, p_corrected] = multipletests(p_values, method = 'bonferroni')
  small_men_data = kinematic_data[1][8:]
  large_men_data = kinematic_data[1][5:8]
  small_women_data = kinematic_data[1][:3]
  large_women_data = kinematic_data[1][3:5]

  [stat_small, p_small] = stats.ttest_ind(small_men_data, small_women_data);
  [stat_large, p_large] = stats.ttest_ind(large_men_data, large_women_data);
  [stat_women, p_women] = stats.ttest_ind(small_women_data, large_women_data);
  [stat_men, p_men] = stats.ttest_ind(small_men_data, large_men_data);

  return [p_corrected, p_small, p_large, p_women, p_men]

def significant_lum(kinematic_data, p_values):
  [reject, p_corrected] = multipletests(p_values, method = 'bonferroni')
  small_men_data = kinematic_data[2][8:]
  large_men_data = kinematic_data[2][5:8]
  small_women_data = kinematic_data[2][:3]
  large_women_data = kinematic_data[2][3:5]

  [stat_small, p_small] = stats.ttest_ind(small_men_data, small_women_data);
  [stat_large, p_large] = stats.ttest_ind(large_men_data, large_women_data);
  [stat_women, p_women] = stats.ttest_ind(small_women_data, large_women_data);
  [stat_men, p_men] = stats.ttest_ind(small_men_data, large_men_data);

  return [p_corrected, p_small, p_large, p_women, p_men]

# %%
# Flexion
print('\033[1mFlexion\033[0m')
print('')

# Minimums
url_min_stand_flex = 'https://raw.githubusercontent.com/GraceHerchenroder/Thesis/main/min_stand_flex.csv'
min_stand_flex = pd.read_csv(url_min_stand_flex, header = None)

print('Minimum: Upper Thoracic')
result_min_stand_flex_ut = statAnova_ut(min_stand_flex)
print(result_min_stand_flex_ut)
if result_min_stand_flex_ut['PR(>F)'][0] < 0.05:
  print('Gender: Significant')
if result_min_stand_flex_ut['PR(>F)'][1] < 0.05:
  print('Size: Significant')
if result_min_stand_flex_ut['PR(>F)'][2] < 0.05:
  result = significant_ut(min_stand_flex, result_min_stand_flex_ut['PR(>F)'])
  print('Small: ', result[1], ', Large: ', result[2], ', Women: ', result[3], ', Men: ', result[4])
  if result[1] < result[0]:
    print('Small: Significant')
  if result[2] < result[0]:
    print('Large: Significant')
  if result[3] < result[0]:
    print('Women: Significant')
  if result[4] < result[0]:
    print('Men: Significant')
print('')

print('Minimum: Lower Thoracic')
result_min_stand_flex_lt = statAnova_lt(min_stand_flex)
print(result_min_stand_flex_lt)
if result_min_stand_flex_lt['PR(>F)'][0] < 0.05:
  print('Gender: Significant')
if result_min_stand_flex_lt['PR(>F)'][1] < 0.05:
  print('Size: Significant')
if result_min_stand_flex_lt['PR(>F)'][2] < 0.05:
  result = significant_lt(min_stand_flex, result_min_stand_flex_lt['PR(>F)'])
  print('Small: ', result[1], ', Large: ', result[2], ', Women: ', result[3], ', Men: ', result[4])
  if result[1] < result[0]:
    print('Small: Significant')
  if result[2] < result[0]:
    print('Large: Significant')
  if result[3] < result[0]:
    print('Women: Significant')
  if result[4] < result[0]:
    print('Men: Significant')
print('')

print('Minimum: Lumbar')
result_min_stand_flex_lum = statAnova_lum(min_stand_flex)
print(result_min_stand_flex_lum)
if result_min_stand_flex_lum['PR(>F)'][0] < 0.05:
  print('Gender: Significant')
if result_min_stand_flex_lum['PR(>F)'][1] < 0.05:
  print('Size: Significant')
if result_min_stand_flex_lum['PR(>F)'][2] < 0.05:
  result = significant_lum(min_stand_flex, result_min_stand_flex_lum['PR(>F)'])
  print('Small: ', result[1], ', Large: ', result[2], ', Women: ', result[3], ', Men: ', result[4])
  if result[1] < result[0]:
    print('Small: Significant')
  if result[2] < result[0]:
    print('Large: Significant')
  if result[3] < result[0]:
    print('Women: Significant')
  if result[4] < result[0]:
    print('Men: Significant')
print('')

# Maximums
url_max_stand_flex = 'https://raw.githubusercontent.com/GraceHerchenroder/Thesis/main/max_stand_flex.csv'
max_stand_flex = pd.read_csv(url_max_stand_flex, header = None)

print('Maximum: Upper Thoracic')
result_max_stand_flex_ut = statAnova_ut(max_stand_flex)
print(result_max_stand_flex_ut)
if result_max_stand_flex_ut['PR(>F)'][0] < 0.05:
  print('Gender: Significant')
if result_max_stand_flex_ut['PR(>F)'][1] < 0.05:
  print('Size: Significant')
if result_max_stand_flex_ut['PR(>F)'][2] < 0.05:
  result = significant_ut(max_stand_flex, result_max_stand_flex_ut['PR(>F)'])
  print('Small: ', result[1], ', Large: ', result[2], ', Women: ', result[3], ', Men: ', result[4])
  if result[1] < result[0]:
    print('Small: Significant')
  if result[2] < result[0]:
    print('Large: Significant')
  if result[3] < result[0]:
    print('Women: Significant')
  if result[4] < result[0]:
    print('Men: Significant')
print('')

print('Maximum: Lower Thoracic')
result_max_stand_flex_lt = statAnova_lt(max_stand_flex)
print(result_max_stand_flex_lt)
if result_max_stand_flex_lt['PR(>F)'][0] < 0.05:
  print('Gender: Significant')
if result_max_stand_flex_lt['PR(>F)'][1] < 0.05:
  print('Size: Significant')
if result_max_stand_flex_lt['PR(>F)'][2] < 0.05:
  result = significant_lt(max_stand_flex, result_max_stand_flex_lt['PR(>F)'])
  print('Small: ', result[1], ', Large: ', result[2], ', Women: ', result[3], ', Men: ', result[4])
  if result[1] < result[0]:
    print('Small: Significant')
  if result[2] < result[0]:
    print('Large: Significant')
  if result[3] < result[0]:
    print('Women: Significant')
  if result[4] < result[0]:
    print('Men: Significant')
print('')

print('Maximum: Lumbar')
result_max_stand_flex_lum = statAnova_lum(max_stand_flex)
print(result_max_stand_flex_lum)
if result_max_stand_flex_lum['PR(>F)'][0] < 0.05:
  print('Gender: Significant')
if result_max_stand_flex_lum['PR(>F)'][1] < 0.05:
  print('Size: Significant')
if result_max_stand_flex_lum['PR(>F)'][2] < 0.05:
  result = significant_lum(max_stand_flex, result_max_stand_flex_lum['PR(>F)'])
  print('Small: ', result[1], ', Large: ', result[2], ', Women: ', result[3], ', Men: ', result[4])
  if result[1] < result[0]:
    print('Small: Significant')
  if result[2] < result[0]:
    print('Large: Significant')
  if result[3] < result[0]:
    print('Women: Significant')
  if result[4] < result[0]:
    print('Men: Significant')
print('')

# Means
url_mean_stand_flex = 'https://raw.githubusercontent.com/GraceHerchenroder/Thesis/main/mean_stand_flex.csv'
mean_stand_flex = pd.read_csv(url_mean_stand_flex, header = None)

print('Mean: Upper Thoracic')
result_mean_stand_flex_ut = statAnova_ut(mean_stand_flex)
print(result_mean_stand_flex_ut)
if result_mean_stand_flex_ut['PR(>F)'][0] < 0.05:
  print('Gender: Significant')
if result_mean_stand_flex_ut['PR(>F)'][1] < 0.05:
  print('Size: Significant')
if result_mean_stand_flex_ut['PR(>F)'][2] < 0.05:
  result = significant_ut(mean_stand_flex, result_mean_stand_flex_ut['PR(>F)'])
  print('Small: ', result[1], ', Large: ', result[2], ', Women: ', result[3], ', Men: ', result[4])
  if result[1] < result[0]:
    print('Small: Significant')
  if result[2] < result[0]:
    print('Large: Significant')
  if result[3] < result[0]:
    print('Women: Significant')
  if result[4] < result[0]:
    print('Men: Significant')
print('')

print('Mean: Lower Thoracic')
result_mean_stand_flex_lt = statAnova_lt(mean_stand_flex)
print(result_mean_stand_flex_lt)
if result_mean_stand_flex_lt['PR(>F)'][0] < 0.05:
  print('Gender: Significant')
if result_mean_stand_flex_lt['PR(>F)'][1] < 0.05:
  print('Size: Significant')
if result_mean_stand_flex_lt['PR(>F)'][2] < 0.05:
  result = significant_lt(mean_stand_flex, result_mean_stand_flex_lt['PR(>F)'])
  print('Small: ', result[1], ', Large: ', result[2], ', Women: ', result[3], ', Men: ', result[4])
  if result[1] < result[0]:
    print('Small: Significant')
  if result[2] < result[0]:
    print('Large: Significant')
  if result[3] < result[0]:
    print('Women: Significant')
  if result[4] < result[0]:
    print('Men: Significant')
print('')

print('Mean: Lumbar')
result_mean_stand_flex_lum = statAnova_lum(mean_stand_flex)
print(result_mean_stand_flex_lum)
if result_mean_stand_flex_lum['PR(>F)'][0] < 0.05:
  print('Gender: Significant')
if result_mean_stand_flex_lum['PR(>F)'][1] < 0.05:
  print('Size: Significant')
if result_mean_stand_flex_lum['PR(>F)'][2] < 0.05:
  result = significant_lum(mean_stand_flex, result_mean_stand_flex_lum['PR(>F)'])
  print('Small: ', result[1], ', Large: ', result[2], ', Women: ', result[3], ', Men: ', result[4])
  if result[1] < result[0]:
    print('Small: Significant')
  if result[2] < result[0]:
    print('Large: Significant')
  if result[3] < result[0]:
    print('Women: Significant')
  if result[4] < result[0]:
    print('Men: Significant')
print('')
# Out:
# Flexion
#
# Minimum: Upper Thoracic
# 0    24.415020
# 1    20.695237
# 2    21.693920
# Name: 0, dtype: float64
# 22.268058812424332 1.571925174202417
# 3    30.986102
# 4     4.659637
# Name: 0, dtype: float64
# 17.822869489177226 13.163232247813475
# 5    13.431211
# 6    13.218221
# 7    21.693920
# Name: 0, dtype: float64
# 16.1144505097251 3.9462387985678147
# 8     9.134502
# 9    17.921480
# Name: 0, dtype: float64
# 13.52799104638061 4.393489261506491
#   Gender   Size  Kinematic
# 0  women  small  24.415020
# 1  women  small  20.695237
# 2  women  small  21.693920
# 3  women  large  30.986102
# 4  women  large   4.659637
# 5    men  small  13.431211
# 6    men  small  13.218221
# 7    men  small  21.693920
# 8    men  large   9.134502
# 9    men  large  17.921480
#                        sum_sq   df         F    PR(>F)
# C(Gender)           73.173398  1.0  0.999459  0.356038
# C(Size)             29.666451  1.0  0.405207  0.547913
# C(Gender):C(Size)    2.072926  1.0  0.028314  0.871902
# Residual           439.278110  6.0       NaN       NaN
#
# Minimum: Lower Thoracic
# 0    21.260672
# 1    17.285800
# 2    25.142554
# Name: 1, dtype: float64
# 21.229675447534632 3.2075810239052376
# 3    18.241546
# 4    21.754265
# Name: 1, dtype: float64
# 19.997905256904602 1.7563595308853
# 5    17.094268
# 6   -16.022645
# 7    25.142554
# Name: 1, dtype: float64
# 8.738059114639332 17.814096692181593
# 8    34.126978
# 9    23.069126
# Name: 1, dtype: float64
# 28.5980524623578 5.528925975842801
#   Gender   Size  Kinematic
# 0  women  small  21.260672
# 1  women  small  17.285800
# 2  women  small  25.142554
# 3  women  large  18.241546
# 4  women  large  21.754265
# 5    men  small  17.094268
# 6    men  small -16.022645
# 7    men  small  25.142554
# 8    men  large  34.126978
# 9    men  large  23.069126
#                         sum_sq   df         F    PR(>F)
# C(Gender)            41.105756  1.0  0.234845  0.645137
# C(Size)             208.206419  1.0  1.189525  0.317276
# C(Gender):C(Size)   266.917493  1.0  1.524953  0.263034
# Residual           1050.199493  6.0       NaN       NaN
#
# Minimum: Lumbar
# 0   -33.695735
# 1    -9.016901
# 2   -31.692129
# Name: 2, dtype: float64
# -24.80158822624759 11.191391759105409
# 3   -37.394527
# 4    -9.086446
# Name: 2, dtype: float64
# -23.240486528583816 14.154040789433786
# 5   -22.898844
# 6   -35.359341
# 7   -31.692129
# Name: 2, dtype: float64
# -29.9834381974988 5.228493358019529
# 8   -41.298500
# 9   -29.432846
# Name: 2, dtype: float64
# -35.3656730417954 5.9328271250341995
#   Gender   Size  Kinematic
# 0  women  small -33.695735
# 1  women  small  -9.016901
# 2  women  small -31.692129
# 3  women  large -37.394527
# 4  women  large  -9.086446
# 5    men  small -22.898844
# 6    men  small -35.359341
# 7    men  small -31.692129
# 8    men  large -41.298500
# 9    men  large -29.432846
#                        sum_sq   df         F    PR(>F)
# C(Gender)          158.371548  1.0  1.023046  0.350834
# C(Size)              8.760635  1.0  0.056592  0.819882
# C(Gender):C(Size)   28.925953  1.0  0.186855  0.680650
# Residual           928.823794  6.0       NaN       NaN
#
# Maximum: Upper Thoracic
# 0    26.730293
# 1    22.708002
# 2    23.312118
# Name: 0, dtype: float64
# 24.250137645958432 1.770991435264893
# 3    32.718195
# 4     6.316629
# Name: 0, dtype: float64
# 19.51741177641296 13.20078291472784
# 5    16.656277
# 6    14.363399
# 7    23.312118
# Name: 0, dtype: float64
# 18.11059802197253 3.7952758001281524
# 8    10.784908
# 9    19.160687
# Name: 0, dtype: float64
# 14.97279737809485 4.187889695264551
#   Gender   Size  Kinematic
# 0  women  small  26.730293
# 1  women  small  22.708002
# 2  women  small  23.312118
# 3  women  large  32.718195
# 4  women  large   6.316629
# 5    men  small  16.656277
# 6    men  small  14.363399
# 7    men  small  23.312118
# 8    men  large  10.784908
# 9    men  large  19.160687
#                        sum_sq   df         F    PR(>F)
# C(Gender)           75.668168  1.0  1.040780  0.347000
# C(Size)             37.167113  1.0  0.511216  0.501473
# C(Gender):C(Size)    1.526272  1.0  0.020993  0.889542
# Residual           436.219767  6.0       NaN       NaN
#
# Maximum: Lower Thoracic
# 0    24.421164
# 1    20.479471
# 2    27.407197
# Name: 1, dtype: float64
# 24.102610557691964 2.83718829994545
# 3    22.912772
# 4    23.697350
# Name: 1, dtype: float64
# 23.30506108373505 0.39228872115455005
# 5    19.123327
# 6    -8.176542
# 7    27.407197
# Name: 1, dtype: float64
# 12.78466049890657 15.202733151199006
# 8    36.310887
# 9    25.598017
# Name: 1, dtype: float64
# 30.9544522924189 5.356435055862802
#   Gender   Size  Kinematic
# 0  women  small  24.421164
# 1  women  small  20.479471
# 2  women  small  27.407197
# 3  women  large  22.912772
# 4  women  large  23.697350
# 5    men  small  19.123327
# 6    men  small  -8.176542
# 7    men  small  27.407197
# 8    men  large  36.310887
# 9    men  large  25.598017
#                        sum_sq   df         F    PR(>F)
# C(Gender)           34.801155  1.0  0.269356  0.622343
# C(Size)            181.076882  1.0  1.401508  0.281242
# C(Gender):C(Size)  215.856021  1.0  1.670693  0.243707
# Residual           775.208772  6.0       NaN       NaN
#
# Maximum: Lumbar
# 0   -30.413921
# 1    -6.063476
# 2   -29.667730
# Name: 2, dtype: float64
# -22.0483754014934 11.307135436159832
# 3   -29.750143
# 4    -1.948900
# Name: 2, dtype: float64
# -15.84952154679921 13.900621357259691
# 5   -18.267232
# 6   -31.942465
# 7   -29.667730
# Name: 2, dtype: float64
# -26.62580891907143 5.982918204426923
# 8   -38.695569
# 9   -26.717893
# Name: 2, dtype: float64
# -32.7067312328764 5.988838065357898
#   Gender   Size  Kinematic
# 0  women  small -30.413921
# 1  women  small  -6.063476
# 2  women  small -29.667730
# 3  women  large -29.750143
# 4  women  large  -1.948900
# 5    men  small -18.267232
# 6    men  small -31.942465
# 7    men  small -29.667730
# 8    men  large -38.695569
# 9    men  large -26.717893
#                        sum_sq   df         F    PR(>F)
# C(Gender)          225.119123  1.0  1.423113  0.277922
# C(Size)              0.008345  1.0  0.000053  0.994440
# C(Gender):C(Size)   90.475742  1.0  0.571951  0.478117
# Residual           949.126777  6.0       NaN       NaN
#
# Mean: Upper Thoracic
# 0    25.457734
# 1    21.750887
# 2    22.317071
# Name: 0, dtype: float64
# 23.175230738218698 1.630441020075073
# 3    32.329335
# 4     6.003720
# Name: 0, dtype: float64
# 19.166527882212215 13.162807390775784
# 5    15.551056
# 6    13.927177
# 7    22.317071
# Name: 0, dtype: float64
# 17.2651014617701 3.633276155416162
# 8    10.030439
# 9    18.626363
# Name: 0, dtype: float64
# 14.3284006569023 4.29796187644
#   Gender   Size  Kinematic
# 0  women  small  25.457734
# 1  women  small  21.750887
# 2  women  small  22.317071
# 3  women  large  32.329335
# 4  women  large   6.003720
# 5    men  small  15.551056
# 6    men  small  13.927177
# 7    men  small  22.317071
# 8    men  large  10.030439
# 9    men  large  18.626363
#                        sum_sq   df         F    PR(>F)
# C(Gender)           75.112404  1.0  1.045549  0.345980
# C(Size)             28.943179  1.0  0.402883  0.549027
# C(Gender):C(Size)    0.689513  1.0  0.009598  0.925148
# Residual           431.041050  6.0       NaN       NaN
#
# Mean: Lower Thoracic
# 0    22.581218
# 1    18.684371
# 2    26.110094
# Name: 1, dtype: float64
# 22.458561376630637 3.0327791121769123
# 3    21.073939
# 4    22.662703
# Name: 1, dtype: float64
# 21.8683211190926 0.7943820914164998
# 5    18.047358
# 6   -10.778599
# 7    26.110094
# Name: 1, dtype: float64
# 11.126284402620568 15.834979744279407
# 8    35.687483
# 9    24.702573
# Name: 1, dtype: float64
# 30.1950279697363 5.492454700345201
#   Gender   Size  Kinematic
# 0  women  small  22.581218
# 1  women  small  18.684371
# 2  women  small  26.110094
# 3  women  large  21.073939
# 4  women  large  22.662703
# 5    men  small  18.047358
# 6    men  small -10.778599
# 7    men  small  26.110094
# 8    men  large  35.687483
# 9    men  large  24.702573
#                        sum_sq   df         F    PR(>F)
# C(Gender)           30.079412  1.0  0.214488  0.659595
# C(Size)            204.873051  1.0  1.460893  0.272255
# C(Gender):C(Size)  231.885387  1.0  1.653511  0.245875
# Residual           841.429201  6.0       NaN       NaN
#
# Mean: Lumbar
# 0   -31.907067
# 1    -7.500107
# 2   -30.514393
# Name: 2, dtype: float64
# -23.307188891365257 11.19174567011801
# 3   -34.389253
# 4    -5.441515
# Name: 2, dtype: float64
# -19.91538400467886 14.47386869686114
# 5   -21.648066
# 6   -34.095941
# 7   -30.514393
# Name: 2, dtype: float64
# -28.752800040733234 5.232259115966602
# 8   -39.769739
# 9   -28.066808
# Name: 2, dtype: float64
# -33.918273319225904 5.8514654688117
#   Gender   Size  Kinematic
# 0  women  small -31.907067
# 1  women  small  -7.500107
# 2  women  small -30.514393
# 3  women  large -34.389253
# 4  women  large  -5.441515
# 5    men  small -21.648066
# 6    men  small -34.095941
# 7    men  small -30.514393
# 8    men  large -39.769739
# 9    men  large -28.066808
#                        sum_sq   df         F    PR(>F)
# C(Gender)          196.626725  1.0  1.247948  0.306671
# C(Size)              1.887540  1.0  0.011980  0.916413
# C(Gender):C(Size)   43.936206  1.0  0.278854  0.616405
# Residual           945.360166  6.0       NaN       NaN

# %%
print('Mean')
box_whisker(mean_stand_flex)
print('Min')
box_whisker(min_stand_flex)
print('Max')
box_whisker(max_stand_flex)
# Out:
# Mean
# Min
# Max

# %%
# Lateral Flexion
print('\033[1mLateral Flexion\033[0m')
print('')

# Minimums
url_min_stand_lat = 'https://raw.githubusercontent.com/GraceHerchenroder/Thesis/main/min_stand_lat.csv'
min_stand_lat = pd.read_csv(url_min_stand_lat, header = None)

print('Minimum: Upper Thoracic')
result_min_stand_lat_ut = statAnova_ut(min_stand_lat)
print(result_min_stand_lat_ut)
if result_min_stand_lat_ut['PR(>F)'][0] < 0.05:
  print('Gender: Significant')
if result_min_stand_lat_ut['PR(>F)'][1] < 0.05:
  print('Size: Significant')
if result_min_stand_lat_ut['PR(>F)'][2] < 0.05:
  result = significant_ut(min_stand_lat, result_min_stand_lat_ut['PR(>F)'])
  print('Small: ', result[1], ', Large: ', result[2], ', Women: ', result[3], ', Men: ', result[4])
  if result[1] < result[0]:
    print('Small: Significant')
  if result[2] < result[0]:
    print('Large: Significant')
  if result[3] < result[0]:
    print('Women: Significant')
  if result[4] < result[0]:
    print('Men: Significant')
print('')

print('Minimum: Lower Thoracic')
result_min_stand_lat_lt = statAnova_lt(min_stand_lat)
print(result_min_stand_lat_lt)
if result_min_stand_lat_lt['PR(>F)'][0] < 0.05:
  print('Gender: Significant')
if result_min_stand_lat_lt['PR(>F)'][1] < 0.05:
  print('Size: Significant')
if result_min_stand_lat_lt['PR(>F)'][2] < 0.05:
  result = significant_lt(min_stand_lat, result_min_stand_lat_lt['PR(>F)'])
  print('Small: ', result[1], ', Large: ', result[2], ', Women: ', result[3], ', Men: ', result[4])
  if result[1] < result[0]:
    print('Small: Significant')
  if result[2] < result[0]:
    print('Large: Significant')
  if result[3] < result[0]:
    print('Women: Significant')
  if result[4] < result[0]:
    print('Men: Significant')
print('')

print('Minimum: Lumbar')
result_min_stand_lat_lum = statAnova_lum(min_stand_lat)
print(result_min_stand_lat_lum)
if result_min_stand_lat_lum['PR(>F)'][0] < 0.05:
  print('Gender: Significant')
if result_min_stand_lat_lum['PR(>F)'][1] < 0.05:
  print('Size: Significant')
if result_min_stand_lat_lum['PR(>F)'][2] < 0.05:
  result = significant_lum(min_stand_lat, result_min_stand_lat_lum['PR(>F)'])
  print('Small: ', result[1], ', Large: ', result[2], ', Women: ', result[3], ', Men: ', result[4])
  if result[1] < result[0]:
    print('Small: Significant')
  if result[2] < result[0]:
    print('Large: Significant')
  if result[3] < result[0]:
    print('Women: Significant')
  if result[4] < result[0]:
    print('Men: Significant')
print('')

# Maximums
url_max_stand_lat = 'https://raw.githubusercontent.com/GraceHerchenroder/Thesis/main/max_stand_lat.csv'
max_stand_lat = pd.read_csv(url_max_stand_lat, header = None)

print('Maximum: Upper Thoracic')
result_max_stand_lat_ut = statAnova_ut(max_stand_lat)
print(result_max_stand_lat_ut)
if result_max_stand_lat_ut['PR(>F)'][0] < 0.05:
  print('Gender: Significant')
if result_max_stand_lat_ut['PR(>F)'][1] < 0.05:
  print('Size: Significant')
if result_max_stand_lat_ut['PR(>F)'][2] < 0.05:
  result = significant_ut(max_stand_lat, result_max_stand_lat_ut['PR(>F)'])
  print('Small: ', result[1], ', Large: ', result[2], ', Women: ', result[3], ', Men: ', result[4])
  if result[1] < result[0]:
    print('Small: Significant')
  if result[2] < result[0]:
    print('Large: Significant')
  if result[3] < result[0]:
    print('Women: Significant')
  if result[4] < result[0]:
    print('Men: Significant')
print('')

print('Maximum: Lower Thoracic')
result_max_stand_lat_lt = statAnova_lt(max_stand_lat)
print(result_max_stand_lat_lt)
if result_max_stand_lat_lt['PR(>F)'][0] < 0.05:
  print('Gender: Significant')
if result_max_stand_lat_lt['PR(>F)'][1] < 0.05:
  print('Size: Significant')
if result_max_stand_lat_lt['PR(>F)'][2] < 0.05:
  result = significant_lt(max_stand_lat, result_max_stand_lat_lt['PR(>F)'])
  print('Small: ', result[1], ', Large: ', result[2], ', Women: ', result[3], ', Men: ', result[4])
  if result[1] < result[0]:
    print('Small: Significant')
  if result[2] < result[0]:
    print('Large: Significant')
  if result[3] < result[0]:
    print('Women: Significant')
  if result[4] < result[0]:
    print('Men: Significant')
print('')

print('Maximum: Lumbar')
result_max_stand_lat_lum = statAnova_lum(max_stand_lat)
print(result_max_stand_lat_lum)
if result_max_stand_lat_lum['PR(>F)'][0] < 0.05:
  print('Gender: Significant')
if result_max_stand_lat_lum['PR(>F)'][1] < 0.05:
  print('Size: Significant')
if result_max_stand_lat_lum['PR(>F)'][2] < 0.05:
  result = significant_lum(max_stand_lat, result_max_stand_lat_lum['PR(>F)'])
  print('Small: ', result[1], ', Large: ', result[2], ', Women: ', result[3], ', Men: ', result[4])
  if result[1] < result[0]:
    print('Small: Significant')
  if result[2] < result[0]:
    print('Large: Significant')
  if result[3] < result[0]:
    print('Women: Significant')
  if result[4] < result[0]:
    print('Men: Significant')
print('')

# Means
url_mean_stand_lat = 'https://raw.githubusercontent.com/GraceHerchenroder/Thesis/main/mean_stand_lat.csv'
mean_stand_lat = pd.read_csv(url_mean_stand_lat, header = None)

print('Mean: Upper Thoracic')
result_mean_stand_lat_ut = statAnova_ut(mean_stand_lat)
print(result_mean_stand_lat_ut)
if result_mean_stand_lat_ut['PR(>F)'][0] < 0.05:
  print('Gender: Significant')
if result_mean_stand_lat_ut['PR(>F)'][1] < 0.05:
  print('Size: Significant')
if result_mean_stand_flex_ut['PR(>F)'][2] < 0.05:
  result = significant_ut(mean_stand_lat, result_mean_stand_lat_ut['PR(>F)'])
  print('Small: ', result[1], ', Large: ', result[2], ', Women: ', result[3], ', Men: ', result[4])
  if result[1] < result[0]:
    print('Small: Significant')
  if result[2] < result[0]:
    print('Large: Significant')
  if result[3] < result[0]:
    print('Women: Significant')
  if result[4] < result[0]:
    print('Men: Significant')
print('')

print('Mean: Lower Thoracic')
result_mean_stand_lat_lt = statAnova_lt(mean_stand_lat)
print(result_mean_stand_lat_lt)
if result_mean_stand_lat_lt['PR(>F)'][0] < 0.05:
  print('Gender: Significant')
if result_mean_stand_lat_lt['PR(>F)'][1] < 0.05:
  print('Size: Significant')
if result_mean_stand_lat_lt['PR(>F)'][2] < 0.05:
  result = significant_lt(mean_stand_lat, result_mean_stand_lat_lt['PR(>F)'])
  print('Small: ', result[1], ', Large: ', result[2], ', Women: ', result[3], ', Men: ', result[4])
  if result[1] < result[0]:
    print('Small: Significant')
  if result[2] < result[0]:
    print('Large: Significant')
  if result[3] < result[0]:
    print('Women: Significant')
  if result[4] < result[0]:
    print('Men: Significant')
print('')

print('Mean: Lumbar')
result_mean_stand_lat_lum = statAnova_lum(mean_stand_lat)
print(result_mean_stand_lat_lum)
if result_mean_stand_lat_lum['PR(>F)'][0] < 0.05:
  print('Gender: Significant')
if result_mean_stand_lat_lum['PR(>F)'][1] < 0.05:
  print('Size: Significant')
if result_mean_stand_lat_lum['PR(>F)'][2] < 0.05:
  result = significant_lum(mean_stand_lat, result_mean_stand_lat_lum['PR(>F)'])
  print('Small: ', result[1], ', Large: ', result[2], ', Women: ', result[3], ', Men: ', result[4])
  if result[1] < result[0]:
    print('Small: Significant')
  if result[2] < result[0]:
    print('Large: Significant')
  if result[3] < result[0]:
    print('Women: Significant')
  if result[4] < result[0]:
    print('Men: Significant')
print('')
# Out:
# Lateral Flexion
#
# Minimum: Upper Thoracic
# 0    2.496395
# 1    1.493620
# 2   -5.862535
# Name: 0, dtype: float64
# -0.6241733131896033 3.726635218396584
# 3    5.98061
# 4   -1.99095
# Name: 0, dtype: float64
# 1.9948301025465203 3.9857799573557804
# 5    0.929457
# 6   -0.702980
# 7   -5.862535
# Name: 0, dtype: float64
# -1.8786862824890855 2.894765536555935
# 8   -0.501026
# 9    3.241610
# Name: 0, dtype: float64
# 1.3702921548528488 1.8713180632681008
#   Gender   Size  Kinematic
# 0  women  small   2.496395
# 1  women  small   1.493620
# 2  women  small  -5.862535
# 3  women  large   5.980610
# 4  women  large  -1.990950
# 5    men  small   0.929457
# 6    men  small  -0.702980
# 7    men  small  -5.862535
# 8    men  large  -0.501026
# 9    men  large   3.241610
#                        sum_sq   df         F    PR(>F)
# C(Gender)            2.512631  1.0  0.142792  0.718529
# C(Size)             20.659927  1.0  1.174093  0.320172
# C(Gender):C(Size)    0.238121  1.0  0.013532  0.911188
# Residual           105.578979  6.0       NaN       NaN
#
# Minimum: Lower Thoracic
# 0    4.205823
# 1   -5.340511
# 2   -0.333212
# Name: 1, dtype: float64
# -0.4892998398253517 3.8988368209551423
# 3    -1.556222
# 4   -11.410179
# Name: 1, dtype: float64
# -6.483200391186255 4.926978351548045
# 5   -1.760538
# 6    5.130450
# 7   -0.333212
# Name: 1, dtype: float64
# 1.0122330873941514 2.969746940832779
# 8   -6.114681
# 9    1.446697
# Name: 1, dtype: float64
# -2.33399209146002 3.78068860857459
#   Gender   Size  Kinematic
# 0  women  small   4.205823
# 1  women  small  -5.340511
# 2  women  small  -0.333212
# 3  women  large  -1.556222
# 4  women  large -11.410179
# 5    men  small  -1.760538
# 6    men  small   5.130450
# 7    men  small  -0.333212
# 8    men  large  -6.114681
# 9    men  large   1.446697
#                        sum_sq   df         F    PR(>F)
# C(Gender)           16.391720  1.0  0.659191  0.447851
# C(Size)             52.342769  1.0  2.104959  0.197016
# C(Gender):C(Size)    4.206111  1.0  0.169148  0.695156
# Residual           149.198420  6.0       NaN       NaN
#
# Minimum: Lumbar
# 0   -3.574113
# 1    0.062421
# 2    4.044153
# Name: 2, dtype: float64
# 0.17748690032252665 3.111208109799733
# 3    2.637877
# 4    0.538106
# Name: 2, dtype: float64
# 1.5879915396073565 1.0498853817796836
# 5    -0.416054
# 6   -10.477036
# 7     4.044153
# Name: 2, dtype: float64
# -2.2829790890042707 6.073455293962928
# 8    3.042276
# 9   -6.784145
# Name: 2, dtype: float64
# -1.87093450377928 4.91321022676989
#   Gender   Size  Kinematic
# 0  women  small  -3.574113
# 1  women  small   0.062421
# 2  women  small   4.044153
# 3  women  large   2.637877
# 4  women  large   0.538106
# 5    men  small  -0.416054
# 6    men  small -10.477036
# 7    men  small   4.044153
# 8    men  large   3.042276
# 9    men  large  -6.784145
#                        sum_sq   df         F    PR(>F)
# C(Gender)           20.446855  1.0  0.645068  0.452515
# C(Size)              1.993011  1.0  0.062877  0.810372
# C(Gender):C(Size)    0.598153  1.0  0.018871  0.895231
# Residual           190.183213  6.0       NaN       NaN
#
# Maximum: Upper Thoracic
# 0    3.677117
# 1    2.427677
# 2   -4.120739
# Name: 0, dtype: float64
# 0.6613517281686269 3.4197044839068926
# 3    7.615344
# 4    3.016319
# Name: 0, dtype: float64
# 5.31583120154227 2.29951241067884
# 5    2.235343
# 6    1.183958
# 7   -4.120739
# Name: 0, dtype: float64
# -0.23381265135975346 2.781785939448894
# 8    0.024652
# 9    4.997223
# Name: 0, dtype: float64
# 2.510937758877234 2.4862856951533354
#   Gender   Size  Kinematic
# 0  women  small   3.677117
# 1  women  small   2.427677
# 2  women  small  -4.120739
# 3  women  large   7.615344
# 4  women  large   3.016319
# 5    men  small   2.235343
# 6    men  small   1.183958
# 7    men  small  -4.120739
# 8    men  large   0.024652
# 9    men  large   4.997223
#                       sum_sq   df         F    PR(>F)
# C(Gender)           6.881167  1.0  0.508230  0.502676
# C(Size)            32.849162  1.0  2.426176  0.170333
# C(Gender):C(Size)   2.188239  1.0  0.161619  0.701600
# Residual           81.236883  6.0       NaN       NaN
#
# Maximum: Lower Thoracic
# 0    5.934671
# 1   -1.886443
# 2    0.953793
# Name: 1, dtype: float64
# 1.667340631391231 3.232575734919263
# 3    2.139505
# 4   -3.539848
# Name: 1, dtype: float64
# -0.7001711775142001 2.8396763492136703
# 5    3.964265
# 6    6.080672
# 7    0.953793
# Name: 1, dtype: float64
# 3.6662435912367908 2.1036215014995365
# 8   -4.129849
# 9    2.680527
# Name: 1, dtype: float64
# -0.7246610245481002 3.40518754859483
#   Gender   Size  Kinematic
# 0  women  small   5.934671
# 1  women  small  -1.886443
# 2  women  small   0.953793
# 3  women  large   2.139505
# 4  women  large  -3.539848
# 5    men  small   3.964265
# 6    men  small   6.080672
# 7    men  small   0.953793
# 8    men  large  -4.129849
# 9    men  large   2.680527
#                       sum_sq   df         F    PR(>F)
# C(Gender)           3.537548  1.0  0.252855  0.632992
# C(Size)            27.405716  1.0  1.958894  0.211154
# C(Gender):C(Size)   2.456471  1.0  0.175583  0.689784
# Residual           83.942436  6.0       NaN       NaN
#
# Maximum: Lumbar
# 0    0.288764
# 1    1.352582
# 2    6.633177
# Name: 2, dtype: float64
# 2.758174207476309 2.774246189833651
# 3    9.316738
# 4    2.389690
# Name: 2, dtype: float64
# 5.8532139493871345 3.4635238971265347
# 5    3.326083
# 6   -4.946087
# 7    6.633177
# Name: 2, dtype: float64
# 1.6710578303465768 4.869919150085895
# 8    6.531962
# 9   -2.819102
# Name: 2, dtype: float64
# 1.856429756617665 4.675531912912185
#   Gender   Size  Kinematic
# 0  women  small   0.288764
# 1  women  small   1.352582
# 2  women  small   6.633177
# 3  women  large   9.316738
# 4  women  large   2.389690
# 5    men  small   3.326083
# 6    men  small  -4.946087
# 7    men  small   6.633177
# 8    men  large   6.531962
# 9    men  large  -2.819102
#                        sum_sq   df         F    PR(>F)
# C(Gender)           12.667317  1.0  0.469302  0.518883
# C(Size)              6.456660  1.0  0.239208  0.642142
# C(Gender):C(Size)    5.079700  1.0  0.188194  0.679588
# Residual           161.950856  6.0       NaN       NaN
#
# Mean: Upper Thoracic
# 0    3.093845
# 1    1.853772
# 2   -5.197891
# Name: 0, dtype: float64
# -0.08342478270711003 3.6517366291016633
# 3    6.828689
# 4    0.844455
# Name: 0, dtype: float64
# 3.8365720176230003 2.9921167126910895
# 5    1.446792
# 6    0.055972
# 7   -5.197891
# Name: 0, dtype: float64
# -1.2317088758886952 2.8614154406832757
# 8   -0.241866
# 9    4.253444
# Name: 0, dtype: float64
# 2.005788911816635 2.247655040686895
#   Gender   Size  Kinematic
# 0  women  small   3.093845
# 1  women  small   1.853772
# 2  women  small  -5.197891
# 3  women  large   6.828689
# 4  women  large   0.844455
# 5    men  small   1.446792
# 6    men  small   0.055972
# 7    men  small  -5.197891
# 8    men  large  -0.241866
# 9    men  large   4.253444
#                       sum_sq   df         F    PR(>F)
# C(Gender)           5.050118  1.0  0.327299  0.588032
# C(Size)            30.737837  1.0  1.992124  0.207812
# C(Gender):C(Size)   0.279483  1.0  0.018113  0.897341
# Residual           92.578067  6.0       NaN       NaN
#
# Mean: Lower Thoracic
# 0    4.941265
# 1   -4.085994
# 2    0.289087
# Name: 1, dtype: float64
# 0.381452953195202 3.685941793346713
# 3   -0.087341
# 4   -6.344909
# Name: 1, dtype: float64
# -3.21612472323688 3.1287838817313505
# 5    2.648580
# 6    5.665995
# 7    0.289087
# Name: 1, dtype: float64
# 2.8678875557658627 2.200584186175159
# 8   -5.208615
# 9    2.352415
# Name: 1, dtype: float64
# -1.4281004058105502 3.78051508658186
#   Gender   Size  Kinematic
# 0  women  small   4.941265
# 1  women  small  -4.085994
# 2  women  small   0.289087
# 3  women  large  -0.087341
# 4  women  large  -6.344909
# 5    men  small   2.648580
# 6    men  small   5.665995
# 7    men  small   0.289087
# 8    men  large  -5.208615
# 9    men  large   2.352415
#                        sum_sq   df         F    PR(>F)
# C(Gender)           12.177900  1.0  0.706311  0.432879
# C(Size)             37.385027  1.0  2.168308  0.191304
# C(Gender):C(Size)    0.292666  1.0  0.016974  0.900598
# Residual           103.449379  6.0       NaN       NaN
#
# Mean: Lumbar
# 0   -2.001503
# 1    0.558406
# 2    5.646318
# Name: 2, dtype: float64
# 1.4010736816380653 3.1785594154278813
# 3    7.550743
# 4    1.004972
# Name: 2, dtype: float64
# 4.277857398931345 3.272885384842105
# 5    1.652349
# 6   -6.530286
# 7    5.646318
# Name: 2, dtype: float64
# 0.25612708085856006 5.068168411217798
# 8    4.163293
# 9   -4.519471
# Name: 2, dtype: float64
# -0.17808930416945978 4.3413821010139095
#   Gender   Size  Kinematic
# 0  women  small  -2.001503
# 1  women  small   0.558406
# 2  women  small   5.646318
# 3  women  large   7.550743
# 4  women  large   1.004972
# 5    men  small   1.652349
# 6    men  small  -6.530286
# 7    men  small   5.646318
# 8    men  large   4.163293
# 9    men  large  -4.519471
#                        sum_sq   df         F    PR(>F)
# C(Gender)           15.244182  1.0  0.549381  0.486556
# C(Size)              3.579681  1.0  0.129007  0.731765
# C(Gender):C(Size)    6.577633  1.0  0.237050  0.643619
# Residual           166.487468  6.0       NaN       NaN

# %%
print('Mean')
box_whisker(mean_stand_lat)
print('Min')
box_whisker(min_stand_lat)
print('Max')
box_whisker(max_stand_lat)
# Out:
# Mean
# Min
# Max

# %%
# Axial Flexion
# Flexion
print('\033[1mAxial Flexion\033[0m')
print('')

# Minimums
url_min_stand_axi = 'https://raw.githubusercontent.com/GraceHerchenroder/Thesis/main/min_stand_axi.csv'
min_stand_axi = pd.read_csv(url_min_stand_axi, header = None)

print('Minimum: Upper Thoracic')
result_min_stand_axi_ut = statAnova_ut(min_stand_axi)
print(result_min_stand_axi_ut)
if result_min_stand_axi_ut['PR(>F)'][0] < 0.05:
  print('Gender: Significant')
if result_min_stand_axi_ut['PR(>F)'][1] < 0.05:
  print('Size: Significant')
if result_min_stand_axi_ut['PR(>F)'][2] < 0.05:
  result = significant_ut(min_stand_axi, result_min_stand_axi_ut['PR(>F)'])
  print('Small: ', result[1], ', Large: ', result[2], ', Women: ', result[3], ', Men: ', result[4])
  if result[1] < result[0]:
    print('Small: Significant')
  if result[2] < result[0]:
    print('Large: Significant')
  if result[3] < result[0]:
    print('Women: Significant')
  if result[4] < result[0]:
    print('Men: Significant')
print('')

print('Minimum: Lower Thoracic')
result_min_stand_axi_lt = statAnova_lt(min_stand_axi)
print(result_min_stand_axi_lt)
if result_min_stand_axi_lt['PR(>F)'][0] < 0.05:
  print('Gender: Significant')
if result_min_stand_axi_lt['PR(>F)'][1] < 0.05:
  print('Size: Significant')
if result_min_stand_axi_lt['PR(>F)'][2] < 0.05:
  result = significant_lt(min_stand_axi, result_min_stand_axi_lt['PR(>F)'])
  print('Small: ', result[1], ', Large: ', result[2], ', Women: ', result[3], ', Men: ', result[4])
  if result[1] < result[0]:
    print('Small: Significant')
  if result[2] < result[0]:
    print('Large: Significant')
  if result[3] < result[0]:
    print('Women: Significant')
  if result[4] < result[0]:
    print('Men: Significant')
print('')

print('Minimum: Lumbar')
result_min_stand_axi_lum = statAnova_lum(min_stand_axi)
print(result_min_stand_axi_lum)
if result_min_stand_axi_lum['PR(>F)'][0] < 0.05:
  print('Gender: Significant')
if result_min_stand_axi_lum['PR(>F)'][1] < 0.05:
  print('Size: Significant')
if result_min_stand_axi_lum['PR(>F)'][2] < 0.05:
  result = significant_lum(min_stand_axi, result_min_stand_axi_lum['PR(>F)'])
  print('Small: ', result[1], ', Large: ', result[2], ', Women: ', result[3], ', Men: ', result[4])
  if result[1] < result[0]:
    print('Small: Significant')
  if result[2] < result[0]:
    print('Large: Significant')
  if result[3] < result[0]:
    print('Women: Significant')
  if result[4] < result[0]:
    print('Men: Significant')
print('')

# Maximums
url_max_stand_axi = 'https://raw.githubusercontent.com/GraceHerchenroder/Thesis/main/max_stand_axi.csv'
max_stand_axi = pd.read_csv(url_max_stand_axi, header = None)

print('Maximum: Upper Thoracic')
result_max_stand_axi_ut = statAnova_ut(max_stand_axi)
print(result_max_stand_axi_ut)
if result_max_stand_axi_ut['PR(>F)'][0] < 0.05:
  print('Gender: Significant')
if result_max_stand_axi_ut['PR(>F)'][1] < 0.05:
  print('Size: Significant')
if result_max_stand_axi_ut['PR(>F)'][2] < 0.05:
  result = significant_ut(max_stand_axi, result_max_stand_axi_ut['PR(>F)'])
  print('Small: ', result[1], ', Large: ', result[2], ', Women: ', result[3], ', Men: ', result[4])
  if result[1] < result[0]:
    print('Small: Significant')
  if result[2] < result[0]:
    print('Large: Significant')
  if result[3] < result[0]:
    print('Women: Significant')
  if result[4] < result[0]:
    print('Men: Significant')
print('')

print('Maximum: Lower Thoracic')
result_max_stand_axi_lt = statAnova_lt(max_stand_axi)
print(result_max_stand_axi_lt)
if result_max_stand_axi_lt['PR(>F)'][0] < 0.05:
  print('Gender: Significant')
if result_max_stand_axi_lt['PR(>F)'][1] < 0.05:
  print('Size: Significant')
if result_max_stand_axi_lt['PR(>F)'][2] < 0.05:
  result = significant_lt(max_stand_axi, result_max_stand_axi_lt['PR(>F)'])
  print('Small: ', result[1], ', Large: ', result[2], ', Women: ', result[3], ', Men: ', result[4])
  if result[1] < result[0]:
    print('Small: Significant')
  if result[2] < result[0]:
    print('Large: Significant')
  if result[3] < result[0]:
    print('Women: Significant')
  if result[4] < result[0]:
    print('Men: Significant')
print('')

print('Maximum: Lumbar')
result_max_stand_axi_lum = statAnova_lum(max_stand_axi)
print(result_max_stand_axi_lum)
if result_max_stand_axi_lum['PR(>F)'][0] < 0.05:
  print('Gender: Significant')
if result_max_stand_axi_lum['PR(>F)'][1] < 0.05:
  print('Size: Significant')
if result_max_stand_axi_lum['PR(>F)'][2] < 0.05:
  result = significant_lum(max_stand_axi, result_max_stand_axi_lum['PR(>F)'])
  print('Small: ', result[1], ', Large: ', result[2], ', Women: ', result[3], ', Men: ', result[4])
  if result[1] < result[0]:
    print('Small: Significant')
  if result[2] < result[0]:
    print('Large: Significant')
  if result[3] < result[0]:
    print('Women: Significant')
  if result[4] < result[0]:
    print('Men: Significant')
print('')

# Means
url_mean_stand_axi = 'https://raw.githubusercontent.com/GraceHerchenroder/Thesis/main/mean_stand_axi.csv'
mean_stand_axi = pd.read_csv(url_mean_stand_axi, header = None)

print('Mean: Upper Thoracic')
result_mean_stand_axi_ut = statAnova_ut(mean_stand_axi)
print(result_mean_stand_axi_ut)
if result_mean_stand_axi_ut['PR(>F)'][0] < 0.05:
  print('Gender: Significant')
if result_mean_stand_axi_ut['PR(>F)'][1] < 0.05:
  print('Size: Significant')
if result_mean_stand_axi_ut['PR(>F)'][2] < 0.05:
  result = significant_ut(mean_stand_axi, result_mean_stand_axi_ut['PR(>F)'])
  print('Small: ', result[1], ', Large: ', result[2], ', Women: ', result[3], ', Men: ', result[4])
  if result[1] < result[0]:
    print('Small: Significant')
  if result[2] < result[0]:
    print('Large: Significant')
  if result[3] < result[0]:
    print('Women: Significant')
  if result[4] < result[0]:
    print('Men: Significant')
print('')

print('Mean: Lower Thoracic')
result_mean_stand_axi_lt = statAnova_lt(mean_stand_axi)
print(result_mean_stand_axi_lt)
if result_mean_stand_axi_lt['PR(>F)'][0] < 0.05:
  print('Gender: Significant')
if result_mean_stand_axi_lt['PR(>F)'][1] < 0.05:
  print('Size: Significant')
if result_mean_stand_axi_lt['PR(>F)'][2] < 0.05:
  result = significant_lt(mean_stand_axi, result_mean_stand_axi_lt['PR(>F)'])
  print('Small: ', result[1], ', Large: ', result[2], ', Women: ', result[3], ', Men: ', result[4])
  if result[1] < result[0]:
    print('Small: Significant')
  if result[2] < result[0]:
    print('Large: Significant')
  if result[3] < result[0]:
    print('Women: Significant')
  if result[4] < result[0]:
    print('Men: Significant')
print('')

print('Mean: Lumbar')
result_mean_stand_axi_lum = statAnova_lum(mean_stand_axi)
print(result_mean_stand_axi_lum)
if result_mean_stand_axi_lum['PR(>F)'][0] < 0.05:
  print('Gender: Significant')
if result_mean_stand_axi_lum['PR(>F)'][1] < 0.05:
  print('Size: Significant')
if result_mean_stand_axi_lum['PR(>F)'][2] < 0.05:
  result = significant_lum(mean_stand_axi, result_mean_stand_axi_lum['PR(>F)'])
  print('Small: ', result[1], ', Large: ', result[2], ', Women: ', result[3], ', Men: ', result[4])
  if result[1] < result[0]:
    print('Small: Significant')
  if result[2] < result[0]:
    print('Large: Significant')
  if result[3] < result[0]:
    print('Women: Significant')
  if result[4] < result[0]:
    print('Men: Significant')
print('')
# Out:
# Axial Flexion
#
# Minimum: Upper Thoracic
# 0    1.472959
# 1   -1.102785
# 2   -6.016705
# Name: 0, dtype: float64
# -1.8821772405708697 3.1069123790291537
# 3   -5.506341
# 4   -3.536731
# Name: 0, dtype: float64
# -4.52153609695359 0.9848051524082602
# 5    5.770277
# 6   -6.741441
# 7   -6.016705
# Name: 0, dtype: float64
# -2.3292899085156367 5.734896000163942
# 8   -3.370905
# 9    0.620943
# Name: 0, dtype: float64
# -1.374980670810386 1.995923940556214
#   Gender   Size  Kinematic
# 0  women  small   1.472959
# 1  women  small  -1.102785
# 2  women  small  -6.016705
# 3  women  large  -5.506341
# 4  women  large  -3.536731
# 5    men  small   5.770277
# 6    men  small  -6.741441
# 7    men  small  -6.016705
# 8    men  large  -3.370905
# 9    men  large   0.620943
#                        sum_sq   df         F    PR(>F)
# C(Gender)            2.452005  1.0  0.106971  0.754729
# C(Size)              1.703635  1.0  0.074323  0.794284
# C(Gender):C(Size)    7.748670  1.0  0.338043  0.582129
# Residual           137.532917  6.0       NaN       NaN
#
# Minimum: Lower Thoracic
# 0     3.809058
# 1    -2.175041
# 2    11.390660
# Name: 1, dtype: float64
# 4.341558996512177 5.550959856602603
# 3    2.280622
# 4   -2.374490
# Name: 1, dtype: float64
# -0.046933911443480136 2.32755568274269
# 5    -6.172078
# 6    -6.033684
# 7    11.390660
# Name: 1, dtype: float64
# -0.27170061079849006 8.246728122052597
# 8   -9.224662
# 9    1.952721
# Name: 1, dtype: float64
# -3.635970300486355 5.588691798177075
#   Gender   Size  Kinematic
# 0  women  small   3.809058
# 1  women  small  -2.175041
# 2  women  small  11.390660
# 3  women  large   2.280622
# 4  women  large  -2.374490
# 5    men  small  -6.172078
# 6    men  small  -6.033684
# 7    men  small  11.390660
# 8    men  large  -9.224662
# 9    men  large   1.952721
#                        sum_sq   df         F    PR(>F)
# C(Gender)           44.175009  1.0  0.716803  0.429663
# C(Size)             36.063197  1.0  0.585177  0.473295
# C(Gender):C(Size)    0.629420  1.0  0.010213  0.922795
# Residual           369.767023  6.0       NaN       NaN
#
# Minimum: Lumbar
# 0   -2.053847
# 1    3.185001
# 2    6.416562
# Name: 2, dtype: float64
# 2.5159052649378166 3.490245670082288
# 3   -1.622202
# 4   -1.939192
# Name: 2, dtype: float64
# -1.780696571977235 0.15849502837874496
# 5    0.706432
# 6    0.084070
# 7    6.416562
# Name: 2, dtype: float64
# 2.4023545849481933 2.849822133712484
# 8   -1.220800
# 9    1.553355
# Name: 2, dtype: float64
# 0.1662771477361451 1.387077509761105
#   Gender   Size  Kinematic
# 0  women  small  -2.053847
# 1  women  small   3.185001
# 2  women  small   6.416562
# 3  women  large  -1.622202
# 4  women  large  -1.939192
# 5    men  small   0.706432
# 6    men  small   0.084070
# 7    men  small   6.416562
# 8    men  large  -1.220800
# 9    men  large   1.553355
#                       sum_sq   df         F    PR(>F)
# C(Gender)           1.262591  1.0  0.116892  0.744087
# C(Size)            25.605539  1.0  2.370586  0.174567
# C(Gender):C(Size)   2.547456  1.0  0.235846  0.644447
# Residual           64.808112  6.0       NaN       NaN
#
# Maximum: Upper Thoracic
# 0    6.363716
# 1    1.676879
# 2   -0.775517
# Name: 0, dtype: float64
# 2.421692809947245 2.961781207342579
# 3    0.695539
# 4    0.732637
# Name: 0, dtype: float64
# 0.7140881300002895 0.01854883815768149
# 5    8.768776
# 6   -3.572693
# 7   -0.775517
# Name: 0, dtype: float64
# 1.4735219965461017 5.283407886398766
# 8   -1.766755
# 9    6.167456
# Name: 0, dtype: float64
# 2.200350671924045 3.967105539497345
#   Gender   Size  Kinematic
# 0  women  small   6.363716
# 1  women  small   1.676879
# 2  women  small  -0.775517
# 3  women  large   0.695539
# 4  women  large   0.732637
# 5    men  small   8.768776
# 6    men  small  -3.572693
# 7    men  small  -0.775517
# 8    men  large  -1.766755
# 9    men  large   6.167456
#                        sum_sq   df         F    PR(>F)
# C(Gender)            0.001639  1.0  0.000069  0.993620
# C(Size)              0.577153  1.0  0.024467  0.880834
# C(Gender):C(Size)    3.555879  1.0  0.150741  0.711230
# Residual           141.536181  6.0       NaN       NaN
#
# Maximum: Lower Thoracic
# 0     6.509693
# 1     0.018240
# 2    14.608402
# Name: 1, dtype: float64
# 7.045445022933222 5.968443594571075
# 3    8.649842
# 4    4.733062
# Name: 1, dtype: float64
# 6.691451690803834 1.9583898556441848
# 5     1.875472
# 6    -2.459331
# 7    14.608402
# Name: 1, dtype: float64
# 4.67484769184867 7.243583768227521
# 8   -4.720311
# 9    6.531965
# Name: 1, dtype: float64
# 0.905826652711645 5.626137969947135
#   Gender   Size  Kinematic
# 0  women  small   6.509693
# 1  women  small   0.018240
# 2  women  small  14.608402
# 3  women  large   8.649842
# 4  women  large   4.733062
# 5    men  small   1.875472
# 6    men  small  -2.459331
# 7    men  small  14.608402
# 8    men  large  -4.720311
# 9    men  large   6.531965
#                        sum_sq   df         F    PR(>F)
# C(Gender)           34.905606  1.0  0.624703  0.459395
# C(Size)             10.199549  1.0  0.182541  0.684106
# C(Gender):C(Size)    6.997449  1.0  0.125233  0.735530
# Residual           335.252913  6.0       NaN       NaN
#
# Maximum: Lumbar
# 0     0.696612
# 1     4.417685
# 2    10.437287
# Name: 2, dtype: float64
# 5.1838614283344056 4.013349160809859
# 3    3.714212
# 4    1.888147
# Name: 2, dtype: float64
# 2.80117973802827 0.91303223964323
# 5     4.434168
# 6     4.571182
# 7    10.437287
# Name: 2, dtype: float64
# 6.480879029901444 2.798162176239026
# 8    0.739672
# 9    6.232465
# Name: 2, dtype: float64
# 3.4860686636865896 2.7463963281112895
#   Gender   Size  Kinematic
# 0  women  small   0.696612
# 1  women  small   4.417685
# 2  women  small  10.437287
# 3  women  large   3.714212
# 4  women  large   1.888147
# 5    men  small   4.434168
# 6    men  small   4.571182
# 7    men  small  10.437287
# 8    men  large   0.739672
# 9    men  large   6.232465
#                       sum_sq   df         F    PR(>F)
# C(Gender)           2.767634  1.0  0.187503  0.680136
# C(Size)            17.350452  1.0  1.175469  0.319912
# C(Gender):C(Size)   0.224821  1.0  0.015231  0.905809
# Residual           88.562690  6.0       NaN       NaN
#
# Mean: Upper Thoracic
# 0    4.103677
# 1    0.433417
# 2   -3.496476
# Name: 0, dtype: float64
# 0.3468726057579081 3.1033527000183763
# 3   -1.337660
# 4   -1.972436
# Name: 0, dtype: float64
# -1.6550478229665 0.3173881131659
# 5    7.549667
# 6   -4.999803
# 7   -3.496476
# Name: 0, dtype: float64
# -0.31553716318552016 5.595300493550268
# 8   -2.311096
# 9    4.926900
# Name: 0, dtype: float64
# 1.307902088848225 3.6189982559593847
#   Gender   Size  Kinematic
# 0  women  small   4.103677
# 1  women  small   0.433417
# 2  women  small  -3.496476
# 3  women  large  -1.337660
# 4  women  large  -1.972436
# 5    men  small   7.549667
# 6    men  small  -4.999803
# 7    men  small  -3.496476
# 8    men  large  -2.311096
# 9    men  large   4.926900
#                        sum_sq   df         F    PR(>F)
# C(Gender)            1.551313  1.0  0.062381  0.811103
# C(Size)              0.085949  1.0  0.003456  0.955029
# C(Gender):C(Size)    7.885940  1.0  0.317107  0.593754
# Residual           149.210324  6.0       NaN       NaN
#
# Mean: Lower Thoracic
# 0     5.153902
# 1    -0.952843
# 2    12.819310
# Name: 1, dtype: float64
# 5.673456316737969 5.634447541419728
# 3    5.057601
# 4    0.525877
# Name: 1, dtype: float64
# 2.7917392964198076 2.2658620975769423
# 5    -2.476949
# 6    -4.087263
# 7    12.819310
# Name: 1, dtype: float64
# 2.08503283071976 7.618696570978572
# 8   -8.259274
# 9    4.043442
# Name: 1, dtype: float64
# -2.1079160884591652 6.151358256033475
#   Gender   Size  Kinematic
# 0  women  small   5.153902
# 1  women  small  -0.952843
# 2  women  small  12.819310
# 3  women  large   5.057601
# 4  women  large   0.525877
# 5    men  small  -2.476949
# 6    men  small  -4.087263
# 7    men  small  12.819310
# 8    men  large  -8.259274
# 9    men  large   4.043442
#                        sum_sq   df         F    PR(>F)
# C(Gender)           42.290200  1.0  0.714118  0.430482
# C(Size)             30.030539  1.0  0.507099  0.503133
# C(Gender):C(Size)    1.031597  1.0  0.017420  0.899312
# Residual           355.321288  6.0       NaN       NaN
#
# Mean: Lumbar
# 0   -0.850179
# 1    3.806301
# 2    8.522202
# Name: 2, dtype: float64
# 3.82610778766019 3.826284076608308
# 3   -0.502271
# 4    0.188217
# Name: 2, dtype: float64
# -0.15702709234088152 0.3452443637203205
# 5    2.160836
# 6    2.994468
# 7    8.522202
# Name: 2, dtype: float64
# 4.559168705121164 2.8228777831499476
# 8   -0.337188
# 9    2.859714
# Name: 2, dtype: float64
# 1.2612628719783694 1.5984512204297003
#   Gender   Size  Kinematic
# 0  women  small  -0.850179
# 1  women  small   3.806301
# 2  women  small   8.522202
# 3  women  large  -0.502271
# 4  women  large   0.188217
# 5    men  small   2.160836
# 6    men  small   2.994468
# 7    men  small   8.522202
# 8    men  large  -0.337188
# 9    men  large   2.859714
#                       sum_sq   df         F    PR(>F)
# C(Gender)           2.535891  1.0  0.207929  0.664434
# C(Size)            31.808132  1.0  2.608088  0.157447
# C(Gender):C(Size)   0.281723  1.0  0.023100  0.884180
# Residual           73.175746  6.0       NaN       NaN

# %%
print('Mean')
box_whisker(mean_stand_axi)
print('Min')
box_whisker(min_stand_axi)
print('Max')
box_whisker(max_stand_axi)
# Out:
# Mean
# Min
# Max
