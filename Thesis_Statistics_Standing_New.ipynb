# %% [markdown]
# <a href="https://colab.research.google.com/github/GraceHerchenroder/Thesis/blob/main/Thesis_Statistics_Standing_New.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# Importing libraries
import pandas as pd
import numpy as np
import statsmodels.api as sm
from statsmodels.formula.api import ols
from scipy import stats
from statsmodels.stats.multitest import multipletests
import matplotlib.pyplot as plt

# %%
# Performing two-way ANOVA
def statAnova_ut(kinematic_data):
  dataframe = pd.DataFrame({'Gender': np.repeat(['women', 'men'], 5),
                          'Size': ['small', 'small', 'small', 'large', 'large', 'small', 'small', 'small', 'large', 'large'],
                          'Kinematic': kinematic_data[0][:]})
  group_1_mean = np.mean(kinematic_data[0][:3])
  group_1_sd = np.std(kinematic_data[0][:3])
  group_2_mean = np.mean(kinematic_data[0][3:5])
  group_2_sd = np.std(kinematic_data[0][3:5])
  group_3_mean = np.mean(kinematic_data[0][5:8])
  group_3_sd = np.std(kinematic_data[0][5:8])
  group_4_mean = np.mean(kinematic_data[0][8:])
  group_4_sd = np.std(kinematic_data[0][8:])
  print(kinematic_data[0][:3])
  print(group_1_mean, group_1_sd)
  print(kinematic_data[0][3:5])
  print(group_2_mean, group_2_sd)
  print(kinematic_data[0][5:8])
  print(group_3_mean, group_3_sd)
  print(kinematic_data[0][8:])
  print(group_3_mean, group_3_sd)
  print(dataframe)
  model = ols('Kinematic ~ C(Gender) + C(Size) + C(Gender):C(Size)', data=dataframe).fit()
  result = sm.stats.anova_lm(model, typ=2)
  return result

def statAnova_lt(kinematic_data):
  dataframe = pd.DataFrame({'Gender': np.repeat(['women', 'men'], 5),
                          'Size': ['small', 'small', 'small', 'large', 'large', 'small', 'small', 'small', 'large', 'large'],
                          'Kinematic': kinematic_data[1][:]})
  group_1_mean = np.mean(kinematic_data[0][:3])
  group_1_sd = np.std(kinematic_data[0][:3])
  group_2_mean = np.mean(kinematic_data[0][3:5])
  group_2_sd = np.std(kinematic_data[0][3:5])
  group_3_mean = np.mean(kinematic_data[0][5:8])
  group_3_sd = np.std(kinematic_data[0][5:8])
  group_4_mean = np.mean(kinematic_data[0][8:])
  group_4_sd = np.std(kinematic_data[0][8:])
  print(kinematic_data[0][:3])
  print(group_1_mean, group_1_sd)
  print(kinematic_data[0][3:5])
  print(group_2_mean, group_2_sd)
  print(kinematic_data[0][5:8])
  print(group_3_mean, group_3_sd)
  print(kinematic_data[0][8:])
  print(group_3_mean, group_3_sd)
  print(dataframe)
  model = ols('Kinematic ~ C(Gender) + C(Size) + C(Gender):C(Size)', data=dataframe).fit()
  result = sm.stats.anova_lm(model, typ=2)
  return result

def statAnova_lum(kinematic_data):
  dataframe = pd.DataFrame({'Gender': np.repeat(['women', 'men'], 5),
                          'Size': ['small', 'small', 'small', 'large', 'large', 'small', 'small', 'small', 'large', 'large'],
                          'Kinematic': kinematic_data[2][:]})
  group_1_mean = np.mean(kinematic_data[0][:3])
  group_1_sd = np.std(kinematic_data[0][:3])
  group_2_mean = np.mean(kinematic_data[0][3:5])
  group_2_sd = np.std(kinematic_data[0][3:5])
  group_3_mean = np.mean(kinematic_data[0][5:8])
  group_3_sd = np.std(kinematic_data[0][5:8])
  group_4_mean = np.mean(kinematic_data[0][8:])
  group_4_sd = np.std(kinematic_data[0][8:])
  print(kinematic_data[0][:3])
  print(group_1_mean, group_1_sd)
  print(kinematic_data[0][3:5])
  print(group_2_mean, group_2_sd)
  print(kinematic_data[0][5:8])
  print(group_3_mean, group_3_sd)
  print(kinematic_data[0][8:])
  print(group_3_mean, group_3_sd)
  print(dataframe)
  model = ols('Kinematic ~ C(Gender) + C(Size) + C(Gender):C(Size)', data=dataframe).fit()
  result = sm.stats.anova_lm(model, typ=2)
  return result

def box_whisker(kinematic_data):
   small_men_data_ut = kinematic_data[0][8:]
   large_men_data_ut = kinematic_data[0][5:8]
   small_women_data_ut = kinematic_data[0][:3]
   large_women_data_ut = kinematic_data[0][3:5]
   small_men_data_lt = kinematic_data[1][8:]
   large_men_data_lt = kinematic_data[1][5:8]
   small_women_data_lt = kinematic_data[1][:3]
   large_women_data_lt = kinematic_data[1][3:5]
   small_men_data_lum = kinematic_data[2][8:]
   large_men_data_lum = kinematic_data[2][5:8]
   small_women_data_lum = kinematic_data[2][:3]
   large_women_data_lum = kinematic_data[2][3:5]
   fig, ax = plt.subplots(3, 2, figsize=(6, 10))
   ax[0][0].boxplot([small_men_data_ut, large_men_data_ut], labels = ['small', 'large'])
   ax[0][0].set_title('Men')
   ax[0][0].set_ylabel('Upper Thoracic')
   ax[0][1].boxplot([small_women_data_ut, large_women_data_ut], labels = ['small', 'large'])
   ax[0][1].set_title('Women')
   ax[1][0].boxplot([small_men_data_lt, large_men_data_lt], labels = ['small', 'large'])
   ax[1][0].set_title('Men')
   ax[1][0].set_ylabel('Lower Thoracic')
   ax[1][1].boxplot([small_women_data_lt, large_women_data_lt], labels = ['small', 'large'])
   ax[1][1].set_title('Women')
   ax[2][0].boxplot([small_men_data_lum, large_men_data_lum], labels = ['small', 'large'])
   ax[2][0].set_title('Men')
   ax[2][0].set_ylabel('Lumbar')
   ax[2][1].boxplot([small_women_data_lum, large_women_data_lum], labels = ['small', 'large'])
   ax[2][1].set_title('Women')
   plt.show()

# %%
# Follow Up analysis: Significant
def significant_ut(kinematic_data, p_values):
  [reject, p_corrected] = multipletests(p_values, method = 'bonferroni')
  small_men_data = kinematic_data[0][8:]
  large_men_data = kinematic_data[0][5:8]
  small_women_data = kinematic_data[0][:3]
  large_women_data = kinematic_data[0][3:5]

  [stat_small, p_small] = stats.ttest_ind(small_men_data, small_women_data);
  [stat_large, p_large] = stats.ttest_ind(large_men_data, large_women_data);
  [stat_women, p_women] = stats.ttest_ind(small_women_data, large_women_data);
  [stat_men, p_men] = stats.ttest_ind(small_men_data, large_men_data);

  return [p_corrected, p_small, p_large, p_women, p_men]

def significant_lt(kinematic_data, p_values):
  [reject, p_corrected] = multipletests(p_values, method = 'bonferroni')
  small_men_data = kinematic_data[1][8:]
  large_men_data = kinematic_data[1][5:8]
  small_women_data = kinematic_data[1][:3]
  large_women_data = kinematic_data[1][3:5]

  [stat_small, p_small] = stats.ttest_ind(small_men_data, small_women_data);
  [stat_large, p_large] = stats.ttest_ind(large_men_data, large_women_data);
  [stat_women, p_women] = stats.ttest_ind(small_women_data, large_women_data);
  [stat_men, p_men] = stats.ttest_ind(small_men_data, large_men_data);

  return [p_corrected, p_small, p_large, p_women, p_men]

def significant_lum(kinematic_data, p_values):
  [reject, p_corrected] = multipletests(p_values, method = 'bonferroni')
  small_men_data = kinematic_data[2][8:]
  large_men_data = kinematic_data[2][5:8]
  small_women_data = kinematic_data[2][:3]
  large_women_data = kinematic_data[2][3:5]

  [stat_small, p_small] = stats.ttest_ind(small_men_data, small_women_data);
  [stat_large, p_large] = stats.ttest_ind(large_men_data, large_women_data);
  [stat_women, p_women] = stats.ttest_ind(small_women_data, large_women_data);
  [stat_men, p_men] = stats.ttest_ind(small_men_data, large_men_data);

  return [p_corrected, p_small, p_large, p_women, p_men]

# %%
# Flexion
print('\033[1mFlexion\033[0m')
print('')

# Minimums
url_min_stand_flex = 'https://raw.githubusercontent.com/GraceHerchenroder/Thesis/main/min_stand_flex.csv'
min_stand_flex = pd.read_csv(url_min_stand_flex, header = None)

print('Minimum: Upper Thoracic')
result_min_stand_flex_ut = statAnova_ut(min_stand_flex)
print(result_min_stand_flex_ut)
if result_min_stand_flex_ut['PR(>F)'][0] < 0.05:
  print('Gender: Significant')
if result_min_stand_flex_ut['PR(>F)'][1] < 0.05:
  print('Size: Significant')
if result_min_stand_flex_ut['PR(>F)'][2] < 0.05:
  result = significant_ut(min_stand_flex, result_min_stand_flex_ut['PR(>F)'])
  print('Small: ', result[1], ', Large: ', result[2], ', Women: ', result[3], ', Men: ', result[4])
  if result[1] < result[0]:
    print('Small: Significant')
  if result[2] < result[0]:
    print('Large: Significant')
  if result[3] < result[0]:
    print('Women: Significant')
  if result[4] < result[0]:
    print('Men: Significant')
print('')

print('Minimum: Lower Thoracic')
result_min_stand_flex_lt = statAnova_lt(min_stand_flex)
print(result_min_stand_flex_lt)
if result_min_stand_flex_lt['PR(>F)'][0] < 0.05:
  print('Gender: Significant')
if result_min_stand_flex_lt['PR(>F)'][1] < 0.05:
  print('Size: Significant')
if result_min_stand_flex_lt['PR(>F)'][2] < 0.05:
  result = significant_lt(min_stand_flex, result_min_stand_flex_lt['PR(>F)'])
  print('Small: ', result[1], ', Large: ', result[2], ', Women: ', result[3], ', Men: ', result[4])
  if result[1] < result[0]:
    print('Small: Significant')
  if result[2] < result[0]:
    print('Large: Significant')
  if result[3] < result[0]:
    print('Women: Significant')
  if result[4] < result[0]:
    print('Men: Significant')
print('')

print('Minimum: Lumbar')
result_min_stand_flex_lum = statAnova_lum(min_stand_flex)
print(result_min_stand_flex_lum)
if result_min_stand_flex_lum['PR(>F)'][0] < 0.05:
  print('Gender: Significant')
if result_min_stand_flex_lum['PR(>F)'][1] < 0.05:
  print('Size: Significant')
if result_min_stand_flex_lum['PR(>F)'][2] < 0.05:
  result = significant_lum(min_stand_flex, result_min_stand_flex_lum['PR(>F)'])
  print('Small: ', result[1], ', Large: ', result[2], ', Women: ', result[3], ', Men: ', result[4])
  if result[1] < result[0]:
    print('Small: Significant')
  if result[2] < result[0]:
    print('Large: Significant')
  if result[3] < result[0]:
    print('Women: Significant')
  if result[4] < result[0]:
    print('Men: Significant')
print('')

# Maximums
url_max_stand_flex = 'https://raw.githubusercontent.com/GraceHerchenroder/Thesis/main/max_stand_flex.csv'
max_stand_flex = pd.read_csv(url_max_stand_flex, header = None)

print('Maximum: Upper Thoracic')
result_max_stand_flex_ut = statAnova_ut(max_stand_flex)
print(result_max_stand_flex_ut)
if result_max_stand_flex_ut['PR(>F)'][0] < 0.05:
  print('Gender: Significant')
if result_max_stand_flex_ut['PR(>F)'][1] < 0.05:
  print('Size: Significant')
if result_max_stand_flex_ut['PR(>F)'][2] < 0.05:
  result = significant_ut(max_stand_flex, result_max_stand_flex_ut['PR(>F)'])
  print('Small: ', result[1], ', Large: ', result[2], ', Women: ', result[3], ', Men: ', result[4])
  if result[1] < result[0]:
    print('Small: Significant')
  if result[2] < result[0]:
    print('Large: Significant')
  if result[3] < result[0]:
    print('Women: Significant')
  if result[4] < result[0]:
    print('Men: Significant')
print('')

print('Maximum: Lower Thoracic')
result_max_stand_flex_lt = statAnova_lt(max_stand_flex)
print(result_max_stand_flex_lt)
if result_max_stand_flex_lt['PR(>F)'][0] < 0.05:
  print('Gender: Significant')
if result_max_stand_flex_lt['PR(>F)'][1] < 0.05:
  print('Size: Significant')
if result_max_stand_flex_lt['PR(>F)'][2] < 0.05:
  result = significant_lt(max_stand_flex, result_max_stand_flex_lt['PR(>F)'])
  print('Small: ', result[1], ', Large: ', result[2], ', Women: ', result[3], ', Men: ', result[4])
  if result[1] < result[0]:
    print('Small: Significant')
  if result[2] < result[0]:
    print('Large: Significant')
  if result[3] < result[0]:
    print('Women: Significant')
  if result[4] < result[0]:
    print('Men: Significant')
print('')

print('Maximum: Lumbar')
result_max_stand_flex_lum = statAnova_lum(max_stand_flex)
print(result_max_stand_flex_lum)
if result_max_stand_flex_lum['PR(>F)'][0] < 0.05:
  print('Gender: Significant')
if result_max_stand_flex_lum['PR(>F)'][1] < 0.05:
  print('Size: Significant')
if result_max_stand_flex_lum['PR(>F)'][2] < 0.05:
  result = significant_lum(max_stand_flex, result_max_stand_flex_lum['PR(>F)'])
  print('Small: ', result[1], ', Large: ', result[2], ', Women: ', result[3], ', Men: ', result[4])
  if result[1] < result[0]:
    print('Small: Significant')
  if result[2] < result[0]:
    print('Large: Significant')
  if result[3] < result[0]:
    print('Women: Significant')
  if result[4] < result[0]:
    print('Men: Significant')
print('')

# Means
url_mean_stand_flex = 'https://raw.githubusercontent.com/GraceHerchenroder/Thesis/main/mean_stand_flex.csv'
mean_stand_flex = pd.read_csv(url_mean_stand_flex, header = None)

print('Mean: Upper Thoracic')
result_mean_stand_flex_ut = statAnova_ut(mean_stand_flex)
print(result_mean_stand_flex_ut)
if result_mean_stand_flex_ut['PR(>F)'][0] < 0.05:
  print('Gender: Significant')
if result_mean_stand_flex_ut['PR(>F)'][1] < 0.05:
  print('Size: Significant')
if result_mean_stand_flex_ut['PR(>F)'][2] < 0.05:
  result = significant_ut(mean_stand_flex, result_mean_stand_flex_ut['PR(>F)'])
  print('Small: ', result[1], ', Large: ', result[2], ', Women: ', result[3], ', Men: ', result[4])
  if result[1] < result[0]:
    print('Small: Significant')
  if result[2] < result[0]:
    print('Large: Significant')
  if result[3] < result[0]:
    print('Women: Significant')
  if result[4] < result[0]:
    print('Men: Significant')
print('')

print('Mean: Lower Thoracic')
result_mean_stand_flex_lt = statAnova_lt(mean_stand_flex)
print(result_mean_stand_flex_lt)
if result_mean_stand_flex_lt['PR(>F)'][0] < 0.05:
  print('Gender: Significant')
if result_mean_stand_flex_lt['PR(>F)'][1] < 0.05:
  print('Size: Significant')
if result_mean_stand_flex_lt['PR(>F)'][2] < 0.05:
  result = significant_lt(mean_stand_flex, result_mean_stand_flex_lt['PR(>F)'])
  print('Small: ', result[1], ', Large: ', result[2], ', Women: ', result[3], ', Men: ', result[4])
  if result[1] < result[0]:
    print('Small: Significant')
  if result[2] < result[0]:
    print('Large: Significant')
  if result[3] < result[0]:
    print('Women: Significant')
  if result[4] < result[0]:
    print('Men: Significant')
print('')

print('Mean: Lumbar')
result_mean_stand_flex_lum = statAnova_lum(mean_stand_flex)
print(result_mean_stand_flex_lum)
if result_mean_stand_flex_lum['PR(>F)'][0] < 0.05:
  print('Gender: Significant')
if result_mean_stand_flex_lum['PR(>F)'][1] < 0.05:
  print('Size: Significant')
if result_mean_stand_flex_lum['PR(>F)'][2] < 0.05:
  result = significant_lum(mean_stand_flex, result_mean_stand_flex_lum['PR(>F)'])
  print('Small: ', result[1], ', Large: ', result[2], ', Women: ', result[3], ', Men: ', result[4])
  if result[1] < result[0]:
    print('Small: Significant')
  if result[2] < result[0]:
    print('Large: Significant')
  if result[3] < result[0]:
    print('Women: Significant')
  if result[4] < result[0]:
    print('Men: Significant')
print('')
# Out:
# Flexion
#
# Minimum: Upper Thoracic
# 0    19.200039
# 1    19.844000
# 2    18.504286
# Name: 0, dtype: float64
# 19.182775052814403 0.547072456010208
# 3    29.212001
# 4     2.485940
# Name: 0, dtype: float64
# 15.84897056772013 13.36303009555607
# 5    12.134140
# 6   -19.856654
# 7    18.504286
# Name: 0, dtype: float64
# 3.5939238759695336 16.784752953684652
# 8     5.399473
# 9    12.026619
# Name: 0, dtype: float64
# 3.5939238759695336 16.784752953684652
#   Gender   Size  Kinematic
# 0  women  small  19.200039
# 1  women  small  19.844000
# 2  women  small  18.504286
# 3  women  large  29.212001
# 4  women  large   2.485940
# 5    men  small  12.134140
# 6    men  small -19.856654
# 7    men  small  18.504286
# 8    men  large   5.399473
# 9    men  large  12.026619
#                         sum_sq   df         F    PR(>F)
# C(Gender)           372.568663  1.0  1.824555  0.225487
# C(Size)               1.912415  1.0  0.009366  0.926056
# C(Gender):C(Size)    42.871180  1.0  0.209950  0.662933
# Residual           1225.182342  6.0       NaN       NaN
#
# Minimum: Lower Thoracic
# 0    19.200039
# 1    19.844000
# 2    18.504286
# Name: 0, dtype: float64
# 19.182775052814403 0.547072456010208
# 3    29.212001
# 4     2.485940
# Name: 0, dtype: float64
# 15.84897056772013 13.36303009555607
# 5    12.134140
# 6   -19.856654
# 7    18.504286
# Name: 0, dtype: float64
# 3.5939238759695336 16.784752953684652
# 8     5.399473
# 9    12.026619
# Name: 0, dtype: float64
# 3.5939238759695336 16.784752953684652
#   Gender   Size  Kinematic
# 0  women  small -25.123090
# 1  women  small -20.977638
# 2  women  small -28.877586
# 3  women  large -22.988001
# 4  women  large -24.094092
# 5    men  small -20.752084
# 6    men  small -16.470561
# 7    men  small -28.877586
# 8    men  large -40.068564
# 9    men  large -26.247203
#                        sum_sq   df         F    PR(>F)
# C(Gender)           10.723827  1.0  0.311156  0.597153
# C(Size)             56.137233  1.0  1.628845  0.249036
# C(Gender):C(Size)   94.896462  1.0  2.753460  0.148115
# Residual           206.786620  6.0       NaN       NaN
#
# Minimum: Lumbar
# 0    19.200039
# 1    19.844000
# 2    18.504286
# Name: 0, dtype: float64
# 19.182775052814403 0.547072456010208
# 3    29.212001
# 4     2.485940
# Name: 0, dtype: float64
# 15.84897056772013 13.36303009555607
# 5    12.134140
# 6   -19.856654
# 7    18.504286
# Name: 0, dtype: float64
# 3.5939238759695336 16.784752953684652
# 8     5.399473
# 9    12.026619
# Name: 0, dtype: float64
# 3.5939238759695336 16.784752953684652
#   Gender   Size  Kinematic
# 0  women  small -34.787838
# 1  women  small -16.321507
# 2  women  small -34.382967
# 3  women  large -37.283729
# 4  women  large -16.367200
# 5    men  small -27.143703
# 6    men  small -38.400569
# 7    men  small -34.382967
# 8    men  large -49.407698
# 9    men  large -31.273230
#                        sum_sq   df         F    PR(>F)
# C(Gender)          171.933993  1.0  1.538031  0.261209
# C(Size)             17.233973  1.0  0.154166  0.708155
# C(Gender):C(Size)   45.449054  1.0  0.406563  0.547265
# Residual           670.730299  6.0       NaN       NaN
#
# Maximum: Upper Thoracic
# 0    28.093418
# 1    25.602320
# 2    28.462810
# Name: 0, dtype: float64
# 27.386182776545905 1.270364357807754
# 3    33.140894
# 4     8.459495
# Name: 0, dtype: float64
# 20.800194758500542 12.340699402021361
# 5    18.517011
# 6    16.339467
# 7    28.462810
# Name: 0, dtype: float64
# 21.106429340471667 5.2771634418172155
# 8    18.648077
# 9    22.143774
# Name: 0, dtype: float64
# 21.106429340471667 5.2771634418172155
#   Gender   Size  Kinematic
# 0  women  small  28.093418
# 1  women  small  25.602320
# 2  women  small  28.462810
# 3  women  large  33.140894
# 4  women  large   8.459495
# 5    men  small  18.517011
# 6    men  small  16.339467
# 7    men  small  28.462810
# 8    men  large  18.648077
# 9    men  large  22.143774
#                        sum_sq   df         F    PR(>F)
# C(Gender)           38.603598  1.0  0.580385  0.475032
# C(Size)             31.943274  1.0  0.480251  0.514224
# C(Gender):C(Size)   20.712790  1.0  0.311406  0.597010
# Residual           399.082511  6.0       NaN       NaN
#
# Maximum: Lower Thoracic
# 0    28.093418
# 1    25.602320
# 2    28.462810
# Name: 0, dtype: float64
# 27.386182776545905 1.270364357807754
# 3    33.140894
# 4     8.459495
# Name: 0, dtype: float64
# 20.800194758500542 12.340699402021361
# 5    18.517011
# 6    16.339467
# 7    28.462810
# Name: 0, dtype: float64
# 21.106429340471667 5.2771634418172155
# 8    18.648077
# 9    22.143774
# Name: 0, dtype: float64
# 21.106429340471667 5.2771634418172155
#   Gender   Size  Kinematic
# 0  women  small  28.080355
# 1  women  small  20.053548
# 2  women  small  27.111844
# 3  women  large  20.252910
# 4  women  large  24.133627
# 5    men  small  19.632813
# 6    men  small  -7.002671
# 7    men  small  27.111844
# 8    men  large  38.359543
# 9    men  large  26.043160
#                        sum_sq   df         F    PR(>F)
# C(Gender)           23.986562  1.0  0.188171  0.679607
# C(Size)            154.857778  1.0  1.214834  0.312614
# C(Gender):C(Size)  286.261341  1.0  2.245674  0.184643
# Residual           764.834046  6.0       NaN       NaN
#
# Maximum: Lumbar
# 0    28.093418
# 1    25.602320
# 2    28.462810
# Name: 0, dtype: float64
# 27.386182776545905 1.270364357807754
# 3    33.140894
# 4     8.459495
# Name: 0, dtype: float64
# 20.800194758500542 12.340699402021361
# 5    18.517011
# 6    16.339467
# 7    28.462810
# Name: 0, dtype: float64
# 21.106429340471667 5.2771634418172155
# 8    18.648077
# 9    22.143774
# Name: 0, dtype: float64
# 21.106429340471667 5.2771634418172155
#   Gender   Size  Kinematic
# 0  women  small  27.414012
# 1  women  small  -3.131631
# 2  women  small  25.304278
# 3  women  large  30.706795
# 4  women  large   6.423148
# 5    men  small  24.832479
# 6    men  small  37.498989
# 7    men  small  25.304278
# 8    men  large  33.756940
# 9    men  large  29.190282
#                        sum_sq   df         F    PR(>F)
# C(Gender)          407.891279  1.0  2.470998  0.167023
# C(Size)             11.082553  1.0  0.067138  0.804211
# C(Gender):C(Size)    0.030540  1.0  0.000185  0.989589
# Residual           990.429022  6.0       NaN       NaN
#
# Mean: Upper Thoracic
# 0    25.457734
# 1    21.750887
# 2    22.317071
# Name: 0, dtype: float64
# 23.17523073821317 1.630441020082018
# 3    32.329335
# 4     6.003720
# Name: 0, dtype: float64
# 19.166527882219324 13.162807390765375
# 5    15.551056
# 6    -8.258494
# 7    22.317071
# Name: 0, dtype: float64
# 9.869877923247953 13.11292317361301
# 8    10.030439
# 9    18.626363
# Name: 0, dtype: float64
# 9.869877923247953 13.11292317361301
#   Gender   Size  Kinematic
# 0  women  small  25.457734
# 1  women  small  21.750887
# 2  women  small  22.317071
# 3  women  large  32.329335
# 4  women  large   6.003720
# 5    men  small  15.551056
# 6    men  small  -8.258494
# 7    men  small  22.317071
# 8    men  large  10.030439
# 9    men  large  18.626363
#                        sum_sq   df         F    PR(>F)
# C(Gender)          245.939750  1.0  1.626433  0.249349
# C(Size)              0.121403  1.0  0.000803  0.978314
# C(Gender):C(Size)   43.016346  1.0  0.284473  0.612954
# Residual           907.285226  6.0       NaN       NaN
#
# Mean: Lower Thoracic
# 0    25.457734
# 1    21.750887
# 2    22.317071
# Name: 0, dtype: float64
# 23.17523073821317 1.630441020082018
# 3    32.329335
# 4     6.003720
# Name: 0, dtype: float64
# 19.166527882219324 13.162807390765375
# 5    15.551056
# 6    -8.258494
# 7    22.317071
# Name: 0, dtype: float64
# 9.869877923247953 13.11292317361301
# 8    10.030439
# 9    18.626363
# Name: 0, dtype: float64
# 9.869877923247953 13.11292317361301
#   Gender   Size  Kinematic
# 0  women  small -22.347716
# 1  women  small -16.189105
# 2  women  small -26.124485
# 3  women  large -21.216718
# 4  women  large  11.071876
# 5    men  small -17.232790
# 6    men  small -11.567253
# 7    men  small -26.124485
# 8    men  large -34.236628
# 9    men  large -21.974206
#                        sum_sq   df         F    PR(>F)
# C(Gender)          131.981177  1.0  1.049618  0.345114
# C(Size)             26.806368  1.0  0.213185  0.660549
# C(Gender):C(Size)  414.338532  1.0  3.295145  0.119403
# Residual           754.452776  6.0       NaN       NaN
#
# Mean: Lumbar
# 0    25.457734
# 1    21.750887
# 2    22.317071
# Name: 0, dtype: float64
# 23.17523073821317 1.630441020082018
# 3    32.329335
# 4     6.003720
# Name: 0, dtype: float64
# 19.166527882219324 13.162807390765375
# 5    15.551056
# 6    -8.258494
# 7    22.317071
# Name: 0, dtype: float64
# 9.869877923247953 13.11292317361301
# 8    10.030439
# 9    18.626363
# Name: 0, dtype: float64
# 9.869877923247953 13.11292317361301
#   Gender   Size  Kinematic
# 0  women  small -31.834457
# 1  women  small  -7.500107
# 2  women  small -30.496809
# 3  women  large -34.209558
# 4  women  large  -5.422100
# 5    men  small -19.691764
# 6    men  small  -4.344356
# 7    men  small -30.496809
# 8    men  large -39.632022
# 9    men  large -27.799349
#                         sum_sq   df         F    PR(>F)
# C(Gender)            15.628175  1.0  0.077878  0.789563
# C(Size)              87.508685  1.0  0.436073  0.533540
# C(Gender):C(Size)   216.584904  1.0  1.079286  0.338899
# Residual           1204.045267  6.0       NaN       NaN

# %%
print('Mean')
box_whisker(mean_stand_flex)
print('Min')
box_whisker(min_stand_flex)
print('Max')
box_whisker(max_stand_flex)
# Out:
# Mean
# Min
# Max

# %%
# Lateral Flexion
print('\033[1mLateral Flexion\033[0m')
print('')

# Minimums
url_min_stand_lat = 'https://raw.githubusercontent.com/GraceHerchenroder/Thesis/main/min_stand_lat.csv'
min_stand_lat = pd.read_csv(url_min_stand_lat, header = None)

print('Minimum: Upper Thoracic')
result_min_stand_lat_ut = statAnova_ut(min_stand_lat)
print(result_min_stand_lat_ut)
if result_min_stand_lat_ut['PR(>F)'][0] < 0.05:
  print('Gender: Significant')
if result_min_stand_lat_ut['PR(>F)'][1] < 0.05:
  print('Size: Significant')
if result_min_stand_lat_ut['PR(>F)'][2] < 0.05:
  result = significant_ut(min_stand_lat, result_min_stand_lat_ut['PR(>F)'])
  print('Small: ', result[1], ', Large: ', result[2], ', Women: ', result[3], ', Men: ', result[4])
  if result[1] < result[0]:
    print('Small: Significant')
  if result[2] < result[0]:
    print('Large: Significant')
  if result[3] < result[0]:
    print('Women: Significant')
  if result[4] < result[0]:
    print('Men: Significant')
print('')

print('Minimum: Lower Thoracic')
result_min_stand_lat_lt = statAnova_lt(min_stand_lat)
print(result_min_stand_lat_lt)
if result_min_stand_lat_lt['PR(>F)'][0] < 0.05:
  print('Gender: Significant')
if result_min_stand_lat_lt['PR(>F)'][1] < 0.05:
  print('Size: Significant')
if result_min_stand_lat_lt['PR(>F)'][2] < 0.05:
  result = significant_lt(min_stand_lat, result_min_stand_lat_lt['PR(>F)'])
  print('Small: ', result[1], ', Large: ', result[2], ', Women: ', result[3], ', Men: ', result[4])
  if result[1] < result[0]:
    print('Small: Significant')
  if result[2] < result[0]:
    print('Large: Significant')
  if result[3] < result[0]:
    print('Women: Significant')
  if result[4] < result[0]:
    print('Men: Significant')
print('')

print('Minimum: Lumbar')
result_min_stand_lat_lum = statAnova_lum(min_stand_lat)
print(result_min_stand_lat_lum)
if result_min_stand_lat_lum['PR(>F)'][0] < 0.05:
  print('Gender: Significant')
if result_min_stand_lat_lum['PR(>F)'][1] < 0.05:
  print('Size: Significant')
if result_min_stand_lat_lum['PR(>F)'][2] < 0.05:
  result = significant_lum(min_stand_lat, result_min_stand_lat_lum['PR(>F)'])
  print('Small: ', result[1], ', Large: ', result[2], ', Women: ', result[3], ', Men: ', result[4])
  if result[1] < result[0]:
    print('Small: Significant')
  if result[2] < result[0]:
    print('Large: Significant')
  if result[3] < result[0]:
    print('Women: Significant')
  if result[4] < result[0]:
    print('Men: Significant')
print('')

# Maximums
url_max_stand_lat = 'https://raw.githubusercontent.com/GraceHerchenroder/Thesis/main/max_stand_lat.csv'
max_stand_lat = pd.read_csv(url_max_stand_lat, header = None)

print('Maximum: Upper Thoracic')
result_max_stand_lat_ut = statAnova_ut(max_stand_lat)
print(result_max_stand_lat_ut)
if result_max_stand_lat_ut['PR(>F)'][0] < 0.05:
  print('Gender: Significant')
if result_max_stand_lat_ut['PR(>F)'][1] < 0.05:
  print('Size: Significant')
if result_max_stand_lat_ut['PR(>F)'][2] < 0.05:
  result = significant_ut(max_stand_lat, result_max_stand_lat_ut['PR(>F)'])
  print('Small: ', result[1], ', Large: ', result[2], ', Women: ', result[3], ', Men: ', result[4])
  if result[1] < result[0]:
    print('Small: Significant')
  if result[2] < result[0]:
    print('Large: Significant')
  if result[3] < result[0]:
    print('Women: Significant')
  if result[4] < result[0]:
    print('Men: Significant')
print('')

print('Maximum: Lower Thoracic')
result_max_stand_lat_lt = statAnova_lt(max_stand_lat)
print(result_max_stand_lat_lt)
if result_max_stand_lat_lt['PR(>F)'][0] < 0.05:
  print('Gender: Significant')
if result_max_stand_lat_lt['PR(>F)'][1] < 0.05:
  print('Size: Significant')
if result_max_stand_lat_lt['PR(>F)'][2] < 0.05:
  result = significant_lt(max_stand_lat, result_max_stand_lat_lt['PR(>F)'])
  print('Small: ', result[1], ', Large: ', result[2], ', Women: ', result[3], ', Men: ', result[4])
  if result[1] < result[0]:
    print('Small: Significant')
  if result[2] < result[0]:
    print('Large: Significant')
  if result[3] < result[0]:
    print('Women: Significant')
  if result[4] < result[0]:
    print('Men: Significant')
print('')

print('Maximum: Lumbar')
result_max_stand_lat_lum = statAnova_lum(max_stand_lat)
print(result_max_stand_lat_lum)
if result_max_stand_lat_lum['PR(>F)'][0] < 0.05:
  print('Gender: Significant')
if result_max_stand_lat_lum['PR(>F)'][1] < 0.05:
  print('Size: Significant')
if result_max_stand_lat_lum['PR(>F)'][2] < 0.05:
  result = significant_lum(max_stand_lat, result_max_stand_lat_lum['PR(>F)'])
  print('Small: ', result[1], ', Large: ', result[2], ', Women: ', result[3], ', Men: ', result[4])
  if result[1] < result[0]:
    print('Small: Significant')
  if result[2] < result[0]:
    print('Large: Significant')
  if result[3] < result[0]:
    print('Women: Significant')
  if result[4] < result[0]:
    print('Men: Significant')
print('')

# Means
url_mean_stand_lat = 'https://raw.githubusercontent.com/GraceHerchenroder/Thesis/main/mean_stand_lat.csv'
mean_stand_lat = pd.read_csv(url_mean_stand_lat, header = None)

print('Mean: Upper Thoracic')
result_mean_stand_lat_ut = statAnova_ut(mean_stand_lat)
print(result_mean_stand_lat_ut)
if result_mean_stand_lat_ut['PR(>F)'][0] < 0.05:
  print('Gender: Significant')
if result_mean_stand_lat_ut['PR(>F)'][1] < 0.05:
  print('Size: Significant')
if result_mean_stand_flex_ut['PR(>F)'][2] < 0.05:
  result = significant_ut(mean_stand_lat, result_mean_stand_lat_ut['PR(>F)'])
  print('Small: ', result[1], ', Large: ', result[2], ', Women: ', result[3], ', Men: ', result[4])
  if result[1] < result[0]:
    print('Small: Significant')
  if result[2] < result[0]:
    print('Large: Significant')
  if result[3] < result[0]:
    print('Women: Significant')
  if result[4] < result[0]:
    print('Men: Significant')
print('')

print('Mean: Lower Thoracic')
result_mean_stand_lat_lt = statAnova_lt(mean_stand_lat)
print(result_mean_stand_lat_lt)
if result_mean_stand_lat_lt['PR(>F)'][0] < 0.05:
  print('Gender: Significant')
if result_mean_stand_lat_lt['PR(>F)'][1] < 0.05:
  print('Size: Significant')
if result_mean_stand_lat_lt['PR(>F)'][2] < 0.05:
  result = significant_lt(mean_stand_lat, result_mean_stand_lat_lt['PR(>F)'])
  print('Small: ', result[1], ', Large: ', result[2], ', Women: ', result[3], ', Men: ', result[4])
  if result[1] < result[0]:
    print('Small: Significant')
  if result[2] < result[0]:
    print('Large: Significant')
  if result[3] < result[0]:
    print('Women: Significant')
  if result[4] < result[0]:
    print('Men: Significant')
print('')

print('Mean: Lumbar')
result_mean_stand_lat_lum = statAnova_lum(mean_stand_lat)
print(result_mean_stand_lat_lum)
if result_mean_stand_lat_lum['PR(>F)'][0] < 0.05:
  print('Gender: Significant')
if result_mean_stand_lat_lum['PR(>F)'][1] < 0.05:
  print('Size: Significant')
if result_mean_stand_lat_lum['PR(>F)'][2] < 0.05:
  result = significant_lum(mean_stand_lat, result_mean_stand_lat_lum['PR(>F)'])
  print('Small: ', result[1], ', Large: ', result[2], ', Women: ', result[3], ', Men: ', result[4])
  if result[1] < result[0]:
    print('Small: Significant')
  if result[2] < result[0]:
    print('Large: Significant')
  if result[3] < result[0]:
    print('Women: Significant')
  if result[4] < result[0]:
    print('Men: Significant')
print('')
# Out:
# Lateral Flexion
#
# Minimum: Upper Thoracic
# 0    -7.694685
# 1    -6.013769
# 2   -10.996013
# Name: 0, dtype: float64
# -8.234822216008356 2.069541048828146
# 3   -10.359501
# 4    -4.510883
# Name: 0, dtype: float64
# -7.435191924929015 2.924309397633685
# 5    -4.569916
# 6    -6.165117
# 7   -10.996013
# Name: 0, dtype: float64
# -7.243681972171856 2.7320513860001783
# 8   -5.449320
# 9   -6.440289
# Name: 0, dtype: float64
# -7.243681972171856 2.7320513860001783
#   Gender   Size  Kinematic
# 0  women  small  -7.694685
# 1  women  small  -6.013769
# 2  women  small -10.996013
# 3  women  large -10.359501
# 4  women  large  -4.510883
# 5    men  small  -4.569916
# 6    men  small  -6.165117
# 7    men  small -10.996013
# 8    men  large  -5.449320
# 9    men  large  -6.440289
#                       sum_sq   df         F    PR(>F)
# C(Gender)           3.545245  1.0  0.402598  0.549164
# C(Size)             2.642241  1.0  0.300053  0.603614
# C(Gender):C(Size)   0.149549  1.0  0.016983  0.900574
# Residual           52.835496  6.0       NaN       NaN
#
# Minimum: Lower Thoracic
# 0    -7.694685
# 1    -6.013769
# 2   -10.996013
# Name: 0, dtype: float64
# -8.234822216008356 2.069541048828146
# 3   -10.359501
# 4    -4.510883
# Name: 0, dtype: float64
# -7.435191924929015 2.924309397633685
# 5    -4.569916
# 6    -6.165117
# 7   -10.996013
# Name: 0, dtype: float64
# -7.243681972171856 2.7320513860001783
# 8   -5.449320
# 9   -6.440289
# Name: 0, dtype: float64
# -7.243681972171856 2.7320513860001783
#   Gender   Size  Kinematic
# 0  women  small  -9.524918
# 1  women  small  -7.987135
# 2  women  small -12.383880
# 3  women  large  -6.233205
# 4  women  large -11.018657
# 5    men  small  -6.195363
# 6    men  small  -7.125373
# 7    men  small -12.383880
# 8    men  large  -8.488471
# 9    men  large  -3.825675
#                       sum_sq   df         F    PR(>F)
# C(Gender)           8.333923  1.0  0.916668  0.375323
# C(Size)             8.439806  1.0  0.928314  0.372510
# C(Gender):C(Size)   0.689192  1.0  0.075806  0.792300
# Residual           54.549235  6.0       NaN       NaN
#
# Minimum: Lumbar
# 0    -7.694685
# 1    -6.013769
# 2   -10.996013
# Name: 0, dtype: float64
# -8.234822216008356 2.069541048828146
# 3   -10.359501
# 4    -4.510883
# Name: 0, dtype: float64
# -7.435191924929015 2.924309397633685
# 5    -4.569916
# 6    -6.165117
# 7   -10.996013
# Name: 0, dtype: float64
# -7.243681972171856 2.7320513860001783
# 8   -5.449320
# 9   -6.440289
# Name: 0, dtype: float64
# -7.243681972171856 2.7320513860001783
#   Gender   Size  Kinematic
# 0  women  small  -6.788772
# 1  women  small  -6.844447
# 2  women  small -12.126451
# 3  women  large -10.624593
# 4  women  large  -4.560307
# 5    men  small  -8.672342
# 6    men  small -14.774372
# 7    men  small -12.126451
# 8    men  large -13.193947
# 9    men  large  -8.378584
#                       sum_sq   df         F    PR(>F)
# C(Gender)          26.247649  1.0  2.332945  0.177520
# C(Size)             2.559930  1.0  0.227532  0.650237
# C(Gender):C(Size)   0.003590  1.0  0.000319  0.986328
# Residual           67.505177  6.0       NaN       NaN
#
# Maximum: Upper Thoracic
# 0    10.241363
# 1     3.273163
# 2    11.686100
# Name: 0, dtype: float64
# 8.400208719431207 3.673033795746248
# 3   -3.361725
# 4    4.865658
# Name: 0, dtype: float64
# 0.751966275974735 4.113691727033995
# 5     3.042869
# 6     4.129967
# 7    11.686100
# Name: 0, dtype: float64
# 6.286312144490584 3.8439326203676205
# 8    6.733011
# 9    3.616395
# Name: 0, dtype: float64
# 6.286312144490584 3.8439326203676205
#   Gender   Size  Kinematic
# 0  women  small  10.241363
# 1  women  small   3.273163
# 2  women  small  11.686100
# 3  women  large  -3.361725
# 4  women  large   4.865658
# 5    men  small   3.042869
# 6    men  small   4.129967
# 7    men  small  11.686100
# 8    men  large   6.733011
# 9    men  large   3.616395
#                        sum_sq   df         F    PR(>F)
# C(Gender)            0.626893  1.0  0.030456  0.867200
# C(Size)             46.041002  1.0  2.236764  0.185393
# C(Gender):C(Size)   25.636543  1.0  1.245474  0.307109
# Residual           123.502551  6.0       NaN       NaN
#
# Maximum: Lower Thoracic
# 0    10.241363
# 1     3.273163
# 2    11.686100
# Name: 0, dtype: float64
# 8.400208719431207 3.673033795746248
# 3   -3.361725
# 4    4.865658
# Name: 0, dtype: float64
# 0.751966275974735 4.113691727033995
# 5     3.042869
# 6     4.129967
# 7    11.686100
# Name: 0, dtype: float64
# 6.286312144490584 3.8439326203676205
# 8    6.733011
# 9    3.616395
# Name: 0, dtype: float64
# 6.286312144490584 3.8439326203676205
#   Gender   Size  Kinematic
# 0  women  small   8.904945
# 1  women  small   6.548116
# 2  women  small  12.377239
# 3  women  large   4.170022
# 4  women  large  10.058283
# 5    men  small   5.873904
# 6    men  small   8.290339
# 7    men  small  12.377239
# 8    men  large  10.795896
# 9    men  large   4.213616
#                       sum_sq   df         F    PR(>F)
# C(Gender)           0.025767  1.0  0.001987  0.965892
# C(Size)             7.371091  1.0  0.568410  0.479423
# C(Gender):C(Size)   0.403647  1.0  0.031127  0.865763
# Residual           77.807485  6.0       NaN       NaN
#
# Maximum: Lumbar
# 0    10.241363
# 1     3.273163
# 2    11.686100
# Name: 0, dtype: float64
# 8.400208719431207 3.673033795746248
# 3   -3.361725
# 4    4.865658
# Name: 0, dtype: float64
# 0.751966275974735 4.113691727033995
# 5     3.042869
# 6     4.129967
# 7    11.686100
# Name: 0, dtype: float64
# 6.286312144490584 3.8439326203676205
# 8    6.733011
# 9    3.616395
# Name: 0, dtype: float64
# 6.286312144490584 3.8439326203676205
#   Gender   Size  Kinematic
# 0  women  small   9.494055
# 1  women  small   3.516017
# 2  women  small  11.030944
# 3  women  large   9.720132
# 4  women  large   4.899910
# 5    men  small   1.794689
# 6    men  small  12.991134
# 7    men  small  11.030944
# 8    men  large  11.957324
# 9    men  large  12.582520
#                        sum_sq   df         F    PR(>F)
# C(Gender)           13.678596  1.0  0.714655  0.430318
# C(Size)              5.259383  1.0  0.274783  0.618934
# C(Gender):C(Size)   11.447570  1.0  0.598093  0.468670
# Residual           114.840783  6.0       NaN       NaN
#
# Mean: Upper Thoracic
# 0   -3.347047
# 1   -0.466641
# 2    4.714527
# Name: 0, dtype: float64
# 0.30027991385108194 3.3355028194984477
# 3   -6.828689
# 4    2.148719
# Name: 0, dtype: float64
# -2.339984958429465 4.4887037718768745
# 5   -1.440512
# 6   -0.629334
# 7    4.714527
# Name: 0, dtype: float64
# 0.8815604913467983 2.730473364036799
# 8    0.366484
# 9   -4.282459
# Name: 0, dtype: float64
# 0.8815604913467983 2.730473364036799
#   Gender   Size  Kinematic
# 0  women  small  -3.347047
# 1  women  small  -0.466641
# 2  women  small   4.714527
# 3  women  large  -6.828689
# 4  women  large   2.148719
# 5    men  small  -1.440512
# 6    men  small  -0.629334
# 7    men  small   4.714527
# 8    men  large   0.366484
# 9    men  large  -4.282459
#                        sum_sq   df         F    PR(>F)
# C(Gender)            0.628924  1.0  0.035317  0.857127
# C(Size)             18.017009  1.0  1.011752  0.353311
# C(Gender):C(Size)    0.023828  1.0  0.001338  0.972007
# Residual           106.846449  6.0       NaN       NaN
#
# Mean: Lower Thoracic
# 0   -3.347047
# 1   -0.466641
# 2    4.714527
# Name: 0, dtype: float64
# 0.30027991385108194 3.3355028194984477
# 3   -6.828689
# 4    2.148719
# Name: 0, dtype: float64
# -2.339984958429465 4.4887037718768745
# 5   -1.440512
# 6   -0.629334
# 7    4.714527
# Name: 0, dtype: float64
# 0.8815604913467983 2.730473364036799
# 8    0.366484
# 9   -4.282459
# Name: 0, dtype: float64
# 0.8815604913467983 2.730473364036799
#   Gender   Size  Kinematic
# 0  women  small  -4.543697
# 1  women  small  -4.458970
# 2  women  small  -0.737522
# 3  women  large  -1.150448
# 4  women  large  -7.269808
# 5    men  small  -4.092255
# 6    men  small   4.333031
# 7    men  small  -0.737522
# 8    men  large  -5.100321
# 9    men  large  -2.290980
#                       sum_sq   df         F    PR(>F)
# C(Gender)          10.552219  1.0  0.929702  0.372177
# C(Size)            12.114745  1.0  1.067368  0.341374
# C(Gender):C(Size)   3.952678  1.0  0.348250  0.576639
# Residual           68.100660  6.0       NaN       NaN
#
# Mean: Lumbar
# 0   -3.347047
# 1   -0.466641
# 2    4.714527
# Name: 0, dtype: float64
# 0.30027991385108194 3.3355028194984477
# 3   -6.828689
# 4    2.148719
# Name: 0, dtype: float64
# -2.339984958429465 4.4887037718768745
# 5   -1.440512
# 6   -0.629334
# 7    4.714527
# Name: 0, dtype: float64
# 0.8815604913467983 2.730473364036799
# 8    0.366484
# 9   -4.282459
# Name: 0, dtype: float64
# 0.8815604913467983 2.730473364036799
#   Gender   Size  Kinematic
# 0  women  small   2.079774
# 1  women  small  -0.558826
# 2  women  small  -5.694281
# 3  women  large  -3.373331
# 4  women  large  -1.006398
# 5    men  small  -1.652869
# 6    men  small   6.541951
# 7    men  small  -5.694281
# 8    men  large  -4.199026
# 9    men  large  -0.269801
#                        sum_sq   df         F    PR(>F)
# C(Gender)            1.075208  1.0  0.053978  0.824002
# C(Size)              4.586362  1.0  0.230248  0.648331
# C(Gender):C(Size)    0.817498  1.0  0.041041  0.846154
# Residual           119.515428  6.0       NaN       NaN

# %%
print('Mean')
box_whisker(mean_stand_lat)
print('Min')
box_whisker(min_stand_lat)
print('Max')
box_whisker(max_stand_lat)
# Out:
# Mean
# Min
# Max

# %%
# Axial Flexion
# Flexion
print('\033[1mAxial Flexion\033[0m')
print('')

# Minimums
url_min_stand_axi = 'https://raw.githubusercontent.com/GraceHerchenroder/Thesis/main/min_stand_axi.csv'
min_stand_axi = pd.read_csv(url_min_stand_axi, header = None)

print('Minimum: Upper Thoracic')
result_min_stand_axi_ut = statAnova_ut(min_stand_axi)
print(result_min_stand_axi_ut)
if result_min_stand_axi_ut['PR(>F)'][0] < 0.05:
  print('Gender: Significant')
if result_min_stand_axi_ut['PR(>F)'][1] < 0.05:
  print('Size: Significant')
if result_min_stand_axi_ut['PR(>F)'][2] < 0.05:
  result = significant_ut(min_stand_axi, result_min_stand_axi_ut['PR(>F)'])
  print('Small: ', result[1], ', Large: ', result[2], ', Women: ', result[3], ', Men: ', result[4])
  if result[1] < result[0]:
    print('Small: Significant')
  if result[2] < result[0]:
    print('Large: Significant')
  if result[3] < result[0]:
    print('Women: Significant')
  if result[4] < result[0]:
    print('Men: Significant')
print('')

print('Minimum: Lower Thoracic')
result_min_stand_axi_lt = statAnova_lt(min_stand_axi)
print(result_min_stand_axi_lt)
if result_min_stand_axi_lt['PR(>F)'][0] < 0.05:
  print('Gender: Significant')
if result_min_stand_axi_lt['PR(>F)'][1] < 0.05:
  print('Size: Significant')
if result_min_stand_axi_lt['PR(>F)'][2] < 0.05:
  result = significant_lt(min_stand_axi, result_min_stand_axi_lt['PR(>F)'])
  print('Small: ', result[1], ', Large: ', result[2], ', Women: ', result[3], ', Men: ', result[4])
  if result[1] < result[0]:
    print('Small: Significant')
  if result[2] < result[0]:
    print('Large: Significant')
  if result[3] < result[0]:
    print('Women: Significant')
  if result[4] < result[0]:
    print('Men: Significant')
print('')

print('Minimum: Lumbar')
result_min_stand_axi_lum = statAnova_lum(min_stand_axi)
print(result_min_stand_axi_lum)
if result_min_stand_axi_lum['PR(>F)'][0] < 0.05:
  print('Gender: Significant')
if result_min_stand_axi_lum['PR(>F)'][1] < 0.05:
  print('Size: Significant')
if result_min_stand_axi_lum['PR(>F)'][2] < 0.05:
  result = significant_lum(min_stand_axi, result_min_stand_axi_lum['PR(>F)'])
  print('Small: ', result[1], ', Large: ', result[2], ', Women: ', result[3], ', Men: ', result[4])
  if result[1] < result[0]:
    print('Small: Significant')
  if result[2] < result[0]:
    print('Large: Significant')
  if result[3] < result[0]:
    print('Women: Significant')
  if result[4] < result[0]:
    print('Men: Significant')
print('')

# Maximums
url_max_stand_axi = 'https://raw.githubusercontent.com/GraceHerchenroder/Thesis/main/max_stand_axi.csv'
max_stand_axi = pd.read_csv(url_max_stand_axi, header = None)

print('Maximum: Upper Thoracic')
result_max_stand_axi_ut = statAnova_ut(max_stand_axi)
print(result_max_stand_axi_ut)
if result_max_stand_axi_ut['PR(>F)'][0] < 0.05:
  print('Gender: Significant')
if result_max_stand_axi_ut['PR(>F)'][1] < 0.05:
  print('Size: Significant')
if result_max_stand_axi_ut['PR(>F)'][2] < 0.05:
  result = significant_ut(max_stand_axi, result_max_stand_axi_ut['PR(>F)'])
  print('Small: ', result[1], ', Large: ', result[2], ', Women: ', result[3], ', Men: ', result[4])
  if result[1] < result[0]:
    print('Small: Significant')
  if result[2] < result[0]:
    print('Large: Significant')
  if result[3] < result[0]:
    print('Women: Significant')
  if result[4] < result[0]:
    print('Men: Significant')
print('')

print('Maximum: Lower Thoracic')
result_max_stand_axi_lt = statAnova_lt(max_stand_axi)
print(result_max_stand_axi_lt)
if result_max_stand_axi_lt['PR(>F)'][0] < 0.05:
  print('Gender: Significant')
if result_max_stand_axi_lt['PR(>F)'][1] < 0.05:
  print('Size: Significant')
if result_max_stand_axi_lt['PR(>F)'][2] < 0.05:
  result = significant_lt(max_stand_axi, result_max_stand_axi_lt['PR(>F)'])
  print('Small: ', result[1], ', Large: ', result[2], ', Women: ', result[3], ', Men: ', result[4])
  if result[1] < result[0]:
    print('Small: Significant')
  if result[2] < result[0]:
    print('Large: Significant')
  if result[3] < result[0]:
    print('Women: Significant')
  if result[4] < result[0]:
    print('Men: Significant')
print('')

print('Maximum: Lumbar')
result_max_stand_axi_lum = statAnova_lum(max_stand_axi)
print(result_max_stand_axi_lum)
if result_max_stand_axi_lum['PR(>F)'][0] < 0.05:
  print('Gender: Significant')
if result_max_stand_axi_lum['PR(>F)'][1] < 0.05:
  print('Size: Significant')
if result_max_stand_axi_lum['PR(>F)'][2] < 0.05:
  result = significant_lum(max_stand_axi, result_max_stand_axi_lum['PR(>F)'])
  print('Small: ', result[1], ', Large: ', result[2], ', Women: ', result[3], ', Men: ', result[4])
  if result[1] < result[0]:
    print('Small: Significant')
  if result[2] < result[0]:
    print('Large: Significant')
  if result[3] < result[0]:
    print('Women: Significant')
  if result[4] < result[0]:
    print('Men: Significant')
print('')

# Means
url_mean_stand_axi = 'https://raw.githubusercontent.com/GraceHerchenroder/Thesis/main/mean_stand_axi.csv'
mean_stand_axi = pd.read_csv(url_mean_stand_axi, header = None)

print('Mean: Upper Thoracic')
result_mean_stand_axi_ut = statAnova_ut(mean_stand_axi)
print(result_mean_stand_axi_ut)
if result_mean_stand_axi_ut['PR(>F)'][0] < 0.05:
  print('Gender: Significant')
if result_mean_stand_axi_ut['PR(>F)'][1] < 0.05:
  print('Size: Significant')
if result_mean_stand_axi_ut['PR(>F)'][2] < 0.05:
  result = significant_ut(mean_stand_axi, result_mean_stand_axi_ut['PR(>F)'])
  print('Small: ', result[1], ', Large: ', result[2], ', Women: ', result[3], ', Men: ', result[4])
  if result[1] < result[0]:
    print('Small: Significant')
  if result[2] < result[0]:
    print('Large: Significant')
  if result[3] < result[0]:
    print('Women: Significant')
  if result[4] < result[0]:
    print('Men: Significant')
print('')

print('Mean: Lower Thoracic')
result_mean_stand_axi_lt = statAnova_lt(mean_stand_axi)
print(result_mean_stand_axi_lt)
if result_mean_stand_axi_lt['PR(>F)'][0] < 0.05:
  print('Gender: Significant')
if result_mean_stand_axi_lt['PR(>F)'][1] < 0.05:
  print('Size: Significant')
if result_mean_stand_axi_lt['PR(>F)'][2] < 0.05:
  result = significant_lt(mean_stand_axi, result_mean_stand_axi_lt['PR(>F)'])
  print('Small: ', result[1], ', Large: ', result[2], ', Women: ', result[3], ', Men: ', result[4])
  if result[1] < result[0]:
    print('Small: Significant')
  if result[2] < result[0]:
    print('Large: Significant')
  if result[3] < result[0]:
    print('Women: Significant')
  if result[4] < result[0]:
    print('Men: Significant')
print('')

print('Mean: Lumbar')
result_mean_stand_axi_lum = statAnova_lum(mean_stand_axi)
print(result_mean_stand_axi_lum)
if result_mean_stand_axi_lum['PR(>F)'][0] < 0.05:
  print('Gender: Significant')
if result_mean_stand_axi_lum['PR(>F)'][1] < 0.05:
  print('Size: Significant')
if result_mean_stand_axi_lum['PR(>F)'][2] < 0.05:
  result = significant_lum(mean_stand_axi, result_mean_stand_axi_lum['PR(>F)'])
  print('Small: ', result[1], ', Large: ', result[2], ', Women: ', result[3], ', Men: ', result[4])
  if result[1] < result[0]:
    print('Small: Significant')
  if result[2] < result[0]:
    print('Large: Significant')
  if result[3] < result[0]:
    print('Women: Significant')
  if result[4] < result[0]:
    print('Men: Significant')
print('')
# Out:
# Axial Flexion
#
# Minimum: Upper Thoracic
# 0   -14.697686
# 1    -4.809211
# 2   -15.142645
# Name: 0, dtype: float64
# -11.5498473165036 4.7698099041497874
# 3   -9.633537
# 4   -6.758128
# Name: 0, dtype: float64
# -8.195832640992414 1.4377043009463852
# 5    -4.242759
# 6   -10.620657
# 7   -15.142645
# Name: 0, dtype: float64
# -10.002020419376453 4.471309585348013
# 8    -7.980289
# 9   -10.923557
# Name: 0, dtype: float64
# -10.002020419376453 4.471309585348013
#   Gender   Size  Kinematic
# 0  women  small -14.697686
# 1  women  small  -4.809211
# 2  women  small -15.142645
# 3  women  large  -9.633537
# 4  women  large  -6.758128
# 5    men  small  -4.242759
# 6    men  small -10.620657
# 7    men  small -15.142645
# 8    men  large  -7.980289
# 9    men  large -10.923557
#                        sum_sq   df         F    PR(>F)
# C(Gender)            0.454244  1.0  0.019938  0.892332
# C(Size)              9.145253  1.0  0.401411  0.549735
# C(Gender):C(Size)    4.717172  1.0  0.207050  0.665090
# Residual           136.696489  6.0       NaN       NaN
#
# Minimum: Lower Thoracic
# 0   -14.697686
# 1    -4.809211
# 2   -15.142645
# Name: 0, dtype: float64
# -11.5498473165036 4.7698099041497874
# 3   -9.633537
# 4   -6.758128
# Name: 0, dtype: float64
# -8.195832640992414 1.4377043009463852
# 5    -4.242759
# 6   -10.620657
# 7   -15.142645
# Name: 0, dtype: float64
# -10.002020419376453 4.471309585348013
# 8    -7.980289
# 9   -10.923557
# Name: 0, dtype: float64
# -10.002020419376453 4.471309585348013
#   Gender   Size  Kinematic
# 0  women  small  -2.958365
# 1  women  small  -8.638448
# 2  women  small   3.528681
# 3  women  large  -3.641842
# 4  women  large -11.718137
# 5    men  small -25.234583
# 6    men  small -20.220309
# 7    men  small   3.528681
# 8    men  large -18.668999
# 9    men  large -11.352894
#                        sum_sq   df         F    PR(>F)
# C(Gender)          235.418969  1.0  2.332170  0.177581
# C(Size)             21.788728  1.0  0.215849  0.658602
# C(Gender):C(Size)    9.385545  1.0  0.092978  0.770726
# Residual           605.664931  6.0       NaN       NaN
#
# Minimum: Lumbar
# 0   -14.697686
# 1    -4.809211
# 2   -15.142645
# Name: 0, dtype: float64
# -11.5498473165036 4.7698099041497874
# 3   -9.633537
# 4   -6.758128
# Name: 0, dtype: float64
# -8.195832640992414 1.4377043009463852
# 5    -4.242759
# 6   -10.620657
# 7   -15.142645
# Name: 0, dtype: float64
# -10.002020419376453 4.471309585348013
# 8    -7.980289
# 9   -10.923557
# Name: 0, dtype: float64
# -10.002020419376453 4.471309585348013
#   Gender   Size  Kinematic
# 0  women  small  -5.120161
# 1  women  small  -2.305721
# 2  women  small  -1.621834
# 3  women  large -11.825111
# 4  women  large  -6.268585
# 5    men  small  -3.186803
# 6    men  small  -1.652437
# 7    men  small  -1.621834
# 8    men  large -10.253596
# 9    men  large  -1.539601
#                       sum_sq   df         F    PR(>F)
# C(Gender)           7.898131  1.0  0.765799  0.415172
# C(Size)            57.316880  1.0  5.557418  0.056483
# C(Gender):C(Size)   3.141065  1.0  0.304556  0.600975
# Residual           61.881484  6.0       NaN       NaN
#
# Maximum: Upper Thoracic
# 0    12.016875
# 1     7.077604
# 2    10.985546
# Name: 0, dtype: float64
# 10.026675113412537 2.127389042117886
# 3     9.506145
# 4    15.007177
# Name: 0, dtype: float64
# 12.256661074050875 2.750515701245325
# 5    16.256509
# 6     0.252570
# 7    10.985546
# Name: 0, dtype: float64
# 9.164875009864621 6.659211634867629
# 8     3.273660
# 9    11.620817
# Name: 0, dtype: float64
# 9.164875009864621 6.659211634867629
#   Gender   Size  Kinematic
# 0  women  small  12.016875
# 1  women  small   7.077604
# 2  women  small  10.985546
# 3  women  large   9.506145
# 4  women  large  15.007177
# 5    men  small  16.256509
# 6    men  small   0.252570
# 7    men  small  10.985546
# 8    men  large   3.273660
# 9    men  large  11.620817
#                        sum_sq   df         F    PR(>F)
# C(Gender)           14.894359  1.0  0.454603  0.525268
# C(Size)              0.157501  1.0  0.004807  0.946977
# C(Gender):C(Size)    9.350233  1.0  0.285386  0.612397
# Residual           196.580842  6.0       NaN       NaN
#
# Maximum: Lower Thoracic
# 0    12.016875
# 1     7.077604
# 2    10.985546
# Name: 0, dtype: float64
# 10.026675113412537 2.127389042117886
# 3     9.506145
# 4    15.007177
# Name: 0, dtype: float64
# 12.256661074050875 2.750515701245325
# 5    16.256509
# 6     0.252570
# 7    10.985546
# Name: 0, dtype: float64
# 9.164875009864621 6.659211634867629
# 8     3.273660
# 9    11.620817
# Name: 0, dtype: float64
# 9.164875009864621 6.659211634867629
#   Gender   Size  Kinematic
# 0  women  small  10.699319
# 1  women  small   6.121937
# 2  women  small  25.038902
# 3  women  large   9.657978
# 4  women  large  13.072450
# 5    men  small   5.134909
# 6    men  small  10.272714
# 7    men  small  25.038902
# 8    men  large   6.944006
# 9    men  large  10.142999
#                        sum_sq   df         F    PR(>F)
# C(Gender)            4.980205  1.0  0.071266  0.798440
# C(Size)             33.992023  1.0  0.486422  0.511634
# C(Gender):C(Size)    3.314912  1.0  0.047436  0.834805
# Residual           419.290728  6.0       NaN       NaN
#
# Maximum: Lumbar
# 0    12.016875
# 1     7.077604
# 2    10.985546
# Name: 0, dtype: float64
# 10.026675113412537 2.127389042117886
# 3     9.506145
# 4    15.007177
# Name: 0, dtype: float64
# 12.256661074050875 2.750515701245325
# 5    16.256509
# 6     0.252570
# 7    10.985546
# Name: 0, dtype: float64
# 9.164875009864621 6.659211634867629
# 8     3.273660
# 9    11.620817
# Name: 0, dtype: float64
# 9.164875009864621 6.659211634867629
#   Gender   Size  Kinematic
# 0  women  small   9.941014
# 1  women  small   6.130944
# 2  women  small  14.865574
# 3  women  large   4.424500
# 4  women  large  10.049352
# 5    men  small   6.928393
# 6    men  small  15.041948
# 7    men  small  14.865574
# 8    men  large   5.884958
# 9    men  large   8.443380
#                        sum_sq   df         F    PR(>F)
# C(Gender)            3.309550  1.0  0.197783  0.672109
# C(Size)             40.246185  1.0  2.405165  0.171916
# C(Gender):C(Size)    2.494229  1.0  0.149058  0.712756
# Residual           100.399377  6.0       NaN       NaN
#
# Mean: Upper Thoracic
# 0    4.103677
# 1    0.433417
# 2   -3.496476
# Name: 0, dtype: float64
# 0.34687260578989215 3.1033526999807948
# 3   -1.337660
# 4   -1.972436
# Name: 0, dtype: float64
# -1.65504782291264 0.317388113176
# 5    7.549667
# 6   -4.999803
# 7   -3.496476
# Name: 0, dtype: float64
# -0.31553716314881336 5.595300493524908
# 8   -2.311096
# 9    4.926900
# Name: 0, dtype: float64
# -0.31553716314881336 5.595300493524908
#   Gender   Size  Kinematic
# 0  women  small   4.103677
# 1  women  small   0.433417
# 2  women  small  -3.496476
# 3  women  large  -1.337660
# 4  women  large  -1.972436
# 5    men  small   7.549667
# 6    men  small  -4.999803
# 7    men  small  -3.496476
# 8    men  large  -2.311096
# 9    men  large   4.926900
#                        sum_sq   df         F    PR(>F)
# C(Gender)            1.551313  1.0  0.062381  0.811103
# C(Size)              0.085949  1.0  0.003456  0.955029
# C(Gender):C(Size)    7.885940  1.0  0.317107  0.593754
# Residual           149.210324  6.0       NaN       NaN
#
# Mean: Lower Thoracic
# 0    4.103677
# 1    0.433417
# 2   -3.496476
# Name: 0, dtype: float64
# 0.34687260578989215 3.1033526999807948
# 3   -1.337660
# 4   -1.972436
# Name: 0, dtype: float64
# -1.65504782291264 0.317388113176
# 5    7.549667
# 6   -4.999803
# 7   -3.496476
# Name: 0, dtype: float64
# -0.31553716314881336 5.595300493524908
# 8   -2.311096
# 9    4.926900
# Name: 0, dtype: float64
# -0.31553716314881336 5.595300493524908
#   Gender   Size  Kinematic
# 0  women  small   5.153902
# 1  women  small  -0.952843
# 2  women  small  12.819310
# 3  women  large   5.057601
# 4  women  large   0.525877
# 5    men  small  -2.476949
# 6    men  small  -4.087263
# 7    men  small  12.819310
# 8    men  large  -8.259274
# 9    men  large   4.043442
#                        sum_sq   df         F    PR(>F)
# C(Gender)           42.290200  1.0  0.714118  0.430482
# C(Size)             30.030539  1.0  0.507099  0.503133
# C(Gender):C(Size)    1.031597  1.0  0.017420  0.899312
# Residual           355.321288  6.0       NaN       NaN
#
# Mean: Lumbar
# 0    4.103677
# 1    0.433417
# 2   -3.496476
# Name: 0, dtype: float64
# 0.34687260578989215 3.1033526999807948
# 3   -1.337660
# 4   -1.972436
# Name: 0, dtype: float64
# -1.65504782291264 0.317388113176
# 5    7.549667
# 6   -4.999803
# 7   -3.496476
# Name: 0, dtype: float64
# -0.31553716314881336 5.595300493524908
# 8   -2.311096
# 9    4.926900
# Name: 0, dtype: float64
# -0.31553716314881336 5.595300493524908
#   Gender   Size  Kinematic
# 0  women  small  -0.850179
# 1  women  small   3.806301
# 2  women  small   8.522202
# 3  women  large  -0.502271
# 4  women  large   0.188217
# 5    men  small   2.160836
# 6    men  small   2.994468
# 7    men  small   8.522202
# 8    men  large  -0.337188
# 9    men  large   2.859714
#                       sum_sq   df         F    PR(>F)
# C(Gender)           2.535891  1.0  0.207929  0.664434
# C(Size)            31.808132  1.0  2.608088  0.157447
# C(Gender):C(Size)   0.281723  1.0  0.023100  0.884180
# Residual           73.175746  6.0       NaN       NaN

# %%
print('Mean')
box_whisker(mean_stand_axi)
print('Min')
box_whisker(min_stand_axi)
print('Max')
box_whisker(max_stand_axi)
# Out:
# Mean
# Min
# Max
