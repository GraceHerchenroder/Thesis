# %% [markdown]
# <a href="https://colab.research.google.com/github/GraceHerchenroder/Thesis/blob/main/Thesis_Statistics_Sitting_Newest.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# Importing libraries
import pandas as pd
import numpy as np
import statsmodels.api as sm
from statsmodels.formula.api import ols
from scipy import stats
from statsmodels.stats.multitest import multipletests
import matplotlib.pyplot as plt

# %%
# Performing two-way ANOVA
def statAnova_ut(kinematic_data):
  dataframe = pd.DataFrame({'Gender': np.repeat(['women', 'men'], 5),
                          'Size': ['small', 'small', 'small', 'large', 'large', 'small', 'small', 'small', 'large', 'large'],
                          'Kinematic': kinematic_data[0][:]})
  group_1_mean = np.mean(kinematic_data[0][:3])
  group_1_sd = np.std(kinematic_data[0][:3])
  group_2_mean = np.mean(kinematic_data[0][3:5])
  group_2_sd = np.std(kinematic_data[0][3:5])
  group_3_mean = np.mean(kinematic_data[0][5:8])
  group_3_sd = np.std(kinematic_data[0][5:8])
  group_4_mean = np.mean(kinematic_data[0][8:])
  group_4_sd = np.std(kinematic_data[0][8:])
  print(kinematic_data[0][:3])
  print(group_1_mean, group_1_sd)
  print(kinematic_data[0][3:5])
  print(group_2_mean, group_2_sd)
  print(kinematic_data[0][5:8])
  print(group_3_mean, group_3_sd)
  print(kinematic_data[0][8:])
  print(group_3_mean, group_3_sd)
  print(dataframe)
  model = ols('Kinematic ~ C(Gender) + C(Size) + C(Gender):C(Size)', data=dataframe).fit()
  result = sm.stats.anova_lm(model, typ=2)
  return result

def statAnova_lt(kinematic_data):
  dataframe = pd.DataFrame({'Gender': np.repeat(['women', 'men'], 5),
                          'Size': ['small', 'small', 'small', 'large', 'large', 'small', 'small', 'small', 'large', 'large'],
                          'Kinematic': kinematic_data[1][:]})
  group_1_mean = np.mean(kinematic_data[0][:3])
  group_1_sd = np.std(kinematic_data[0][:3])
  group_2_mean = np.mean(kinematic_data[0][3:5])
  group_2_sd = np.std(kinematic_data[0][3:5])
  group_3_mean = np.mean(kinematic_data[0][5:8])
  group_3_sd = np.std(kinematic_data[0][5:8])
  group_4_mean = np.mean(kinematic_data[0][8:])
  group_4_sd = np.std(kinematic_data[0][8:])
  print(kinematic_data[0][:3])
  print(group_1_mean, group_1_sd)
  print(kinematic_data[0][3:5])
  print(group_2_mean, group_2_sd)
  print(kinematic_data[0][5:8])
  print(group_3_mean, group_3_sd)
  print(kinematic_data[0][8:])
  print(group_3_mean, group_3_sd)
  print(dataframe)
  model = ols('Kinematic ~ C(Gender) + C(Size) + C(Gender):C(Size)', data=dataframe).fit()
  result = sm.stats.anova_lm(model, typ=2)
  return result

def statAnova_lum(kinematic_data):
  dataframe = pd.DataFrame({'Gender': np.repeat(['women', 'men'], 5),
                          'Size': ['small', 'small', 'small', 'large', 'large', 'small', 'small', 'small', 'large', 'large'],
                          'Kinematic': kinematic_data[2][:]})
  group_1_mean = np.mean(kinematic_data[0][:3])
  group_1_sd = np.std(kinematic_data[0][:3])
  group_2_mean = np.mean(kinematic_data[0][3:5])
  group_2_sd = np.std(kinematic_data[0][3:5])
  group_3_mean = np.mean(kinematic_data[0][5:8])
  group_3_sd = np.std(kinematic_data[0][5:8])
  group_4_mean = np.mean(kinematic_data[0][8:])
  group_4_sd = np.std(kinematic_data[0][8:])
  print(kinematic_data[0][:3])
  print(group_1_mean, group_1_sd)
  print(kinematic_data[0][3:5])
  print(group_2_mean, group_2_sd)
  print(kinematic_data[0][5:8])
  print(group_3_mean, group_3_sd)
  print(kinematic_data[0][8:])
  print(group_3_mean, group_3_sd)
  print(dataframe)
  model = ols('Kinematic ~ C(Gender) + C(Size) + C(Gender):C(Size)', data=dataframe).fit()
  result = sm.stats.anova_lm(model, typ=2)
  return result

def box_whisker(kinematic_data):
   small_men_data_ut = kinematic_data[0][8:]
   large_men_data_ut = kinematic_data[0][5:8]
   small_women_data_ut = kinematic_data[0][:3]
   large_women_data_ut = kinematic_data[0][3:5]
   small_men_data_lt = kinematic_data[1][8:]
   large_men_data_lt = kinematic_data[1][5:8]
   small_women_data_lt = kinematic_data[1][:3]
   large_women_data_lt = kinematic_data[1][3:5]
   small_men_data_lum = kinematic_data[2][8:]
   large_men_data_lum = kinematic_data[2][5:8]
   small_women_data_lum = kinematic_data[2][:3]
   large_women_data_lum = kinematic_data[2][3:5]
   fig, ax = plt.subplots(3, 2, figsize=(6, 10))
   ax[0][0].boxplot([small_men_data_ut, large_men_data_ut], labels = ['small', 'large'])
   ax[0][0].set_title('Men')
   ax[0][0].set_ylabel('Upper Thoracic')
   ax[0][1].boxplot([small_women_data_ut, large_women_data_ut], labels = ['small', 'large'])
   ax[0][1].set_title('Women')
   ax[1][0].boxplot([small_men_data_lt, large_men_data_lt], labels = ['small', 'large'])
   ax[1][0].set_title('Men')
   ax[1][0].set_ylabel('Lower Thoracic')
   ax[1][1].boxplot([small_women_data_lt, large_women_data_lt], labels = ['small', 'large'])
   ax[1][1].set_title('Women')
   ax[2][0].boxplot([small_men_data_lum, large_men_data_lum], labels = ['small', 'large'])
   ax[2][0].set_title('Men')
   ax[2][0].set_ylabel('Lumbar')
   ax[2][1].boxplot([small_women_data_lum, large_women_data_lum], labels = ['small', 'large'])
   ax[2][1].set_title('Women')
   plt.show()

# %%
# Follow Up analysis: Significant
def significant_ut(kinematic_data, p_values):
  [reject, p_corrected] = multipletests(p_values, method = 'bonferroni')
  small_men_data = kinematic_data[0][8:]
  large_men_data = kinematic_data[0][5:8]
  small_women_data = kinematic_data[0][:3]
  large_women_data = kinematic_data[0][3:5]

  [stat_small, p_small] = stats.ttest_ind(small_men_data, small_women_data);
  [stat_large, p_large] = stats.ttest_ind(large_men_data, large_women_data);
  [stat_women, p_women] = stats.ttest_ind(small_women_data, large_women_data);
  [stat_men, p_men] = stats.ttest_ind(small_men_data, large_men_data);

  return [p_corrected, p_small, p_large, p_women, p_men]

def significant_lt(kinematic_data, p_values):
  [reject, p_corrected] = multipletests(p_values, method = 'bonferroni')
  small_men_data = kinematic_data[1][8:]
  large_men_data = kinematic_data[1][5:8]
  small_women_data = kinematic_data[1][:3]
  large_women_data = kinematic_data[1][3:5]

  [stat_small, p_small] = stats.ttest_ind(small_men_data, small_women_data);
  [stat_large, p_large] = stats.ttest_ind(large_men_data, large_women_data);
  [stat_women, p_women] = stats.ttest_ind(small_women_data, large_women_data);
  [stat_men, p_men] = stats.ttest_ind(small_men_data, large_men_data);

  return [p_corrected, p_small, p_large, p_women, p_men]

def significant_lum(kinematic_data, p_values):
  [reject, p_corrected] = multipletests(p_values, method = 'bonferroni')
  small_men_data = kinematic_data[2][8:]
  large_men_data = kinematic_data[2][5:8]
  small_women_data = kinematic_data[2][:3]
  large_women_data = kinematic_data[2][3:5]

  [stat_small, p_small] = stats.ttest_ind(small_men_data, small_women_data);
  [stat_large, p_large] = stats.ttest_ind(large_men_data, large_women_data);
  [stat_women, p_women] = stats.ttest_ind(small_women_data, large_women_data);
  [stat_men, p_men] = stats.ttest_ind(small_men_data, large_men_data);

  return [p_corrected, p_small, p_large, p_women, p_men]

# %%
# Flexion
print('\033[1mFlexion\033[0m')
print('')

# Minimums
url_min_sit_flex = 'https://raw.githubusercontent.com/GraceHerchenroder/Thesis/main/min_sit_flex.csv'
min_sit_flex = pd.read_csv(url_min_sit_flex, header = None)

print('Minimum: Upper Thoracic')
result_min_sit_flex_ut = statAnova_ut(min_sit_flex)
print(result_min_sit_flex_ut)
if result_min_sit_flex_ut['PR(>F)'][0] < 0.05:
  print('Gender: Significant')
if result_min_sit_flex_ut['PR(>F)'][1] < 0.05:
  print('Size: Significant')
if result_min_sit_flex_ut['PR(>F)'][2] < 0.05:
  result = significant_ut(min_sit_flex, result_min_sit_flex_ut['PR(>F)'])
  print('Small: ', result[1], ', Large: ', result[2], ', Women: ', result[3], ', Men: ', result[4])
  if result[1] < result[0]:
    print('Small: Significant')
  if result[2] < result[0]:
    print('Large: Significant')
  if result[3] < result[0]:
    print('Women: Significant')
  if result[4] < result[0]:
    print('Men: Significant')
print('')

print('Minimum: Lower Thoracic')
result_min_sit_flex_lt = statAnova_lt(min_sit_flex)
print(result_min_sit_flex_lt)
if result_min_sit_flex_lt['PR(>F)'][0] < 0.05:
  print('Gender: Significant')
if result_min_sit_flex_lt['PR(>F)'][1] < 0.05:
  print('Size: Significant')
if result_min_sit_flex_lt['PR(>F)'][2] < 0.05:
  result = significant_lt(min_sit_flex, result_min_sit_flex_lt['PR(>F)'])
  print('Small: ', result[1], ', Large: ', result[2], ', Women: ', result[3], ', Men: ', result[4])
  if result[1] < result[0]:
    print('Small: Significant')
  if result[2] < result[0]:
    print('Large: Significant')
  if result[3] < result[0]:
    print('Women: Significant')
  if result[4] < result[0]:
    print('Men: Significant')
print('')

print('Minimum: Lumbar')
result_min_sit_flex_lum = statAnova_lum(min_sit_flex)
print(result_min_sit_flex_lum)
if result_min_sit_flex_lum['PR(>F)'][0] < 0.05:
  print('Gender: Significant')
if result_min_sit_flex_lum['PR(>F)'][1] < 0.05:
  print('Size: Significant')
if result_min_sit_flex_lum['PR(>F)'][2] < 0.05:
  result = significant_lum(min_sit_flex, result_min_sit_flex_lum['PR(>F)'])
  print('Small: ', result[1], ', Large: ', result[2], ', Women: ', result[3], ', Men: ', result[4])
  if result[1] < result[0]:
    print('Small: Significant')
  if result[2] < result[0]:
    print('Large: Significant')
  if result[3] < result[0]:
    print('Women: Significant')
  if result[4] < result[0]:
    print('Men: Significant')
print('')

# Maximums
url_max_sit_flex = 'https://raw.githubusercontent.com/GraceHerchenroder/Thesis/main/max_sit_flex.csv'
max_sit_flex = pd.read_csv(url_max_sit_flex, header = None)

print('Maximum: Upper Thoracic')
result_max_sit_flex_ut = statAnova_ut(max_sit_flex)
print(result_max_sit_flex_ut)
if result_max_sit_flex_ut['PR(>F)'][0] < 0.05:
  print('Gender: Significant')
if result_max_sit_flex_ut['PR(>F)'][1] < 0.05:
  print('Size: Significant')
if result_max_sit_flex_ut['PR(>F)'][2] < 0.05:
  result = significant_ut(max_sit_flex, result_max_sit_flex_ut['PR(>F)'])
  print('Small: ', result[1], ', Large: ', result[2], ', Women: ', result[3], ', Men: ', result[4])
  if result[1] < result[0]:
    print('Small: Significant')
  if result[2] < result[0]:
    print('Large: Significant')
  if result[3] < result[0]:
    print('Women: Significant')
  if result[4] < result[0]:
    print('Men: Significant')
print('')

print('Maximum: Lower Thoracic')
result_max_sit_flex_lt = statAnova_lt(max_sit_flex)
print(result_max_sit_flex_lt)
if result_max_sit_flex_lt['PR(>F)'][0] < 0.05:
  print('Gender: Significant')
if result_max_sit_flex_lt['PR(>F)'][1] < 0.05:
  print('Size: Significant')
if result_max_sit_flex_lt['PR(>F)'][2] < 0.05:
  result = significant_lt(max_sit_flex, result_max_sit_flex_lt['PR(>F)'])
  print('Small: ', result[1], ', Large: ', result[2], ', Women: ', result[3], ', Men: ', result[4])
  if result[1] < result[0]:
    print('Small: Significant')
  if result[2] < result[0]:
    print('Large: Significant')
  if result[3] < result[0]:
    print('Women: Significant')
  if result[4] < result[0]:
    print('Men: Significant')
print('')

print('Maximum: Lumbar')
result_max_sit_flex_lum = statAnova_lum(max_sit_flex)
print(result_max_sit_flex_lum)
if result_max_sit_flex_lum['PR(>F)'][0] < 0.05:
  print('Gender: Significant')
if result_max_sit_flex_lum['PR(>F)'][1] < 0.05:
  print('Size: Significant')
if result_max_sit_flex_lum['PR(>F)'][2] < 0.05:
  result = significant_lum(max_sit_flex, result_max_sit_flex_lum['PR(>F)'])
  print('Small: ', result[1], ', Large: ', result[2], ', Women: ', result[3], ', Men: ', result[4])
  if result[1] < result[0]:
    print('Small: Significant')
  if result[2] < result[0]:
    print('Large: Significant')
  if result[3] < result[0]:
    print('Women: Significant')
  if result[4] < result[0]:
    print('Men: Significant')
print('')

# Means
url_mean_sit_flex = 'https://raw.githubusercontent.com/GraceHerchenroder/Thesis/main/mean_sit_flex.csv'
mean_sit_flex = pd.read_csv(url_mean_sit_flex, header = None)

print('Mean: Upper Thoracic')
result_mean_sit_flex_ut = statAnova_ut(mean_sit_flex)
print(result_mean_sit_flex_ut)
if result_mean_sit_flex_ut['PR(>F)'][0] < 0.05:
  print('Gender: Significant')
if result_mean_sit_flex_ut['PR(>F)'][1] < 0.05:
  print('Size: Significant')
if result_mean_sit_flex_ut['PR(>F)'][2] < 0.05:
  result = significant_ut(mean_sit_flex, result_mean_sit_flex_ut['PR(>F)'])
  print('Small: ', result[1], ', Large: ', result[2], ', Women: ', result[3], ', Men: ', result[4])
  if result[1] < result[0]:
    print('Small: Significant')
  if result[2] < result[0]:
    print('Large: Significant')
  if result[3] < result[0]:
    print('Women: Significant')
  if result[4] < result[0]:
    print('Men: Significant')
print('')

print('Mean: Lower Thoracic')
result_mean_sit_flex_lt = statAnova_lt(mean_sit_flex)
print(result_mean_sit_flex_lt)
if result_mean_sit_flex_lt['PR(>F)'][0] < 0.05:
  print('Gender: Significant')
if result_mean_sit_flex_lt['PR(>F)'][1] < 0.05:
  print('Size: Significant')
if result_mean_sit_flex_lt['PR(>F)'][2] < 0.05:
  result = significant_lt(mean_sit_flex, result_mean_sit_flex_lt['PR(>F)'])
  print('Small: ', result[1], ', Large: ', result[2], ', Women: ', result[3], ', Men: ', result[4])
  if result[1] < result[0]:
    print('Small: Significant')
  if result[2] < result[0]:
    print('Large: Significant')
  if result[3] < result[0]:
    print('Women: Significant')
  if result[4] < result[0]:
    print('Men: Significant')
print('')

print('Mean: Lumbar')
result_mean_sit_flex_lum = statAnova_lum(mean_sit_flex)
print(result_mean_sit_flex_lum)
if result_mean_sit_flex_lum['PR(>F)'][0] < 0.05:
  print('Gender: Significant')
if result_mean_sit_flex_lum['PR(>F)'][1] < 0.05:
  print('Size: Significant')
if result_mean_sit_flex_lum['PR(>F)'][2] < 0.05:
  result = significant_lum(mean_sit_flex, result_mean_sit_flex_lum['PR(>F)'])
  print('Small: ', result[1], ', Large: ', result[2], ', Women: ', result[3], ', Men: ', result[4])
  if result[1] < result[0]:
    print('Small: Significant')
  if result[2] < result[0]:
    print('Large: Significant')
  if result[3] < result[0]:
    print('Women: Significant')
  if result[4] < result[0]:
    print('Men: Significant')
print('')
# Out:
# Flexion
#
# Minimum: Upper Thoracic
# 0    20.868979
# 1    15.622897
# 2    14.046538
# Name: 0, dtype: float64
# 16.846138029754268 2.9164661015227007
# 3    3.57983
# 4    0.00003
# Name: 0, dtype: float64
# 1.7899298240119006 1.7899000029804693
# 5    2.260387e+00
# 6   -8.537736e-07
# 7    1.404654e+01
# Name: 0, dtype: float64
# 5.435641479520378 6.158354607888671
# 8    8.480885
# 9    0.007467
# Name: 0, dtype: float64
# 5.435641479520378 6.158354607888671
#   Gender   Size     Kinematic
# 0  women  small  2.086898e+01
# 1  women  small  1.562290e+01
# 2  women  small  1.404654e+01
# 3  women  large  3.579830e+00
# 4  women  large  2.982103e-05
# 5    men  small  2.260387e+00
# 6    men  small -8.537736e-07
# 7    men  small  1.404654e+01
# 8    men  large  8.480885e+00
# 9    men  large  7.467445e-03
#                        sum_sq   df         F    PR(>F)
# C(Gender)           85.983815  1.0  2.840872  0.142873
# C(Size)            158.392136  1.0  5.233214  0.062146
# C(Gender):C(Size)  115.338658  1.0  3.810744  0.098769
# Residual           181.600204  6.0       NaN       NaN
#
# Minimum: Lower Thoracic
# 0    20.868979
# 1    15.622897
# 2    14.046538
# Name: 0, dtype: float64
# 16.846138029754268 2.9164661015227007
# 3    3.57983
# 4    0.00003
# Name: 0, dtype: float64
# 1.7899298240119006 1.7899000029804693
# 5    2.260387e+00
# 6   -8.537736e-07
# 7    1.404654e+01
# Name: 0, dtype: float64
# 5.435641479520378 6.158354607888671
# 8    8.480885
# 9    0.007467
# Name: 0, dtype: float64
# 5.435641479520378 6.158354607888671
#   Gender   Size  Kinematic
# 0  women  small  18.029603
# 1  women  small  17.286545
# 2  women  small  30.461809
# 3  women  large  20.733012
# 4  women  large   5.460854
# 5    men  small -14.085120
# 6    men  small -16.372474
# 7    men  small  30.461809
# 8    men  large -37.949799
# 9    men  large  22.877502
#                         sum_sq   df         F    PR(>F)
# C(Gender)          1145.754127  1.0  1.980825  0.208940
# C(Size)             160.719488  1.0  0.277858  0.617021
# C(Gender):C(Size)     1.000782  1.0  0.001730  0.968171
# Residual           3470.536430  6.0       NaN       NaN
#
# Minimum: Lumbar
# 0    20.868979
# 1    15.622897
# 2    14.046538
# Name: 0, dtype: float64
# 16.846138029754268 2.9164661015227007
# 3    3.57983
# 4    0.00003
# Name: 0, dtype: float64
# 1.7899298240119006 1.7899000029804693
# 5    2.260387e+00
# 6   -8.537736e-07
# 7    1.404654e+01
# Name: 0, dtype: float64
# 5.435641479520378 6.158354607888671
# 8    8.480885
# 9    0.007467
# Name: 0, dtype: float64
# 5.435641479520378 6.158354607888671
#   Gender   Size  Kinematic
# 0  women  small  -3.428070
# 1  women  small -12.287055
# 2  women  small -10.247059
# 3  women  large  -9.382781
# 4  women  large   6.897139
# 5    men  small -10.432031
# 6    men  small -13.667611
# 7    men  small -10.247059
# 8    men  large -22.638222
# 9    men  large   1.368011
#                        sum_sq   df         F    PR(>F)
# C(Gender)           73.815924  1.0  0.940099  0.369698
# C(Size)             40.590726  1.0  0.516952  0.499177
# C(Gender):C(Size)   26.115774  1.0  0.332603  0.585101
# Residual           471.115889  6.0       NaN       NaN
#
# Maximum: Upper Thoracic
# 0    31.114507
# 1    31.649222
# 2    28.372962
# Name: 0, dtype: float64
# 30.378896777374198 1.4351102235090927
# 3    37.783987
# 4    10.968141
# Name: 0, dtype: float64
# 24.3760641895916 13.407922793766298
# 5    23.002363
# 6    23.478877
# 7    28.372962
# Name: 0, dtype: float64
# 24.951400443900866 2.4272174752124314
# 8    18.539627
# 9    12.983119
# Name: 0, dtype: float64
# 24.951400443900866 2.4272174752124314
#   Gender   Size  Kinematic
# 0  women  small  31.114507
# 1  women  small  31.649222
# 2  women  small  28.372962
# 3  women  large  37.783987
# 4  women  large  10.968141
# 5    men  small  23.002363
# 6    men  small  23.478877
# 7    men  small  28.372962
# 8    men  large  18.539627
# 9    men  large  12.983119
#                        sum_sq   df         F    PR(>F)
# C(Gender)          112.304551  1.0  1.689489  0.241368
# C(Size)            138.493795  1.0  2.083475  0.199008
# C(Gender):C(Size)    6.094926  1.0  0.091691  0.772262
# Residual           398.834954  6.0       NaN       NaN
#
# Maximum: Lower Thoracic
# 0    31.114507
# 1    31.649222
# 2    28.372962
# Name: 0, dtype: float64
# 30.378896777374198 1.4351102235090927
# 3    37.783987
# 4    10.968141
# Name: 0, dtype: float64
# 24.3760641895916 13.407922793766298
# 5    23.002363
# 6    23.478877
# 7    28.372962
# Name: 0, dtype: float64
# 24.951400443900866 2.4272174752124314
# 8    18.539627
# 9    12.983119
# Name: 0, dtype: float64
# 24.951400443900866 2.4272174752124314
#   Gender   Size  Kinematic
# 0  women  small  30.320514
# 1  women  small  25.280619
# 2  women  small  36.140809
# 3  women  large  33.510217
# 4  women  large  23.021898
# 5    men  small  17.919915
# 6    men  small  26.356409
# 7    men  small  36.140809
# 8    men  large  41.378558
# 9    men  large  32.776179
#                        sum_sq   df         F    PR(>F)
# C(Gender)            3.966246  1.0  0.074981  0.793400
# C(Size)             37.988964  1.0  0.718174  0.429246
# C(Gender):C(Size)   95.048179  1.0  1.796868  0.228615
# Residual           317.379547  6.0       NaN       NaN
#
# Maximum: Lumbar
# 0    31.114507
# 1    31.649222
# 2    28.372962
# Name: 0, dtype: float64
# 30.378896777374198 1.4351102235090927
# 3    37.783987
# 4    10.968141
# Name: 0, dtype: float64
# 24.3760641895916 13.407922793766298
# 5    23.002363
# 6    23.478877
# 7    28.372962
# Name: 0, dtype: float64
# 24.951400443900866 2.4272174752124314
# 8    18.539627
# 9    12.983119
# Name: 0, dtype: float64
# 24.951400443900866 2.4272174752124314
#   Gender   Size  Kinematic
# 0  women  small  10.704373
# 1  women  small  14.596153
# 2  women  small  10.578830
# 3  women  large   8.298937
# 4  women  large  21.314547
# 5    men  small  15.185007
# 6    men  small  23.623678
# 7    men  small  10.578830
# 8    men  large  18.818250
# 9    men  large  12.156242
#                        sum_sq   df         F    PR(>F)
# C(Gender)           22.109217  1.0  0.647542  0.451692
# C(Size)              2.101951  1.0  0.061563  0.812317
# C(Gender):C(Size)    8.765597  1.0  0.256730  0.630453
# Residual           204.859803  6.0       NaN       NaN
#
# Mean: Upper Thoracic
# 0    27.043798
# 1    25.621527
# 2    24.531393
# Name: 0, dtype: float64
# 25.732239230249235 1.0286682443285806
# 3    26.613147
# 4     2.229191
# Name: 0, dtype: float64
# 14.42116917303826 12.191978235118441
# 5    15.382332
# 6    14.973199
# 7    24.531393
# Name: 0, dtype: float64
# 18.295641409132 4.412504564698338
# 8    14.643003
# 9     8.352309
# Name: 0, dtype: float64
# 18.295641409132 4.412504564698338
#   Gender   Size  Kinematic
# 0  women  small  27.043798
# 1  women  small  25.621527
# 2  women  small  24.531393
# 3  women  large  26.613147
# 4  women  large   2.229191
# 5    men  small  15.382332
# 6    men  small  14.973199
# 7    men  small  24.531393
# 8    men  large  14.643003
# 9    men  large   8.352309
#                        sum_sq   df         F    PR(>F)
# C(Gender)           79.280650  1.0  1.256229  0.305212
# C(Size)            196.762734  1.0  3.117773  0.127879
# C(Gender):C(Size)   12.220760  1.0  0.193642  0.675311
# Residual           378.660151  6.0       NaN       NaN
#
# Mean: Lower Thoracic
# 0    27.043798
# 1    25.621527
# 2    24.531393
# Name: 0, dtype: float64
# 25.732239230249235 1.0286682443285806
# 3    26.613147
# 4     2.229191
# Name: 0, dtype: float64
# 14.42116917303826 12.191978235118441
# 5    15.382332
# 6    14.973199
# 7    24.531393
# Name: 0, dtype: float64
# 18.295641409132 4.412504564698338
# 8    14.643003
# 9     8.352309
# Name: 0, dtype: float64
# 18.295641409132 4.412504564698338
#   Gender   Size  Kinematic
# 0  women  small  28.168097
# 1  women  small  23.075609
# 2  women  small  33.834183
# 3  women  large  29.866736
# 4  women  large  14.244561
# 5    men  small  11.208773
# 6    men  small  16.418627
# 7    men  small  33.834183
# 8    men  large  37.895131
# 9    men  large  29.328514
#                        sum_sq   df         F    PR(>F)
# C(Gender)            0.025397  1.0  0.000306  0.986603
# C(Size)             27.915457  1.0  0.336715  0.582852
# C(Gender):C(Size)  226.474746  1.0  2.731725  0.149460
# Residual           497.432401  6.0       NaN       NaN
#
# Mean: Lumbar
# 0    27.043798
# 1    25.621527
# 2    24.531393
# Name: 0, dtype: float64
# 25.732239230249235 1.0286682443285806
# 3    26.613147
# 4     2.229191
# Name: 0, dtype: float64
# 14.42116917303826 12.191978235118441
# 5    15.382332
# 6    14.973199
# 7    24.531393
# Name: 0, dtype: float64
# 18.295641409132 4.412504564698338
# 8    14.643003
# 9     8.352309
# Name: 0, dtype: float64
# 18.295641409132 4.412504564698338
#   Gender   Size  Kinematic
# 0  women  small   2.429349
# 1  women  small  11.967877
# 2  women  small   4.085012
# 3  women  large   0.452314
# 4  women  large  16.572270
# 5    men  small   3.831081
# 6    men  small   8.329874
# 7    men  small   4.085012
# 8    men  large -10.812004
# 9    men  large   9.275115
#                        sum_sq   df         F    PR(>F)
# C(Gender)           43.254612  1.0  0.654709  0.449322
# C(Size)              8.811553  1.0  0.133373  0.727488
# C(Gender):C(Size)   43.710943  1.0  0.661616  0.447058
# Residual           396.401580  6.0       NaN       NaN

# %%
print('Mean')
box_whisker(mean_sit_flex)
print('Min')
box_whisker(min_sit_flex)
print('Max')
box_whisker(max_sit_flex)
# Out:
# Mean
# Min
# Max

# %%
# Lateral Flexion
print('\033[1mLateral Flexion\033[0m')
print('')

# Minimums
url_min_sit_lat = 'https://raw.githubusercontent.com/GraceHerchenroder/Thesis/main/min_sit_lat.csv'
min_sit_lat = pd.read_csv(url_min_sit_lat, header = None)

print('Minimum: Upper Thoracic')
result_min_sit_lat_ut = statAnova_ut(min_sit_lat)
print(result_min_sit_lat_ut)
if result_min_sit_lat_ut['PR(>F)'][0] < 0.05:
  print('Gender: Significant')
if result_min_sit_lat_ut['PR(>F)'][1] < 0.05:
  print('Size: Significant')
if result_min_sit_lat_ut['PR(>F)'][2] < 0.05:
  result = significant_ut(min_sit_lat, result_min_sit_lat_ut['PR(>F)'])
  print('Small: ', result[1], ', Large: ', result[2], ', Women: ', result[3], ', Men: ', result[4])
  if result[1] < result[0]:
    print('Small: Significant')
  if result[2] < result[0]:
    print('Large: Significant')
  if result[3] < result[0]:
    print('Women: Significant')
  if result[4] < result[0]:
    print('Men: Significant')
print('')

print('Minimum: Lower Thoracic')
result_min_sit_lat_lt = statAnova_lt(min_sit_lat)
print(result_min_sit_lat_lt)
if result_min_sit_lat_lt['PR(>F)'][0] < 0.05:
  print('Gender: Significant')
if result_min_sit_lat_lt['PR(>F)'][1] < 0.05:
  print('Size: Significant')
if result_min_sit_lat_lt['PR(>F)'][2] < 0.05:
  result = significant_lt(min_sit_lat, result_min_sit_lat_lt['PR(>F)'])
  print('Small: ', result[1], ', Large: ', result[2], ', Women: ', result[3], ', Men: ', result[4])
  if result[1] < result[0]:
    print('Small: Significant')
  if result[2] < result[0]:
    print('Large: Significant')
  if result[3] < result[0]:
    print('Women: Significant')
  if result[4] < result[0]:
    print('Men: Significant')
print('')

print('Minimum: Lumbar')
result_min_sit_lat_lum = statAnova_lum(min_sit_lat)
print(result_min_sit_lat_lum)
if result_min_sit_lat_lum['PR(>F)'][0] < 0.05:
  print('Gender: Significant')
if result_min_sit_lat_lum['PR(>F)'][1] < 0.05:
  print('Size: Significant')
if result_min_sit_lat_lum['PR(>F)'][2] < 0.05:
  result = significant_lum(min_sit_lat, result_min_sit_lat_lum['PR(>F)'])
  print('Small: ', result[1], ', Large: ', result[2], ', Women: ', result[3], ', Men: ', result[4])
  if result[1] < result[0]:
    print('Small: Significant')
  if result[2] < result[0]:
    print('Large: Significant')
  if result[3] < result[0]:
    print('Women: Significant')
  if result[4] < result[0]:
    print('Men: Significant')
print('')

# Maximums
url_max_sit_lat = 'https://raw.githubusercontent.com/GraceHerchenroder/Thesis/main/max_sit_lat.csv'
max_sit_lat = pd.read_csv(url_max_sit_lat, header = None)

print('Maximum: Upper Thoracic')
result_max_sit_lat_ut = statAnova_ut(max_sit_lat)
print(result_max_sit_lat_ut)
if result_max_sit_lat_ut['PR(>F)'][0] < 0.05:
  print('Gender: Significant')
if result_max_sit_lat_ut['PR(>F)'][1] < 0.05:
  print('Size: Significant')
if result_max_sit_lat_ut['PR(>F)'][2] < 0.05:
  result = significant_ut(max_sit_lat, result_max_sit_lat_ut['PR(>F)'])
  print('Small: ', result[1], ', Large: ', result[2], ', Women: ', result[3], ', Men: ', result[4])
  if result[1] < result[0]:
    print('Small: Significant')
  if result[2] < result[0]:
    print('Large: Significant')
  if result[3] < result[0]:
    print('Women: Significant')
  if result[4] < result[0]:
    print('Men: Significant')
print('')

print('Maximum: Lower Thoracic')
result_max_sit_lat_lt = statAnova_lt(max_sit_lat)
print(result_max_sit_lat_lt)
if result_max_sit_lat_lt['PR(>F)'][0] < 0.05:
  print('Gender: Significant')
if result_max_sit_lat_lt['PR(>F)'][1] < 0.05:
  print('Size: Significant')
if result_max_sit_lat_lt['PR(>F)'][2] < 0.05:
  result = significant_lt(max_sit_lat, result_max_sit_lat_lt['PR(>F)'])
  print('Small: ', result[1], ', Large: ', result[2], ', Women: ', result[3], ', Men: ', result[4])
  if result[1] < result[0]:
    print('Small: Significant')
  if result[2] < result[0]:
    print('Large: Significant')
  if result[3] < result[0]:
    print('Women: Significant')
  if result[4] < result[0]:
    print('Men: Significant')
print('')

print('Maximum: Lumbar')
result_max_sit_lat_lum = statAnova_lum(max_sit_lat)
print(result_max_sit_lat_lum)
if result_max_sit_lat_lum['PR(>F)'][0] < 0.05:
  print('Gender: Significant')
if result_max_sit_lat_lum['PR(>F)'][1] < 0.05:
  print('Size: Significant')
if result_max_sit_lat_lum['PR(>F)'][2] < 0.05:
  result = significant_lum(max_sit_lat, result_max_sit_lat_lum['PR(>F)'])
  print('Small: ', result[1], ', Large: ', result[2], ', Women: ', result[3], ', Men: ', result[4])
  if result[1] < result[0]:
    print('Small: Significant')
  if result[2] < result[0]:
    print('Large: Significant')
  if result[3] < result[0]:
    print('Women: Significant')
  if result[4] < result[0]:
    print('Men: Significant')
print('')

# Means
url_mean_sit_lat = 'https://raw.githubusercontent.com/GraceHerchenroder/Thesis/main/mean_sit_lat.csv'
mean_sit_lat = pd.read_csv(url_mean_sit_lat, header = None)

print('Mean: Upper Thoracic')
result_mean_sit_lat_ut = statAnova_ut(mean_sit_lat)
print(result_mean_sit_lat_ut)
if result_mean_sit_lat_ut['PR(>F)'][0] < 0.05:
  print('Gender: Significant')
if result_mean_sit_lat_ut['PR(>F)'][1] < 0.05:
  print('Size: Significant')
if result_mean_sit_flex_ut['PR(>F)'][2] < 0.05:
  result = significant_ut(mean_sit_lat, result_mean_sit_lat_ut['PR(>F)'])
  print('Small: ', result[1], ', Large: ', result[2], ', Women: ', result[3], ', Men: ', result[4])
  if result[1] < result[0]:
    print('Small: Significant')
  if result[2] < result[0]:
    print('Large: Significant')
  if result[3] < result[0]:
    print('Women: Significant')
  if result[4] < result[0]:
    print('Men: Significant')
print('')

print('Mean: Lower Thoracic')
result_mean_sit_lat_lt = statAnova_lt(mean_sit_lat)
print(result_mean_sit_lat_lt)
if result_mean_sit_lat_lt['PR(>F)'][0] < 0.05:
  print('Gender: Significant')
if result_mean_sit_lat_lt['PR(>F)'][1] < 0.05:
  print('Size: Significant')
if result_mean_sit_lat_lt['PR(>F)'][2] < 0.05:
  result = significant_lt(mean_sit_lat, result_mean_sit_lat_lt['PR(>F)'])
  print('Small: ', result[1], ', Large: ', result[2], ', Women: ', result[3], ', Men: ', result[4])
  if result[1] < result[0]:
    print('Small: Significant')
  if result[2] < result[0]:
    print('Large: Significant')
  if result[3] < result[0]:
    print('Women: Significant')
  if result[4] < result[0]:
    print('Men: Significant')
print('')

print('Mean: Lumbar')
result_mean_sit_lat_lum = statAnova_lum(mean_sit_lat)
print(result_mean_sit_lat_lum)
if result_mean_sit_lat_lum['PR(>F)'][0] < 0.05:
  print('Gender: Significant')
if result_mean_sit_lat_lum['PR(>F)'][1] < 0.05:
  print('Size: Significant')
if result_mean_sit_lat_lum['PR(>F)'][2] < 0.05:
  result = significant_lum(mean_sit_lat, result_mean_sit_lat_lum['PR(>F)'])
  print('Small: ', result[1], ', Large: ', result[2], ', Women: ', result[3], ', Men: ', result[4])
  if result[1] < result[0]:
    print('Small: Significant')
  if result[2] < result[0]:
    print('Large: Significant')
  if result[3] < result[0]:
    print('Women: Significant')
  if result[4] < result[0]:
    print('Men: Significant')
print('')
# Out:
# Lateral Flexion
#
# Minimum: Upper Thoracic
# 0   -10.952028
# 1   -14.831854
# 2     0.000004
# Name: 0, dtype: float64
# -8.594626323587358 6.280340182099039
# 3   -13.393946
# 4    -6.924249
# Name: 0, dtype: float64
# -10.159097702865845 3.2348482897710547
# 5   -26.064827
# 6    -9.023081
# 7     0.000004
# Name: 0, dtype: float64
# -11.695968135433908 10.807469581131407
# 8   -6.762440
# 9   -9.929542
# Name: 0, dtype: float64
# -11.695968135433908 10.807469581131407
#   Gender   Size  Kinematic
# 0  women  small -10.952028
# 1  women  small -14.831854
# 2  women  small   0.000004
# 3  women  large -13.393946
# 4  women  large  -6.924249
# 5    men  small -26.064827
# 6    men  small  -9.023081
# 7    men  small   0.000004
# 8    men  large  -6.762440
# 9    men  large  -9.929542
#                        sum_sq   df         F    PR(>F)
# C(Gender)            3.223756  1.0  0.039101  0.849777
# C(Size)              1.912818  1.0  0.023201  0.883929
# C(Gender):C(Size)   14.491081  1.0  0.175765  0.689634
# Residual           494.675971  6.0       NaN       NaN
#
# Minimum: Lower Thoracic
# 0   -10.952028
# 1   -14.831854
# 2     0.000004
# Name: 0, dtype: float64
# -8.594626323587358 6.280340182099039
# 3   -13.393946
# 4    -6.924249
# Name: 0, dtype: float64
# -10.159097702865845 3.2348482897710547
# 5   -26.064827
# 6    -9.023081
# 7     0.000004
# Name: 0, dtype: float64
# -11.695968135433908 10.807469581131407
# 8   -6.762440
# 9   -9.929542
# Name: 0, dtype: float64
# -11.695968135433908 10.807469581131407
#   Gender   Size  Kinematic
# 0  women  small  -7.347941
# 1  women  small -11.666886
# 2  women  small  -4.844498
# 3  women  large  -9.581497
# 4  women  large -12.197961
# 5    men  small -12.725319
# 6    men  small -13.095425
# 7    men  small  -4.844498
# 8    men  large -16.763240
# 9    men  large -14.104352
#                       sum_sq   df         F    PR(>F)
# C(Gender)          25.262093  1.0  2.042197  0.202919
# C(Size)            39.840491  1.0  3.220721  0.122862
# C(Gender):C(Size)   3.106544  1.0  0.251134  0.634128
# Residual           74.220327  6.0       NaN       NaN
#
# Minimum: Lumbar
# 0   -10.952028
# 1   -14.831854
# 2     0.000004
# Name: 0, dtype: float64
# -8.594626323587358 6.280340182099039
# 3   -13.393946
# 4    -6.924249
# Name: 0, dtype: float64
# -10.159097702865845 3.2348482897710547
# 5   -26.064827
# 6    -9.023081
# 7     0.000004
# Name: 0, dtype: float64
# -11.695968135433908 10.807469581131407
# 8   -6.762440
# 9   -9.929542
# Name: 0, dtype: float64
# -11.695968135433908 10.807469581131407
#   Gender   Size  Kinematic
# 0  women  small -16.618924
# 1  women  small  -9.941803
# 2  women  small  -3.959775
# 3  women  large  -7.555735
# 4  women  large  -7.446800
# 5    men  small  -9.364435
# 6    men  small  -8.365167
# 7    men  small  -3.959775
# 8    men  large -16.794112
# 9    men  large  -8.537789
#                        sum_sq   df         F    PR(>F)
# C(Gender)            0.224473  1.0  0.010294  0.922491
# C(Size)              4.583567  1.0  0.210198  0.662750
# C(Gender):C(Size)   39.447609  1.0  1.809029  0.227233
# Residual           130.835714  6.0       NaN       NaN
#
# Maximum: Upper Thoracic
# 0    8.950330
# 1    6.733801
# 2    8.878410
# Name: 0, dtype: float64
# 8.18751387633452 1.0283491354587906
# 3    13.418885
# 4    16.423161
# Name: 0, dtype: float64
# 14.921022855478501 1.502137983379801
# 5     7.564641
# 6    23.033963
# 7     8.878410
# Name: 0, dtype: float64
# 13.159004613611609 7.003218022011012
# 8    7.92069
# 9    8.94886
# Name: 0, dtype: float64
# 13.159004613611609 7.003218022011012
#   Gender   Size  Kinematic
# 0  women  small   8.950330
# 1  women  small   6.733801
# 2  women  small   8.878410
# 3  women  large  13.418885
# 4  women  large  16.423161
# 5    men  small   7.564641
# 6    men  small  23.033963
# 7    men  small   8.878410
# 8    men  large   7.920690
# 9    men  large   8.948860
#                        sum_sq   df         F    PR(>F)
# C(Gender)            0.377127  1.0  0.014566  0.907878
# C(Size)              2.422322  1.0  0.093557  0.770038
# C(Gender):C(Size)   78.767867  1.0  3.042227  0.131743
# Residual           155.349098  6.0       NaN       NaN
#
# Maximum: Lower Thoracic
# 0    8.950330
# 1    6.733801
# 2    8.878410
# Name: 0, dtype: float64
# 8.18751387633452 1.0283491354587906
# 3    13.418885
# 4    16.423161
# Name: 0, dtype: float64
# 14.921022855478501 1.502137983379801
# 5     7.564641
# 6    23.033963
# 7     8.878410
# Name: 0, dtype: float64
# 13.159004613611609 7.003218022011012
# 8    7.92069
# 9    8.94886
# Name: 0, dtype: float64
# 13.159004613611609 7.003218022011012
#   Gender   Size  Kinematic
# 0  women  small   6.687518
# 1  women  small   9.793454
# 2  women  small   7.128611
# 3  women  large  10.358638
# 4  women  large  14.150171
# 5    men  small   7.919960
# 6    men  small  18.094834
# 7    men  small   7.128611
# 8    men  large   9.649587
# 9    men  large  11.767415
#                       sum_sq   df         F    PR(>F)
# C(Gender)           4.149954  1.0  0.277026  0.617537
# C(Size)             9.818393  1.0  0.655418  0.449089
# C(Gender):C(Size)  13.388826  1.0  0.893759  0.380959
# Residual           89.882163  6.0       NaN       NaN
#
# Maximum: Lumbar
# 0    8.950330
# 1    6.733801
# 2    8.878410
# Name: 0, dtype: float64
# 8.18751387633452 1.0283491354587906
# 3    13.418885
# 4    16.423161
# Name: 0, dtype: float64
# 14.921022855478501 1.502137983379801
# 5     7.564641
# 6    23.033963
# 7     8.878410
# Name: 0, dtype: float64
# 13.159004613611609 7.003218022011012
# 8    7.92069
# 9    8.94886
# Name: 0, dtype: float64
# 13.159004613611609 7.003218022011012
#   Gender   Size  Kinematic
# 0  women  small  15.923177
# 1  women  small   1.614017
# 2  women  small   7.419024
# 3  women  large   4.919321
# 4  women  large  -0.000036
# 5    men  small   6.460107
# 6    men  small  22.125122
# 7    men  small   7.419024
# 8    men  large  12.586742
# 9    men  large   8.095423
#                        sum_sq   df         F    PR(>F)
# C(Gender)           71.882521  1.0  1.540504  0.260866
# C(Size)             33.925112  1.0  0.727044  0.426564
# C(Gender):C(Size)   10.577760  1.0  0.226690  0.650830
# Residual           279.970117  6.0       NaN       NaN
#
# Mean: Upper Thoracic
# 0   -1.068249
# 1   -4.822383
# 2    2.106704
# Name: 0, dtype: float64
# -1.2613094964735299 2.8320798701623957
# 3   -0.887173
# 4    3.459212
# Name: 0, dtype: float64
# 1.2860193187268376 2.1731927334394427
# 5   -2.246725
# 6    2.110942
# 7    2.106704
# Name: 0, dtype: float64
# 0.6569734420800266 2.0532256200797505
# 8   -0.759597
# 9   -0.747069
# Name: 0, dtype: float64
# 0.6569734420800266 2.0532256200797505
#   Gender   Size  Kinematic
# 0  women  small  -1.068249
# 1  women  small  -4.822383
# 2  women  small   2.106704
# 3  women  large  -0.887173
# 4  women  large   3.459212
# 5    men  small  -2.246725
# 6    men  small   2.110942
# 7    men  small   2.106704
# 8    men  large  -0.759597
# 9    men  large  -0.747069
#                       sum_sq   df         F    PR(>F)
# C(Gender)           0.280946  1.0  0.036522  0.854744
# C(Size)             0.775692  1.0  0.100838  0.761587
# C(Gender):C(Size)   9.397727  1.0  1.221678  0.311371
# Residual           46.154847  6.0       NaN       NaN
#
# Mean: Lower Thoracic
# 0   -1.068249
# 1   -4.822383
# 2    2.106704
# Name: 0, dtype: float64
# -1.2613094964735299 2.8320798701623957
# 3   -0.887173
# 4    3.459212
# Name: 0, dtype: float64
# 1.2860193187268376 2.1731927334394427
# 5   -2.246725
# 6    2.110942
# 7    2.106704
# Name: 0, dtype: float64
# 0.6569734420800266 2.0532256200797505
# 8   -0.759597
# 9   -0.747069
# Name: 0, dtype: float64
# 0.6569734420800266 2.0532256200797505
#   Gender   Size  Kinematic
# 0  women  small  -2.273576
# 1  women  small  -2.042348
# 2  women  small   1.248491
# 3  women  large  -1.137258
# 4  women  large   1.613897
# 5    men  small  -2.164795
# 6    men  small   2.942523
# 7    men  small   1.248491
# 8    men  large  -2.997228
# 9    men  large  -3.832640
#                       sum_sq   df         F    PR(>F)
# C(Gender)           0.489672  1.0  0.115529  0.745518
# C(Size)             4.803789  1.0  1.133368  0.328014
# C(Gender):C(Size)  17.180804  1.0  4.053502  0.090735
# Residual           25.431052  6.0       NaN       NaN
#
# Mean: Lumbar
# 0   -1.068249
# 1   -4.822383
# 2    2.106704
# Name: 0, dtype: float64
# -1.2613094964735299 2.8320798701623957
# 3   -0.887173
# 4    3.459212
# Name: 0, dtype: float64
# 1.2860193187268376 2.1731927334394427
# 5   -2.246725
# 6    2.110942
# 7    2.106704
# Name: 0, dtype: float64
# 0.6569734420800266 2.0532256200797505
# 8   -0.759597
# 9   -0.747069
# Name: 0, dtype: float64
# 0.6569734420800266 2.0532256200797505
#   Gender   Size  Kinematic
# 0  women  small  -1.354755
# 1  women  small  -2.594929
# 2  women  small   2.774386
# 3  women  large  -2.084426
# 4  women  large  -1.123816
# 5    men  small  -3.868095
# 6    men  small   2.639783
# 7    men  small   2.774386
# 8    men  large  -9.861149
# 9    men  large   0.463810
#                       sum_sq   df         F    PR(>F)
# C(Gender)           1.202512  1.0  0.073323  0.795632
# C(Size)            24.779033  1.0  1.510907  0.265016
# C(Gender):C(Size)   9.608030  1.0  0.585852  0.473051
# Residual           98.400614  6.0       NaN       NaN

# %%
print('Mean')
box_whisker(mean_sit_lat)
print('Min')
box_whisker(min_sit_lat)
print('Max')
box_whisker(max_sit_lat)
# Out:
# Mean
# Min
# Max

# %%
# Axial Flexion
# Flexion
print('\033[1mAxial Flexion\033[0m')
print('')

# Minimums
url_min_sit_axi = 'https://raw.githubusercontent.com/GraceHerchenroder/Thesis/main/min_sit_axi.csv'
min_sit_axi = pd.read_csv(url_min_sit_axi, header = None)

print('Minimum: Upper Thoracic')
result_min_sit_axi_ut = statAnova_ut(min_sit_axi)
print(result_min_sit_axi_ut)
if result_min_sit_axi_ut['PR(>F)'][0] < 0.05:
  print('Gender: Significant')
if result_min_sit_axi_ut['PR(>F)'][1] < 0.05:
  print('Size: Significant')
if result_min_sit_axi_ut['PR(>F)'][2] < 0.05:
  result = significant_ut(min_sit_axi, result_min_sit_axi_ut['PR(>F)'])
  print('Small: ', result[1], ', Large: ', result[2], ', Women: ', result[3], ', Men: ', result[4])
  if result[1] < result[0]:
    print('Small: Significant')
  if result[2] < result[0]:
    print('Large: Significant')
  if result[3] < result[0]:
    print('Women: Significant')
  if result[4] < result[0]:
    print('Men: Significant')
print('')

print('Minimum: Lower Thoracic')
result_min_sit_axi_lt = statAnova_lt(min_sit_axi)
print(result_min_sit_axi_lt)
if result_min_sit_axi_lt['PR(>F)'][0] < 0.05:
  print('Gender: Significant')
if result_min_sit_axi_lt['PR(>F)'][1] < 0.05:
  print('Size: Significant')
if result_min_sit_axi_lt['PR(>F)'][2] < 0.05:
  result = significant_lt(min_sit_axi, result_min_sit_axi_lt['PR(>F)'])
  print('Small: ', result[1], ', Large: ', result[2], ', Women: ', result[3], ', Men: ', result[4])
  if result[1] < result[0]:
    print('Small: Significant')
  if result[2] < result[0]:
    print('Large: Significant')
  if result[3] < result[0]:
    print('Women: Significant')
  if result[4] < result[0]:
    print('Men: Significant')
print('')

print('Minimum: Lumbar')
result_min_sit_axi_lum = statAnova_lum(min_sit_axi)
print(result_min_sit_axi_lum)
if result_min_sit_axi_lum['PR(>F)'][0] < 0.05:
  print('Gender: Significant')
if result_min_sit_axi_lum['PR(>F)'][1] < 0.05:
  print('Size: Significant')
if result_min_sit_axi_lum['PR(>F)'][2] < 0.05:
  result = significant_lum(min_sit_axi, result_min_sit_axi_lum['PR(>F)'])
  print('Small: ', result[1], ', Large: ', result[2], ', Women: ', result[3], ', Men: ', result[4])
  if result[1] < result[0]:
    print('Small: Significant')
  if result[2] < result[0]:
    print('Large: Significant')
  if result[3] < result[0]:
    print('Women: Significant')
  if result[4] < result[0]:
    print('Men: Significant')
print('')

# Maximums
url_max_sit_axi = 'https://raw.githubusercontent.com/GraceHerchenroder/Thesis/main/max_sit_axi.csv'
max_sit_axi = pd.read_csv(url_max_sit_axi, header = None)

print('Maximum: Upper Thoracic')
result_max_sit_axi_ut = statAnova_ut(max_sit_axi)
print(result_max_sit_axi_ut)
if result_max_sit_axi_ut['PR(>F)'][0] < 0.05:
  print('Gender: Significant')
if result_max_sit_axi_ut['PR(>F)'][1] < 0.05:
  print('Size: Significant')
if result_max_sit_axi_ut['PR(>F)'][2] < 0.05:
  result = significant_ut(max_sit_axi, result_max_sit_axi_ut['PR(>F)'])
  print('Small: ', result[1], ', Large: ', result[2], ', Women: ', result[3], ', Men: ', result[4])
  if result[1] < result[0]:
    print('Small: Significant')
  if result[2] < result[0]:
    print('Large: Significant')
  if result[3] < result[0]:
    print('Women: Significant')
  if result[4] < result[0]:
    print('Men: Significant')
print('')

print('Maximum: Lower Thoracic')
result_max_sit_axi_lt = statAnova_lt(max_sit_axi)
print(result_max_sit_axi_lt)
if result_max_sit_axi_lt['PR(>F)'][0] < 0.05:
  print('Gender: Significant')
if result_max_sit_axi_lt['PR(>F)'][1] < 0.05:
  print('Size: Significant')
if result_max_sit_axi_lt['PR(>F)'][2] < 0.05:
  result = significant_lt(max_sit_axi, result_max_sit_axi_lt['PR(>F)'])
  print('Small: ', result[1], ', Large: ', result[2], ', Women: ', result[3], ', Men: ', result[4])
  if result[1] < result[0]:
    print('Small: Significant')
  if result[2] < result[0]:
    print('Large: Significant')
  if result[3] < result[0]:
    print('Women: Significant')
  if result[4] < result[0]:
    print('Men: Significant')
print('')

print('Maximum: Lumbar')
result_max_sit_axi_lum = statAnova_lum(max_sit_axi)
print(result_max_sit_axi_lum)
if result_max_sit_axi_lum['PR(>F)'][0] < 0.05:
  print('Gender: Significant')
if result_max_sit_axi_lum['PR(>F)'][1] < 0.05:
  print('Size: Significant')
if result_max_sit_axi_lum['PR(>F)'][2] < 0.05:
  result = significant_lum(max_sit_axi, result_max_sit_axi_lum['PR(>F)'])
  print('Small: ', result[1], ', Large: ', result[2], ', Women: ', result[3], ', Men: ', result[4])
  if result[1] < result[0]:
    print('Small: Significant')
  if result[2] < result[0]:
    print('Large: Significant')
  if result[3] < result[0]:
    print('Women: Significant')
  if result[4] < result[0]:
    print('Men: Significant')
print('')

# Means
url_mean_sit_axi = 'https://raw.githubusercontent.com/GraceHerchenroder/Thesis/main/mean_sit_axi.csv'
mean_sit_axi = pd.read_csv(url_mean_sit_axi, header = None)

print('Mean: Upper Thoracic')
result_mean_sit_axi_ut = statAnova_ut(mean_sit_axi)
print(result_mean_sit_axi_ut)
if result_mean_sit_axi_ut['PR(>F)'][0] < 0.05:
  print('Gender: Significant')
if result_mean_sit_axi_ut['PR(>F)'][1] < 0.05:
  print('Size: Significant')
if result_mean_sit_axi_ut['PR(>F)'][2] < 0.05:
  result = significant_ut(mean_sit_axi, result_mean_sit_axi_ut['PR(>F)'])
  print('Small: ', result[1], ', Large: ', result[2], ', Women: ', result[3], ', Men: ', result[4])
  if result[1] < result[0]:
    print('Small: Significant')
  if result[2] < result[0]:
    print('Large: Significant')
  if result[3] < result[0]:
    print('Women: Significant')
  if result[4] < result[0]:
    print('Men: Significant')
print('')

print('Mean: Lower Thoracic')
result_mean_sit_axi_lt = statAnova_lt(mean_sit_axi)
print(result_mean_sit_axi_lt)
if result_mean_sit_axi_lt['PR(>F)'][0] < 0.05:
  print('Gender: Significant')
if result_mean_sit_axi_lt['PR(>F)'][1] < 0.05:
  print('Size: Significant')
if result_mean_sit_axi_lt['PR(>F)'][2] < 0.05:
  result = significant_lt(mean_sit_axi, result_mean_sit_axi_lt['PR(>F)'])
  print('Small: ', result[1], ', Large: ', result[2], ', Women: ', result[3], ', Men: ', result[4])
  if result[1] < result[0]:
    print('Small: Significant')
  if result[2] < result[0]:
    print('Large: Significant')
  if result[3] < result[0]:
    print('Women: Significant')
  if result[4] < result[0]:
    print('Men: Significant')
print('')

print('Mean: Lumbar')
result_mean_sit_axi_lum = statAnova_lum(mean_sit_axi)
print(result_mean_sit_axi_lum)
if result_mean_sit_axi_lum['PR(>F)'][0] < 0.05:
  print('Gender: Significant')
if result_mean_sit_axi_lum['PR(>F)'][1] < 0.05:
  print('Size: Significant')
if result_mean_sit_axi_lum['PR(>F)'][2] < 0.05:
  result = significant_lum(mean_sit_axi, result_mean_sit_axi_lum['PR(>F)'])
  print('Small: ', result[1], ', Large: ', result[2], ', Women: ', result[3], ', Men: ', result[4])
  if result[1] < result[0]:
    print('Small: Significant')
  if result[2] < result[0]:
    print('Large: Significant')
  if result[3] < result[0]:
    print('Women: Significant')
  if result[4] < result[0]:
    print('Men: Significant')
print('')
# Out:
# Axial Flexion
#
# Minimum: Upper Thoracic
# 0   -16.834080
# 1   -10.536023
# 2   -12.319487
# Name: 0, dtype: float64
# -13.229863604746031 2.6505308775198526
# 3   -47.914211
# 4   -23.542810
# Name: 0, dtype: float64
# -35.7285103613045 12.1857001696308
# 5   -11.886059
# 6   -34.018583
# 7   -12.319487
# Name: 0, dtype: float64
# -19.408042950553366 10.332726849473152
# 8   -29.548390
# 9   -10.012464
# Name: 0, dtype: float64
# -19.408042950553366 10.332726849473152
#   Gender   Size  Kinematic
# 0  women  small -16.834080
# 1  women  small -10.536023
# 2  women  small -12.319487
# 3  women  large -47.914211
# 4  women  large -23.542810
# 5    men  small -11.886059
# 6    men  small -34.018583
# 7    men  small -12.319487
# 8    men  large -29.548390
# 9    men  large -10.012464
#                        sum_sq   df         F    PR(>F)
# C(Gender)           17.853312  1.0  0.129188  0.731587
# C(Size)            313.850429  1.0  2.271041  0.182531
# C(Gender):C(Size)  293.742902  1.0  2.125541  0.195133
# Residual           829.180444  6.0       NaN       NaN
#
# Minimum: Lower Thoracic
# 0   -16.834080
# 1   -10.536023
# 2   -12.319487
# Name: 0, dtype: float64
# -13.229863604746031 2.6505308775198526
# 3   -47.914211
# 4   -23.542810
# Name: 0, dtype: float64
# -35.7285103613045 12.1857001696308
# 5   -11.886059
# 6   -34.018583
# 7   -12.319487
# Name: 0, dtype: float64
# -19.408042950553366 10.332726849473152
# 8   -29.548390
# 9   -10.012464
# Name: 0, dtype: float64
# -19.408042950553366 10.332726849473152
#   Gender   Size  Kinematic
# 0  women  small -22.662833
# 1  women  small -17.884622
# 2  women  small  -3.091951
# 3  women  large -20.761631
# 4  women  large -14.540142
# 5    men  small -39.714248
# 6    men  small -21.202423
# 7    men  small  -3.091951
# 8    men  large -32.748051
# 9    men  large -17.147721
#                         sum_sq   df         F    PR(>F)
# C(Gender)           122.242645  1.0  0.719154  0.428948
# C(Size)              27.063572  1.0  0.159215  0.703694
# C(Gender):C(Size)     0.154388  1.0  0.000908  0.976935
# Residual           1019.886377  6.0       NaN       NaN
#
# Minimum: Lumbar
# 0   -16.834080
# 1   -10.536023
# 2   -12.319487
# Name: 0, dtype: float64
# -13.229863604746031 2.6505308775198526
# 3   -47.914211
# 4   -23.542810
# Name: 0, dtype: float64
# -35.7285103613045 12.1857001696308
# 5   -11.886059
# 6   -34.018583
# 7   -12.319487
# Name: 0, dtype: float64
# -19.408042950553366 10.332726849473152
# 8   -29.548390
# 9   -10.012464
# Name: 0, dtype: float64
# -19.408042950553366 10.332726849473152
#   Gender   Size  Kinematic
# 0  women  small -33.609722
# 1  women  small -14.383789
# 2  women  small  -7.457174
# 3  women  large -13.399641
# 4  women  large -13.478062
# 5    men  small -39.390633
# 6    men  small -21.805313
# 7    men  small  -7.457174
# 8    men  large -17.048848
# 9    men  large -10.698676
#                        sum_sq   df         F    PR(>F)
# C(Gender)           19.802842  1.0  0.132169  0.728659
# C(Size)            118.531242  1.0  0.791109  0.408008
# C(Gender):C(Size)    9.437024  1.0  0.062985  0.810212
# Residual           898.974960  6.0       NaN       NaN
#
# Maximum: Upper Thoracic
# 0    19.499627
# 1    23.080284
# 2    11.807629
# Name: 0, dtype: float64
# 18.129179828268267 4.702962241912787
# 3    8.257957
# 4    5.560592
# Name: 0, dtype: float64
# 6.909274284049374 1.3486823466397548
# 5    24.515847
# 6    23.053416
# 7    11.807629
# Name: 0, dtype: float64
# 19.792297367182833 5.677492065305045
# 8     4.970445
# 9    29.540311
# Name: 0, dtype: float64
# 19.792297367182833 5.677492065305045
#   Gender   Size  Kinematic
# 0  women  small  19.499627
# 1  women  small  23.080284
# 2  women  small  11.807629
# 3  women  large   8.257957
# 4  women  large   5.560592
# 5    men  small  24.515847
# 6    men  small  23.053416
# 7    men  small  11.807629
# 8    men  large   4.970445
# 9    men  large  29.540311
#                        sum_sq   df         F    PR(>F)
# C(Gender)           65.954251  1.0  0.844607  0.393529
# C(Size)            113.550142  1.0  1.454117  0.273259
# C(Gender):C(Size)   45.236547  1.0  0.579297  0.475428
# Residual           468.532364  6.0       NaN       NaN
#
# Maximum: Lower Thoracic
# 0    19.499627
# 1    23.080284
# 2    11.807629
# Name: 0, dtype: float64
# 18.129179828268267 4.702962241912787
# 3    8.257957
# 4    5.560592
# Name: 0, dtype: float64
# 6.909274284049374 1.3486823466397548
# 5    24.515847
# 6    23.053416
# 7    11.807629
# Name: 0, dtype: float64
# 19.792297367182833 5.677492065305045
# 8     4.970445
# 9    29.540311
# Name: 0, dtype: float64
# 19.792297367182833 5.677492065305045
#   Gender   Size  Kinematic
# 0  women  small  12.737084
# 1  women  small  24.562111
# 2  women  small  21.788324
# 3  women  large  20.560163
# 4  women  large  28.100169
# 5    men  small  22.897346
# 6    men  small  32.811433
# 7    men  small  21.788324
# 8    men  large  18.453266
# 9    men  large  17.367351
#                        sum_sq   df         F    PR(>F)
# C(Gender)            3.102343  1.0  0.103888  0.758148
# C(Size)              6.485510  1.0  0.217179  0.657635
# C(Gender):C(Size)   94.597684  1.0  3.167778  0.125407
# Residual           179.174810  6.0       NaN       NaN
#
# Maximum: Lumbar
# 0    19.499627
# 1    23.080284
# 2    11.807629
# Name: 0, dtype: float64
# 18.129179828268267 4.702962241912787
# 3    8.257957
# 4    5.560592
# Name: 0, dtype: float64
# 6.909274284049374 1.3486823466397548
# 5    24.515847
# 6    23.053416
# 7    11.807629
# Name: 0, dtype: float64
# 19.792297367182833 5.677492065305045
# 8     4.970445
# 9    29.540311
# Name: 0, dtype: float64
# 19.792297367182833 5.677492065305045
#   Gender   Size  Kinematic
# 0  women  small  12.733649
# 1  women  small  28.733243
# 2  women  small   6.867261
# 3  women  large  13.734138
# 4  women  large   5.568441
# 5    men  small   8.079349
# 6    men  small  23.790927
# 7    men  small   6.867261
# 8    men  large   6.956109
# 9    men  large  12.761855
#                        sum_sq   df         F    PR(>F)
# C(Gender)            8.429500  1.0  0.104366  0.757614
# C(Size)             54.305432  1.0  0.672359  0.443577
# C(Gender):C(Size)    6.962811  1.0  0.086207  0.778947
# Residual           484.611322  6.0       NaN       NaN
#
# Mean: Upper Thoracic
# 0    3.218304
# 1    3.412056
# 2    0.866087
# Name: 0, dtype: float64
# 2.4988156904482968 1.15721974482695
# 3   -10.042867
# 4    -7.719684
# Name: 0, dtype: float64
# -8.881275148812694 1.1615914457494045
# 5    5.838964
# 6   -9.233681
# 7    0.866087
# Name: 0, dtype: float64
# -0.8428766433837399 6.270915502246958
# 8    -9.545922
# 9    14.012880
# Name: 0, dtype: float64
# -0.8428766433837399 6.270915502246958
#   Gender   Size  Kinematic
# 0  women  small   3.218304
# 1  women  small   3.412056
# 2  women  small   0.866087
# 3  women  large -10.042867
# 4  women  large  -7.719684
# 5    men  small   5.838964
# 6    men  small  -9.233681
# 7    men  small   0.866087
# 8    men  large  -9.545922
# 9    men  large  14.012880
#                        sum_sq   df         F    PR(>F)
# C(Gender)           14.894814  1.0  0.222201  0.654020
# C(Size)             41.371212  1.0  0.617177  0.461985
# C(Gender):C(Size)  125.393305  1.0  1.870622  0.220417
# Residual           402.197777  6.0       NaN       NaN
#
# Mean: Lower Thoracic
# 0    3.218304
# 1    3.412056
# 2    0.866087
# Name: 0, dtype: float64
# 2.4988156904482968 1.15721974482695
# 3   -10.042867
# 4    -7.719684
# Name: 0, dtype: float64
# -8.881275148812694 1.1615914457494045
# 5    5.838964
# 6   -9.233681
# 7    0.866087
# Name: 0, dtype: float64
# -0.8428766433837399 6.270915502246958
# 8    -9.545922
# 9    14.012880
# Name: 0, dtype: float64
# -0.8428766433837399 6.270915502246958
#   Gender   Size  Kinematic
# 0  women  small  -3.197120
# 1  women  small   3.429780
# 2  women  small  11.046637
# 3  women  large  -1.300117
# 4  women  large   6.994649
# 5    men  small  -5.739508
# 6    men  small   0.109668
# 7    men  small  11.046637
# 8    men  large  -2.987110
# 9    men  large   1.375003
#                        sum_sq   df         F    PR(>F)
# C(Gender)           17.342617  1.0  0.357921  0.571540
# C(Size)              7.451790  1.0  0.153792  0.708489
# C(Gender):C(Size)    1.732271  1.0  0.035751  0.856264
# Residual           290.722848  6.0       NaN       NaN
#
# Mean: Lumbar
# 0    3.218304
# 1    3.412056
# 2    0.866087
# Name: 0, dtype: float64
# 2.4988156904482968 1.15721974482695
# 3   -10.042867
# 4    -7.719684
# Name: 0, dtype: float64
# -8.881275148812694 1.1615914457494045
# 5    5.838964
# 6   -9.233681
# 7    0.866087
# Name: 0, dtype: float64
# -0.8428766433837399 6.270915502246958
# 8    -9.545922
# 9    14.012880
# Name: 0, dtype: float64
# -0.8428766433837399 6.270915502246958
#   Gender   Size  Kinematic
# 0  women  small  -1.422210
# 1  women  small   3.822207
# 2  women  small  -1.009553
# 3  women  large  -3.036445
# 4  women  large  -4.331742
# 5    men  small  -7.028497
# 6    men  small   6.088613
# 7    men  small  -1.009553
# 8    men  large  -2.773643
# 9    men  large  -1.888382
#                        sum_sq   df         F    PR(>F)
# C(Gender)            0.040160  1.0  0.002307  0.963253
# C(Size)             20.384771  1.0  1.170856  0.320785
# C(Gender):C(Size)    3.649801  1.0  0.209636  0.663165
# Residual           104.460852  6.0       NaN       NaN
